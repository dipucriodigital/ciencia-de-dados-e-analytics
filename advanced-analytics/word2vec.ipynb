# %% [markdown]
# #Similaridade de palavras em contexto - Word2Vec
#
# Neste exercício vamos calcular a similaridade entre palavras dado um contexto apresentado. Neste caso, vamos analisar textos de machado de assis e ver quais termos aparecem mais próximo dado o contexto da narrativa.
#
# Para isso vamos utilizar 3 bibliotecas para processamento de texto: NLTK, Spacy e Gensim.
#
# *Adaptadado de: https://www.kaggle.com/code/pierremegret/gensim-word2vec-tutorial/notebook

# %%
import re  # For preprocessing
import pandas as pd  # For data handling
from time import time  # To time our operations
from collections import defaultdict  # For word frequency

import spacy  # For preprocessing

import logging  # Setting up the loggings to monitor gensim
logging.basicConfig(format="%(levelname)s - %(asctime)s: %(message)s", datefmt= '%H:%M:%S', level=logging.INFO)

# %% [markdown]
# Vamos fazer o download do pipeline para processamento de texto em português da Spacy.

# %%
# !python3 -m spacy download pt_core_news_sm
from spacy.lang.pt.examples import sentences
# Out:
# Collecting pt-core-news-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/pt_core_news_sm-3.8.0/pt_core_news_sm-3.8.0-py3-none-any.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 80.2 MB/s eta 0:00:00
# Installing collected packages: pt-core-news-sm
# Successfully installed pt-core-news-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %% [markdown]
# Vamos fazer o download da base de texto das obras de machado de assis. (incluso na nltk)

# %%
import nltk
nltk.download('machado')
nltk.download('punkt_tab')
from nltk.corpus import machado

# machado.fileids() # This line caused an AttributeError and is not essential for the next steps.
# Out:
# [nltk_data] Downloading package machado to /root/nltk_data...
# [nltk_data]   Package machado is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %% [markdown]
# Antes de começarmos a análise precisamos extrair caracteres não alfa-numéricos, stop-words e reduzir as palavras ao seu radical. Isto é uma etapa essencial no pré-processamento de dados.

# %%
import re
import io
import zipfile
from time import time
from pathlib import Path

import requests
import spacy
import nltk

nltk.download('punkt_tab', quiet=True)

# ── Download ──────────────────────────────────────────────────────────────────
# O repositório NLTK armazena corpora como .zip na branch gh-pages.
ZIP_URL = (
    "https://raw.githubusercontent.com/nltk/nltk_data/"
    "gh-pages/packages/corpora/machado.zip"
)
TARGET_FILE = "machado/romance/marm05.txt"   # caminho dentro do zip
local_path  = Path("/tmp/marm05.txt")

try:
    print(f"Baixando {ZIP_URL} …")
    resp = requests.get(ZIP_URL, timeout=60)
    resp.raise_for_status()

    with zipfile.ZipFile(io.BytesIO(resp.content)) as zf:
        # Encontra o arquivo ignorando possíveis variações de path
        target = next(
            name for name in zf.namelist()
            if name.endswith("marm05.txt")
        )
        raw_bytes = zf.read(target)

    # Textos do NLTK-Machado costumam ser latin-1
    for enc in ("utf-8", "latin-1", "iso-8859-1"):
        try:
            raw_text = raw_bytes.decode(enc)
            print(f"Decodificado com {enc!r} — {len(raw_text):,} caracteres")
            break
        except UnicodeDecodeError:
            continue
    else:
        raise ValueError("Não foi possível decodificar o arquivo.")

    local_path.write_text(raw_text, encoding="utf-8")

except requests.exceptions.RequestException as e:
    raise IOError(f"Falha no download: {e}") from e
except StopIteration:
    raise IOError(f"'{TARGET_FILE}' não encontrado dentro do zip.")

# ── spaCy ─────────────────────────────────────────────────────────────────────
nlp = spacy.load("pt_core_news_sm", disable=["ner", "parser"])
nlp.max_length = len(raw_text) + 10_000   # evita erro para textos grandes

def cleaning(doc) -> str | None:
    """Lematiza e remove stopwords e tokens não-alfabéticos."""
    tokens = [
        token.lemma_
        for token in doc
        if not token.is_stop and token.is_alpha   # só palavras reais
    ]
    if len(tokens) > 2:
        return " ".join(tokens)
    return None   # retorno explícito (antes era implicitamente None)

# ── Limpeza de texto ──────────────────────────────────────────────────────────
# CORREÇÃO PRINCIPAL: regex anterior tinha ranges Unicode inválidos (e.g. 豈 > ؀).
# \w já cobre letras acentuadas com re.UNICODE (padrão no Python 3).
new_str = re.sub(r"[^\w\s]", "", raw_text, flags=re.UNICODE).lower()

t = time()
doc = nlp(new_str)
txt = cleaning(doc)

if txt:
    print(f"\nAmostra: {txt[:300]} …")
else:
    print("Texto resultante vazio ou muito curto.")

print(f"\nTempo total: {round((time() - t) / 60, 2)} min")
# Out:
# Baixando https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/packages/corpora/machado.zip …
# Decodificado com 'latin-1' — 355,706 caracteres
#
# Amostra: romancer memória póstuma brás cuba memória póstuma brás cuba textofonte obra completo machar assi rio janeiro editora aguilar publicar originalmente folhetim março revista brasileiro verme roeu fria carne cadáver dedico saudoso lembrança memória póstuma prólogo edição edição de este memória póstuma  …
#
# Tempo total: 0.06 min

# %%
txt = txt.split('\n')
txt
# Out:
# ['romancer memória póstuma brás cuba memória póstuma brás cuba textofonte obra completo machar assi rio janeiro editora aguilar publicar originalmente folhetim março revista brasileiro verme roeu fria carne cadáver dedico saudoso lembrança memória póstuma prólogo edição edição de este memória póstuma brás cuba fazer pedaço revista brasileira ano posta livro corrigi texto lugar rever edição emendei algum suprimi dúzia linha composta sair novamente luz obra algum benevolência encontrar público capistrano abrer noticiar publicação livro perguntar memória póstuma brás cuba romance macedo Soares carta escrever recordar amigamente viagem terra responder defunto brás cuba leitor ver ver prólogo de ele adiante romance explicar finar tratase obra difuso brás cuba adotar livre sterne xavier maistre metir rabugem pessimismo gente viajar xavier maistre roda garretr terra de ele sterne terra brás cuba viajar roda vida brás cuba autor particular chamar rabugem pessimismo haver alma livro risonho parecer sentimento amargo ásperer vir modelo taço lavor igual escola levar outro vinho dizer entrar crítica defunto pintar se conforme parecer melhor certo machado assi leitor stendhalr confessar haver escrito livro cem leitor admira consternar admirar provavelmente consternar outro livro ter cem leitor stendhal cinqüentar tratase verdade obra difuso brás cuba adotar livre sterne xavier maistre metir rabugem pessimismo obra finar escrever pena galhofa tinta melancolia difícil antever sair conúbio acrescer gente grave achar livro aparência puro romance passo gente frívolo achar em ele romance usual eilo ficar privado estima grave amor frívolo coluna máxima opinião esperar angariar simpatia opinião remédio fugir prólogo explícito longo bom prólogo contémr coisa jeito obscuro truncar conseguintemente evito contar processo extraordinário empreguei composição de este memória trabalhar outro mundo curioso nimiamente extenso aliás desnecessário entendimento obra obra si mesmo agradar fino leitor pagomer tarefa agradar pagote piparote brás cuba capítulo óbito autor algum hesitar dever abrir memória princípio porer nascimento morte suposto uso vulgar ser começar nascimento consideração levar adotar diferente método propriamente autor defunto defunto autor campa outro berço escrito ficar galante moisés contar morte pôr intróito cabo diferença radical livro pentateuco dizer expirei hora sextafeira agosto belo chácar catumbi ter sessenta ano rijo próspero solteiro possuir cerca trezento conto acompanhar cemitério amigo amigo verdade haver carta anúncio acrescer chover peneirar chuvinha miúda tristar constante constante triste levar de aquele fiel último hora intercalar engenhoso idéia discurso proferir beira cova conheceste senhor podel comigo natureza chorar perda irreparável belo caracter honrar humanidade ar sombrio gota céu nuvem escura cobr azul crepe funéreo dor cruo má rói natureza íntima entranho sublime louvor ilustre finar fiel amigo arreper apólice deixeir cheguei cláusula dia encaminhei undiscovered country hamlet ânsia dúvida moço príncipe pausar trôpegar retirar espetáculo aborrecir viramme pessoa senhora irmã sabina casado cotrim filha lírio vale ter paciência de aqui eles dir senhora contentemse anônimo parentar padecer parenta verdade padecer dizer carpir dizer deixar rolar chão convulsa óbito altamente dramático solteir expirar sessenta ano reúnar se elemento tragédia dar convinhar anônimo aparentálo pé cabeceira cama olho estúpir boca entreabertar triste senhora crer extinção morrer morto dizer com si imaginação de ela cegonha ilustre viajante ver desferir vôo ilisso riba africana embargo ruína tempo imaginação senhora voar destroço presente riba áfrica juvenil deixála ir ir restituir primeiro ano morrer tranqüilamente metodicamente ouvir soluço damas fala baixo homem chuva tamborila folha tinhor chácara som estrídulo navalha amolador afiar porta correeiro jurolhes orquestra morte triste parecer certo chegar delicioso vida estrebuchavame peit ...

# %% [markdown]
# Vamos criar um dataframe com o texto processado

# %%
data_dict = {'clean': txt}
df_clean = pd.DataFrame(data_dict)
df_clean = df_clean.dropna().drop_duplicates()
df_clean.shape
# Out:
# (1, 1)

# %%
# !pip install gensim
from gensim.models.phrases import Phrases, Phraser
# Out:
# Collecting gensim
#   Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.6.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim) (2.1.2)
# Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (27.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 63.1 MB/s eta 0:00:00
# Installing collected packages: gensim
# Successfully installed gensim-4.4.0

# %%
sent = [row.split() for row in df_clean['clean']]
sent
# Out:
# [['romancer',
#   'memória',
#   'póstuma',
#   'brás',
#   'cuba',
#   'memória',
#   'póstuma',
#   'brás',
#   'cuba',
#   'textofonte',
#   'obra',
#   'completo',
#   'machar',
#   'assi',
#   'rio',
#   'janeiro',
#   'editora',
#   'aguilar',
#   'publicar',
#   'originalmente',
#   'folhetim',
#   'março',
#   'revista',
#   'brasileiro',
#   'verme',
#   'roeu',
#   'fria',
#   'carne',
#   'cadáver',
#   'dedico',
#   'saudoso',
#   'lembrança',
#   'memória',
#   'póstuma',
#   'prólogo',
#   'edição',
#   'edição',
#   'de',
#   'este',
#   'memória',
#   'póstuma',
#   'brás',
#   'cuba',
#   'fazer',
#   'pedaço',
#   'revista',
#   'brasileira',
#   'ano',
#   'posta',
#   'livro',
#   'corrigi',
#   'texto',
#   'lugar',
#   'rever',
#   'edição',
#   'emendei',
#   'algum',
#   'suprimi',
#   'dúzia',
#   'linha',
#   'composta',
#   'sair',
#   'novamente',
#   'luz',
#   'obra',
#   'algum',
#   'benevolência',
#   'encontrar',
#   'público',
#   'capistrano',
#   'abrer',
#   'noticiar',
#   'publicação',
#   'livro',
#   'perguntar',
#   'memória',
#   'póstuma',
#   'brás',
#   'cuba',
#   'romance',
#   'macedo',
#   'Soares',
#   'carta',
#   'escrever',
#   'recordar',
#   'amigamente',
#   'viagem',
#   'terra',
#   'responder',
#   'defunto',
#   'brás',
#   'cuba',
#   'leitor',
#   'ver',
#   'ver',
#   'prólogo',
#   'de',
#   'ele',
#   'adiante',
#   'romance',
#   'explicar',
#   'finar',
#   'tratase',
#   'obra',
#   'difuso',
#   'brás',
#   'cuba',
#   'adotar',
#   'livre',
#   'sterne',
#   'xavier',
#   'maistre',
#   'metir',
#   'rabugem',
#   'pessimismo',
#   'gente',
#   'viajar',
#   'xavier',
#   'maistre',
#   'roda',
#   'garretr',
#   'terra',
#   'de',
#   'ele',
#   'sterne',
#   'terra',
#   'brás',
#   'cuba',
#   'viajar',
#   'roda',
#   'vida',
#   'brás',
#   'cuba',
#   'autor',
#   'particular',
#   'chamar',
#   'rabugem',
#   'pessimismo',
#   'haver',
#   'alma',
#   'livro',
#   'risonho',
#   'parecer',
#   'sentimento',
#   'amargo',
#   'ásperer',
#   'vir',
#   'modelo',
#   'taço',
#   'lavor',
#   'igual',
#   'escola',
#   'levar',
#   'outro',
#   'vinho',
#   'dizer',
#   'entrar',
#   'crítica',
#   'defunto',
#   'pintar',
#   'se',
#   'conforme',
#   'parecer',
#   'melhor',
#   'certo',
#   'machado',
#   'assi',
#   'leitor',
#   'stendhalr',
#   'confessar',
#   'haver',
#   'escrito',
#   'livro',
#   'cem',
#   'leitor',
#   'admira',
#   'consternar',
#   'admirar',
#   'provavelmente',
#   'consternar',
#   'outro',
#   'livro',
#   'ter',
#   'cem',
#   'leitor',
#   'stendhal',
#   'cinqüentar',
#   'tratase',
#   'verdade',
#   'obra',
#   'difuso',
#   'brás',
#   'cuba',
#   'adotar',
#   'livre',
#   'sterne',
#   'xavier',
#   'maistre',
#   'metir',
#   'rabugem',
#   'pessimismo',
#   'obra',
#   'finar',
#   'escrever',
#   'pena',
#   'galhofa',
#   'tinta',
#   'melancolia',
#   'difícil',
#   'antever',
#   'sair',
#   'conúbio',
#   'acrescer',
#   'gente',
#   'grave',
#   'achar',
#   'livro',
#   'aparência',
#   'puro',
#   'romance',
#   'passo',
#   'gente',
#   'frívolo',
#   'achar',
#   'em',
#   'ele',
#   'romance',
#   'usual',
#   'eilo',
#   'ficar',
#   'privado',
#   'estima',
#   'grave',
#   'amor',
#   'frívolo',
#   'coluna',
#   'máxima',
#   'opinião',
#   'esperar',
#   'angariar',
#   'simpatia',
#   'opinião',
#   'remédio',
#   'fugir',
#   'prólogo',
#   'explícito',
#   'longo',
#   'bom',
#   'prólogo',
#   'contémr',
#   'coisa',
#   'jeito',
#   'obscuro',
#   'truncar',
#   'conseguintemente',
#   'evito',
#   'contar',
#   'processo',
#   'extraordinário',
#   'empreguei',
#   'composição',
#   'de',
#   'este',
#   'memória',
#   'trabalhar',
#   'outro',
#   'mundo',
#   'curioso',
#   'nimiamente',
#   'extenso',
#   'aliás',
#   'desnecessário',
#   'entendimento',
#   'obra',
#   'obra',
#   'si',
#   'mesmo',
#   'agradar',
#   'fino',
#   'leitor',
#   'pagomer',
#   'tarefa',
#   'agradar',
#   'pagote',
#   'piparote',
#   'brás',
#   'cuba',
#   'capítulo',
#   'óbito',
#   'autor',
#   'algum',
#   'hesitar',
#   'dever',
#   'abrir',
#   'memória',
#   'princípio',
#   'porer',
#   'nascimento',
#   'morte',
#   'suposto',
#   'uso',
#   'vulgar',
#   'ser',
#   'começar',
#   'nascimento',
#   'consideração',
#   'levar',
#   'adotar',
#   'diferente',
#   'método',
#   'propriamente',
#   'autor',
#   'defunto',
#   'defunto',
#   'autor',
#   'campa',
#   'outro',
#   'berço',
#   'escrito',
#   'ficar',
#   'galante',
#   'moisés',
#   'contar',
#   'morte',
#   'pôr',
#   'intróito',
#   'cabo',
#   'diferença',
#   'radical',
#   'livro',
#   'pentateuco',
#   'dizer',
#   'expirei',
#   'hora',
#   'sextafeira',
#   'agosto',
#   'belo',
#   'chácar',
#   'catumbi',
#   'ter',
#   'sessenta',
#   'ano',
#   'rijo',
#   'próspero',
#   'solteiro',
#   'possuir',
#   'cerca',
#   'trezento',
#   'conto',
#   'acompanhar',
#   'cemitério',
#   'amigo',
#   'amigo',
#   'verdade',
#   'haver',
#   'carta',
#   'anúncio',
#   'acrescer',
#   'chover',
#   'peneirar',
#   'chuvinha',
#   'miúda',
#   'tristar',
#   'constante',
#   'constante',
#   'triste',
#   'levar',
#   'de',
#   'aquele',
#   'fiel',
#   'último',
#   'hora',
#   'intercalar',
#   'engenhoso',
#   'idéia',
#   'discurso',
#   'proferir',
#   'beira',
#   'cova',
#   'conheceste',
#   'senhor',
#   'podel',
#   'comigo',
#   'natureza',
#   'chorar',
#   'perda',
#   'irreparável',
#   'belo',
#   'caracter',
#   'honrar',
#   'humanidade',
#   'ar',
#   'sombrio',
#   'gota',
#   'céu',
#   'nuvem',
#   'escura',
#   'cobr',
#   'azul',
#   'crepe',
#   'funéreo',
#   'dor',
#   'cruo',
#   'má',
#   'rói',
#   'natureza',
#   'íntima',
#   'entranho',
#   'sublime',
#   'louvor',
#   'ilustre',
#   'finar',
#   'fiel',
#   'amigo',
#   'arreper',
#   'apólice',
#   'deixeir',
#   'cheguei',
#   'cláusula',
#   'dia',
#   'encaminhei',
#   'undiscovered',
#   'country',
#   'hamlet',
#   'ânsia',
#   'dúvida',
#   'moço',
#   'príncipe',
#   'pausar',
#   'trôpegar',
#   'retirar',
#   'espetáculo',
#   'aborrecir',
#   'viramme',
#   'pessoa',
#   'senhora',
#   'irmã',
#   'sabina',
#   'casado',
#   'cotrim',
#   'filha',
#   'lírio',
#   'vale',
#   'ter',
#   'paciência',
#   'de',
#   'aqui',
#   'eles',
#   'dir',
#   'senhora',
#   'contentemse',
#   'anônimo',
#   'parentar',
#   'padecer',
#   'parenta',
#   'verdade',
#   'padecer',
#   'dizer',
#   'carpir',
#   'dizer',
#   'deixar',
#   'rolar',
#   'chão',
#   'convulsa',
#   'óbito',
#   'altamente',
#   'dramático',
#   'solteir',
#   'expirar',
#   'sessenta',
#   'ano',
#   'reúnar',
#   'se',
#   'elemento',
#   'tragédia',
#   'dar',
#   'convinhar',
#   'anônimo',
#   'aparentálo',
#   'pé',
#   'cabeceira',
#   'cama',
#   'olho',
#   'estúpir',
#   'boca',
#   'entreabertar',
#   'triste',
#   'senhora',
#   'crer',
#   'extinção',
#   'morrer',
#   'morto',
#   'dizer',
#   'com',
#   'si',
#   'imaginação',
#   'de',
#   'ela',
#   'cegonha',
#   'ilustre',
#   'viajante',
#   'ver',
#   'desferir',
#   'vôo',
#   'ilisso',
#   'riba',
#   'africana',
#   'embargo',
#   'ruína',
#   'tempo',
#   'imaginação',
#   'senhora',
#   'voar',
#   'destroço',
#   'presente',
#   'riba',
#   'áfrica',
#   'juvenil',
#   'deixála',
#   'ir',
#   'ir',
#   'restituir',
#   'primeiro',
#   'ano',
#   'morrer',
#   'tranqüilamente',
#   'metodicamente',
#   'ouvir',
#   'soluço',
#   'damas',
#   'fala',
#   'baixo',
#   'homem',
#   'chuva',
#   'tamborila',
#   'folha',
#   'tinhor',
#   'chácara',
#   'som',
#   'estrídulo',
#   'navalha',
#   'amolador',
#   'afiar',
#   'porta',
#   'correeiro',
#   'jurolhes',
#   'orquestra',
#   'morte',
#   'triste',
#   'parecer',
#   'certo',
#   'chegar',
#   'delicioso',
#   'vida',
#   'estrebuchavame',
#   'peito',
#   'ímpeto',
#   'vago',
#   'marinho',
#   'esvaíaseme',
#   'consciência',
#   'descer',
#   'imobilidade',
#   'físico',
#   'moral',
#   'corpo',
#   'faziaseme',
#   'planto',
#   'pedra',
#   'lodo',
#   'morri',
#   'pneumonia',
#   'disser',
#   'pneumonia',
#   'idéia',
#   'grandioso',
#   'útil',
#   'causa',
#   'morte',
#   'leitor',
#   'creio',
#   'todavia',
#   'verdade',
#   'vou',
#   'exporlhe',
#   'sumariamente',
#   'caso',
#   'Julgueo',
#   'si',
#   'capítulo',
#   'ii',
#   'emplasto',
#   'efeito',
#   'dia',
#   'manhã',
#   'estar',
#   'passear',
#   'chácaro',
#   'pendurouseme',
#   'idéia',
#   'trapézio',
#   'ter',
#   'cérebro',
#   'pendurar',
#   'entrar',
#   'bracejar',
#   'pernear',
#   'arrojar',
#   'cabriola',
#   'volatim',
#   'crer',
#   'deixeime',
#   'contemplála',
#   'súbito',
#   'dar',
#   'salto',
#   'estender',
#   'braço',
#   'perna',
#   'tomar',
#   'x',
#   'deciframe',
#   'devorotir',
#   'idéia',
#   'invenção',
#   'medicamento',
#   'sublime',
#   'emplastro',
#   'antihipocondríaco',
#   'destinar',
#   'aliviar',
#   'melancólico',
#   'humanidade',
#   'petição',
#   'privilégio',
#   'redigi',
#   'chameir',
#   'atenção',
#   'governo',
#   'resultado',
#   'verdadeiramente',
#   'cristão',
#   'todavia',
#   'neguei',
#   'amigo',
#   'vantagem',
#   'pecuniário',
#   'dever',
#   'resultar',
#   'distribuição',
#   'produto',
#   'tamanho',
#   'profundo',
#   'efeito',
#   'outro',
#   'vida',
#   'confessar',
#   'influir',
#   'principalmente',
#   'gosto',
#   'impressa',
#   'jornal',
#   'mostrador',
#   'folheto',
#   'esquino',
#   'enfim',
#   'caixinha',
#   'remédio',
#   'palavra',
#   'emplasto',
#   'brás',
#   'cuba',
#   'negálo',
#   'ter',
#   'paixão',
#   'arruído',
#   'cartaz',
#   'foguete',
#   'lágrima',
#   'modesto',
#   'argúam',
#   'defeito',
#   'fio',
#   'talento',
#   'hão',
#   'reconhecer',
#   'hábel',
#   'idéia',
#   'trazer',
#   'face',
#   'medalha',
#   'virado',
#   'público',
#   'eu',
#   'filantropia',
#   'lucro',
#   'outro',
#   'sede',
#   'nomeada',
#   'dizer',
#   'amor',
#   'glória',
#   'tio',
#   'cônego',
#   'prebenda',
#   'inteira',
#   'costumar',
#   'amor',
#   'glória',
#   'temporal',
#   'perdição',
#   'alma',
#   'cobiçar',
#   'glória',
#   'eterno',
#   'retorquiar',
#   'outro',
#   'tio',
#   'oficial',
#   'antigo',
#   'terço',
#   'infantaria',
#   'amor',
#   'glória',
#   'verdadeiramente',
#   'humano',
#   'haver',
#   'homem',
#   'conseguintemente',
#   'genuíno',
#   'feição',
#   'decidar',
#   'leitor',
#   'militar',
#   'cônego',
#   'voltar',
#   'emplasto',
#   'capítulo',
#   'iii',
#   'genealogia',
#   'falar',
#   'tio',
#   'deixemme',
#   'curto',
#   'esboço',
#   'genealógico',
#   'fundador',
#   'família',
#   'certo',
#   'damião',
#   'cuba',
#   'florescer',
#   'metade',
#   'século',
#   'xviii',
#   'tanoeiro',
#   'ofício',
#   'natural',
#   'Rio',
#   'janeiro',
#   'ter',
#   'morrer',
#   'penúria',
#   'obscuridade',
#   'exercer',
#   'tanoaria',
#   'fezser',
#   'lavrador',
#   'plantar',
#   'colheu',
#   'permutar',
#   'produto',
#   'bom',
#   'honrada',
#   'pataco',
#   'morrer',
#   'deixar',
#   'grosso',
#   'cabedal',
#   'filho',
#   'licenciado',
#   'Luís',
#   'cuba',
#   'rapaz',
#   'verdadeiramente',
#   'começar',
#   'série',
#   'avós',
#   'avós',
#   'família',
#   'confessar',
#   'damião',
#   'cuba',
#   'afinal',
#   'conta',
#   'tanoeiro',
#   'mau',
#   'tanoeiro',
#   'passo',
#   'Luís',
#   'cubas',
#   'estudar',
#   'coimbra',
#   'primar',
#   'amigo',
#   'particular',
#   'vicerei',
#   'conde',
#   'cunha',
#   'apelido',
#   'cuba',
#   'cheirar',
#   'excessivamente',
#   'tanoaria',
#   'alegar',
#   'pai',
#   'bisneto',
#   'damião',
#   'dizer',
#   'apelido',
#   'dar',
#   'cavaleiro',
#   'herói',
#   'jornada',
#   'áfrica',
#   'prêmio',
#   'façanha',
#   'praticar',
#   'arrebatar',
#   'trezenta',
#   'cuba',
#   'mouro',
#   'pai',
#   'homem',
#   'imaginação',
#   'escapar',
#   'tanoaria',
#   'asa',
#   'calembour',
#   'caráter',
#   'pai',
#   'var',
#   'digno',
#   'leal',
#   'pouco',
#   'ter',
#   'verdade',
#   'fumos',
#   'pacholice',
#   'pachola',
#   'mundo',
#   'relever',
#   'notar',
#   'recorrer',
#   'inventiva',
#   'senão',
#   'experimentar',
#   'falsificação',
#   'primeiramente',
#   'entroncouse',
#   'família',
#   'famoso',
#   'homônimo',
#   'capitãomor',
#   'brás',
#   'cuba',
#   'fundar',
#   'vila',
#   'vicente',
#   'morrer',
#   'motivo',
#   'dar',
#   'nome',
#   'brás',
#   'opôsselhe',
#   'família',
#   'capitãomor',
#   'imaginar',
#   'trezenta',
#   'cuba',
#   'mourisco',
#   'viver',
#   'membro',
#   'família',
#   'sobrinho',
#   'venância',
#   'lírio',
#   'vale',
#   'flor',
#   'dama',
#   'viver',
#   'pai',
#   'cotrim',
#   'sujeito',
#   'anteciper',
#   'sucesso',
#   'acabemo',
#   'emplasto',
#   'capítulo',
#   'iv',
#   'idéia',
#   'fixo',
#   'idéia',
#   'tanto',
#   'cabriola',
#   'constituírase',
#   'idéia',
#   'fixo',
#   'Deus',
#   'livre',
#   'leitor',
#   'idéia',
#   'fixo',
#   'argueiro',
#   'trave',
#   'olho',
#   'ver',
#   'cavour',
#   'idéia',
#   'fixo',
#   'unidade',
#   'italiano',
#   'matar',
#   'verdade',
#   'bismarck',
#   'morrer',
#   'cumprir',
#   'advertir',
#   'natureza',
#   'caprichoso',
#   'história',
#   'eterno',
#   'loureira',
#   'suetônio',
#   'deuno',
#   'cláudio',
#   'simplório',
#   'abóbora',
#   'chamar',
#   'sêneca',
#   'tito',
#   'merecer',
#   'delícia',
#   'roma',
#   'vir',
#   'modernamente',
#   'professor',
#   'achar',
#   'demonstrar',
#   'césar',
#   'delicioso',
#   'verdadeiro',
#   'delicioso',
#   'abóbora',
#   'sêneca',
#   'madama',
#   'lucrécia',
#   'flor',
#   'bórgia',
#   'poeta',
#   'pintar',
#   'messalina',
#   'católico',
#   'aparecer',
#   'gregorovius',
#   'incrédulo',
#   'apagar',
#   'qualidade',
#   'viestar',
#   'lírio',
#   'ficaste',
#   'pântano',
#   'deixomer',
#   'poeta',
#   'sábio',
#   'viver',
#   'história',
#   'volúvel',
#   'histório',
#   'tornar',
#   'idéia',
#   'fixo',
#   'dirar',
#   'varão',
#   'forte',
#   'doir',
#   'idéia',
#   'móbil',
#   'vago',
#   'furtacor',
#   'cláudio',
#   'fórmula',
#   'suetônio',
#   'fixo',
#   'idéia',
#   'fixo',
#   'ocorrer',
#   'ser',
#   'assaz',
#   'fixo',
#   ...]]

# %% [markdown]
# Vamos processar o texto para considerar bigramas. Esta etapa é importante para identificar palavras compostas como "Brás Cubas"

# %%
phrases = Phrases(sent,min_count=1, progress_per=10)

# %%
bigram = Phraser(phrases)
sentences = bigram[sent]
sentences

# %% [markdown]
# Vamos também ver quais as palavras mais frequentes no texto após remover stop-words

# %%
word_freq = defaultdict(int)
for sent in sentences:
    for i in sent:
        word_freq[i] += 1
len(word_freq)
# Out:
# 8863

# %%
sorted(word_freq, key=word_freq.get, reverse=True)[:10]
# Out:
# ['dizer',
#  'capítulo',
#  'ter',
#  'haver',
#  'ser',
#  'homem',
#  'ir',
#  'olho',
#  'algum',
#  'dia']

# %% [markdown]
# #Treinando um modelo Word2Vec
#
# Vamos agora treinar um modelo para retornar as palavras mais próximas dado o contexto da escrita deste conto de machado de assis.
#
# Word2Vec():
# Nesta primeira etapa, configuramos os parâmetros do modelo.
#
# .build_vocab():
# Aqui construímos o vocabulário a partir de uma sequência de frases e assim inicializamos o modelo.
#
# .Train():
# Finalmente, treinamos o modelo.

# %%
import multiprocessing

from gensim.models import Word2Vec
cores = multiprocessing.cpu_count()

# %% [markdown]
# #Estes são os parâmetros do modelo segundo a referência da bilbioteca Gensim:
#
# *   min_count = int - Ignores all words with total absolute frequency lower than this - (2, 100)
# *   window = int - The maximum distance between the current and predicted word within a sentence. E.g. window words on the left and window words on the left of our target - (2, 10)
# *   size = int - Dimensionality of the feature vectors. - (50, 300)
# *   sample = float - The threshold for configuring which higher-frequency words are randomly downsampled. Highly influencial. - (0, 1e-5)
# *   alpha = float - The initial learning rate - (0.01, 0.05)
# *   min_alpha = float - Learning rate will linearly drop to min_alpha as training progresses. To set it: alpha - (min_alpha * epochs) ~ 0.00
# *   negative = int - If > 0, negative sampling will be used, the int for negative specifies how many "noise words" should be drown. If set to 0, no negative sampling is used. - (5, 20)
# *  workers = int - Use these many worker threads to train the model (=faster training with multicore machines)

# %%
w2v_model = Word2Vec(min_count=3,
                     window=5,
                     vector_size=300, # Changed 'size' to 'vector_size'
                     sample=1e-3,
                     alpha=0.03,
                     min_alpha=0.0007,
                     negative=20,
                     workers=cores-1)
t = time()

#Vamos contruir o vocabulário
w2v_model.build_vocab(sentences)

print('Time to build vocab: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# Time to build vocab: 0.0 mins

# %%
t = time()

w2v_model.train(sentences, total_examples=w2v_model.corpus_count, epochs=20, report_delay=1)

print('Time to train the model: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# Time to train the model: 0.03 mins

# %%
w2v_model.init_sims(replace=True)
# Out:
# /tmp/ipykernel_4872/514372312.py:1: DeprecationWarning: Call to deprecated `init_sims` (Gensim 4.0.0 implemented internal optimizations that make calls to init_sims() unnecessary. init_sims() is now obsoleted and will be completely removed in future versions. See https://github.com/RaRe-Technologies/gensim/wiki/Migrating-from-Gensim-3.x-to-4).
#   w2v_model.init_sims(replace=True)
# WARNING:gensim.models.keyedvectors:destructive init_sims(replace=True) deprecated & no longer required for space-efficiency

# %% [markdown]
# #Vamos agora verificar a similaridade entre algumas palavras

# %%
w2v_model.wv.most_similar(positive=["brás_cuba"]) # Changed 'brás' to 'brás_cuba'
# Out:
# [('virgílio_brás', 0.9996685981750488),
#  ('cuba_virgílio', 0.9996451735496521),
#  ('memória_póstuma', 0.9995756149291992),
#  ('roda', 0.9994513392448425),
#  ('rabugem_pessimismo', 0.9994375705718994),
#  ('romance', 0.9994351267814636),
#  ('obra', 0.9994292259216309),
#  ('terra', 0.9994085431098938),
#  ('finar', 0.9993581175804138),
#  ('edição', 0.9993481636047363)]

# %%
w2v_model.wv.most_similar(negative=["homem"])
# Out:
# [('inconsolável', 0.14875826239585876),
#  ('fundar_jornal', 0.10504307597875595),
#  ('principal', 0.09932701289653778),
#  ('lampião', 0.09322147071361542),
#  ('cidadão', 0.09214811027050018),
#  ('obstar', 0.08900155872106552),
#  ('coitar_d', 0.0850195661187172),
#  ('flor_antanho', 0.08160509169101715),
#  ('revolução', 0.08128489553928375),
#  ('alienista', 0.08048118650913239)]

# %% [markdown]
# #Exercício 1
#
# Agora que você já apredeu a como processar textos e verificar a similaridade entre palavras, verifique quais parâmetros podem de fato alterar os resultdos do modelo. Como podemos melhorar os resultados? E se combinarmos mais de um texto? Qual o resultado?
#
# #Desafio:
# Como podemos fazer analogias com as palavras pesquisadas? Ex: mulher + brás - homem = ?
