# %% [markdown]
# <a href="https://colab.research.google.com/github/dipucriodigital/ciencia-de-dados-e-analytics/blob/main/advanced-analytics/word2vec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Similaridade de palavras em contexto - Word2Vec
#
# Neste exercício vamos calcular a similaridade entre palavras dado um contexto apresentado. Neste caso, vamos analisar textos de machado de assis e ver quais termos aparecem mais próximo dado o contexto da narrativa.
#
# Para isso vamos utilizar 3 bibliotecas para processamento de texto: NLTK, Spacy e Gensim.
#
# *Adaptadado de: https://www.kaggle.com/code/pierremegret/gensim-word2vec-tutorial/notebook

# %%
import re  # For preprocessing
import pandas as pd  # For data handling
from time import time  # To time our operations
from collections import defaultdict  # For word frequency

import spacy  # For preprocessing

import logging  # Setting up the loggings to monitor gensim
logging.basicConfig(format="%(levelname)s - %(asctime)s: %(message)s", datefmt= '%H:%M:%S', level=logging.INFO)

# %% [markdown]
# Vamos fazer o download do pipeline para processamento de texto em português da Spacy.

# %%
# !python3 -m spacy download pt_core_news_sm
from spacy.lang.pt.examples import sentences
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pt-core-news-sm==3.4.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/pt_core_news_sm-3.4.0/pt_core_news_sm-3.4.0-py3-none-any.whl (13.0 MB)
#      |████████████████████████████████| 13.0 MB 19.7 MB/s
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in /usr/local/lib/python3.8/dist-packages (from pt-core-news-sm==3.4.0) (3.4.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (0.10.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (21.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (2.0.7)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (0.9.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (3.3.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (1.0.9)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (2.0.8)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (1.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (2.23.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (2.4.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (2.11.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (3.0.10)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (1.21.6)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (0.7.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (1.10.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (57.4.0)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (8.1.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (3.0.8)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (4.64.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from pathy>=0.3.5->spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (5.2.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (4.1.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (1.24.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (0.0.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (2.0.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_sm')

# %% [markdown]
# Vamos fazer o download da base de texto das obras de machado de assis. (incluso na nltk)

# %%
import nltk
nltk.download('machado')
from nltk.corpus import machado

machado.fileids()
# Out:
# [nltk_data] Downloading package machado to /root/nltk_data...
# [nltk_data]   Package machado is already up-to-date!
# ['contos/macn001.txt',
#  'contos/macn002.txt',
#  'contos/macn003.txt',
#  'contos/macn004.txt',
#  'contos/macn005.txt',
#  'contos/macn006.txt',
#  'contos/macn007.txt',
#  'contos/macn008.txt',
#  'contos/macn009.txt',
#  'contos/macn010.txt',
#  'contos/macn011.txt',
#  'contos/macn012.txt',
#  'contos/macn013.txt',
#  'contos/macn014.txt',
#  'contos/macn015.txt',
#  'contos/macn016.txt',
#  'contos/macn017.txt',
#  'contos/macn018.txt',
#  'contos/macn019.txt',
#  'contos/macn020.txt',
#  'contos/macn021.txt',
#  'contos/macn022.txt',
#  'contos/macn023.txt',
#  'contos/macn024.txt',
#  'contos/macn025.txt',
#  'contos/macn026.txt',
#  'contos/macn027.txt',
#  'contos/macn028.txt',
#  'contos/macn029.txt',
#  'contos/macn030.txt',
#  'contos/macn031.txt',
#  'contos/macn032.txt',
#  'contos/macn033.txt',
#  'contos/macn034.txt',
#  'contos/macn035.txt',
#  'contos/macn036.txt',
#  'contos/macn037.txt',
#  'contos/macn038.txt',
#  'contos/macn039.txt',
#  'contos/macn040.txt',
#  'contos/macn041.txt',
#  'contos/macn042.txt',
#  'contos/macn043.txt',
#  'contos/macn044.txt',
#  'contos/macn045.txt',
#  'contos/macn046.txt',
#  'contos/macn047.txt',
#  'contos/macn048.txt',
#  'contos/macn049.txt',
#  'contos/macn050.txt',
#  'contos/macn051.txt',
#  'contos/macn052.txt',
#  'contos/macn053.txt',
#  'contos/macn054.txt',
#  'contos/macn055.txt',
#  'contos/macn056.txt',
#  'contos/macn057.txt',
#  'contos/macn058.txt',
#  'contos/macn059.txt',
#  'contos/macn060.txt',
#  'contos/macn061.txt',
#  'contos/macn062.txt',
#  'contos/macn063.txt',
#  'contos/macn064.txt',
#  'contos/macn065.txt',
#  'contos/macn066.txt',
#  'contos/macn067.txt',
#  'contos/macn068.txt',
#  'contos/macn069.txt',
#  'contos/macn070.txt',
#  'contos/macn071.txt',
#  'contos/macn072.txt',
#  'contos/macn073.txt',
#  'contos/macn074.txt',
#  'contos/macn075.txt',
#  'contos/macn076.txt',
#  'contos/macn077.txt',
#  'contos/macn078.txt',
#  'contos/macn079.txt',
#  'contos/macn080.txt',
#  'contos/macn081.txt',
#  'contos/macn082.txt',
#  'contos/macn083.txt',
#  'contos/macn084.txt',
#  'contos/macn085.txt',
#  'contos/macn086.txt',
#  'contos/macn087.txt',
#  'contos/macn088.txt',
#  'contos/macn089.txt',
#  'contos/macn090.txt',
#  'contos/macn091.txt',
#  'contos/macn092.txt',
#  'contos/macn093.txt',
#  'contos/macn094.txt',
#  'contos/macn095.txt',
#  'contos/macn096.txt',
#  'contos/macn097.txt',
#  'contos/macn098.txt',
#  'contos/macn099.txt',
#  'contos/macn100.txt',
#  'contos/macn101.txt',
#  'contos/macn102.txt',
#  'contos/macn103.txt',
#  'contos/macn104.txt',
#  'contos/macn105.txt',
#  'contos/macn106.txt',
#  'contos/macn107.txt',
#  'contos/macn108.txt',
#  'contos/macn109.txt',
#  'contos/macn110.txt',
#  'contos/macn111.txt',
#  'contos/macn112.txt',
#  'contos/macn113.txt',
#  'contos/macn114.txt',
#  'contos/macn115.txt',
#  'contos/macn116.txt',
#  'contos/macn117.txt',
#  'contos/macn118.txt',
#  'contos/macn119.txt',
#  'contos/macn120.txt',
#  'contos/macn121.txt',
#  'contos/macn122.txt',
#  'contos/macn123.txt',
#  'contos/macn124.txt',
#  'contos/macn125.txt',
#  'contos/macn126.txt',
#  'contos/macn127.txt',
#  'contos/macn128.txt',
#  'contos/macn129.txt',
#  'contos/macn130.txt',
#  'contos/macn131.txt',
#  'contos/macn132.txt',
#  'contos/macn133.txt',
#  'contos/macn134.txt',
#  'contos/macn135.txt',
#  'contos/macn136.txt',
#  'contos/macn137.txt',
#  'critica/mact01.txt',
#  'critica/mact02.txt',
#  'critica/mact03.txt',
#  'critica/mact04.txt',
#  'critica/mact05.txt',
#  'critica/mact06.txt',
#  'critica/mact07.txt',
#  'critica/mact08.txt',
#  'critica/mact09.txt',
#  'critica/mact10.txt',
#  'critica/mact11.txt',
#  'critica/mact12.txt',
#  'critica/mact13.txt',
#  'critica/mact14.txt',
#  'critica/mact15.txt',
#  'critica/mact16.txt',
#  'critica/mact17.txt',
#  'critica/mact18.txt',
#  'critica/mact19.txt',
#  'critica/mact20.txt',
#  'critica/mact21.txt',
#  'critica/mact22.txt',
#  'critica/mact23.txt',
#  'critica/mact24.txt',
#  'critica/mact25.txt',
#  'critica/mact26.txt',
#  'critica/mact27.txt',
#  'critica/mact28.txt',
#  'critica/mact29.txt',
#  'critica/mact30.txt',
#  'critica/mact31.txt',
#  'critica/mact32.txt',
#  'critica/mact33.txt',
#  'critica/mact34.txt',
#  'critica/mact35.txt',
#  'critica/mact36.txt',
#  'critica/mact37.txt',
#  'critica/mact38.txt',
#  'critica/mact39.txt',
#  'critica/mact40.txt',
#  'critica/mact41.txt',
#  'critica/mact42.txt',
#  'critica/mact43.txt',
#  'critica/mact44.txt',
#  'critica/mact45.txt',
#  'cronica/macr01.txt',
#  'cronica/macr02.txt',
#  'cronica/macr03.txt',
#  'cronica/macr04.txt',
#  'cronica/macr05.txt',
#  'cronica/macr06.txt',
#  'cronica/macr07.txt',
#  'cronica/macr08.txt',
#  'cronica/macr09.txt',
#  'cronica/macr10.txt',
#  'cronica/macr11.txt',
#  'cronica/macr12.txt',
#  'cronica/macr13.txt',
#  'cronica/macr14.txt',
#  'cronica/macr15.txt',
#  'cronica/macr16.txt',
#  'cronica/macr17.txt',
#  'cronica/macr18.txt',
#  'cronica/macr19.txt',
#  'cronica/macr20.txt',
#  'cronica/macr21.txt',
#  'cronica/macr22.txt',
#  'cronica/macr23.txt',
#  'cronica/macr24.txt',
#  'miscelanea/mams01.txt',
#  'miscelanea/mams02.txt',
#  'miscelanea/mams03.txt',
#  'miscelanea/mams04.txt',
#  'miscelanea/mams05.txt',
#  'miscelanea/mams06.txt',
#  'miscelanea/mams07.txt',
#  'miscelanea/mams08.txt',
#  'miscelanea/mams09.txt',
#  'miscelanea/mams10.txt',
#  'poesia/maps01.txt',
#  'poesia/maps02.txt',
#  'poesia/maps03.txt',
#  'poesia/maps04.txt',
#  'poesia/maps05.txt',
#  'poesia/maps06.txt',
#  'poesia/maps07.txt',
#  'romance/marm01.txt',
#  'romance/marm02.txt',
#  'romance/marm03.txt',
#  'romance/marm04.txt',
#  'romance/marm05.txt',
#  'romance/marm06.txt',
#  'romance/marm07.txt',
#  'romance/marm08.txt',
#  'romance/marm09.txt',
#  'romance/marm10.txt',
#  'teatro/matt01.txt',
#  'teatro/matt02.txt',
#  'teatro/matt03.txt',
#  'teatro/matt04.txt',
#  'teatro/matt05.txt',
#  'teatro/matt06.txt',
#  'teatro/matt07.txt',
#  'teatro/matt08.txt',
#  'teatro/matt09.txt',
#  'teatro/matt10.txt',
#  'traducao/matr01.txt',
#  'traducao/matr02.txt',
#  'traducao/matr03.txt']

# %% [markdown]
# Antes de começarmos a análise precisamos extrair caracteres não alfa-numéricos, stop-words e reduzir as palavras ao seu radical. Isto é uma etapa essencial no pré-processamento de dados.

# %%
raw_text = machado.raw('romance/marm05.txt') #memórias bras cubas

spacy.cli.download("pt_core_news_sm")
nlp = spacy.load('pt_core_news_sm', disable=['ner', 'parser']) # disabling Named Entity Recognition for speed

def cleaning(doc):
    # Lemmatizes and removes stopwords
    # doc needs to be a spacy Doc object
    txt = [token.lemma_ for token in doc if not token.is_stop]
    # Word2Vec uses context words to learn the vector representation of a target word,
    # if a sentence is only one or two words long,
    # the benefit for the training is very small
    if len(txt) > 2:
        return ' '.join(txt)

new_str = re.sub(r'[^\w\s]', '', raw_text).lower() #remover caracteres não-alfa numéricos
t = time()
doc = nlp(new_str)
txt = cleaning(doc)

print('Time to clean up everything: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_sm')
# Time to clean up everything: 0.06 mins

# %%
txt = txt.split('\n')
txt
# Out:
# ['romancer memória póstum brás cuba 1880 ',
#  '',
#  ' memória póstum ',
#  ' brá cuba ',
#  '',
#  ' textofonte ',
#  ' obra completo machado ',
#  ' assi ',
#  ' rio ',
#  ' janeiro editora aguilar 1994 ',
#  '',
#  ' publicar originalmente ',
#  ' folhetim março 1880 revista brasileiro ',
#  '',
#  ' verme ',
#  ' ',
#  ' roeu fria ',
#  ' carne ',
#  ' cadáver ',
#  '',
#  ' dedico ',
#  ' saudoso lembrança ',
#  '',
#  ' ',
#  ' memória ',
#  ' póstuma ',
#  '',
#  ' prólogo ',
#  ' edição ',
#  '',
#  ' edição de este ',
#  ' memória póstum brá cuba fazer pedaço revista ',
#  ' brasileira ano 1880 posta livro corrigi texto ',
#  ' lugar rever edição emendei ',
#  ' algum suprimi dúzia linha composta sair ',
#  ' novamente luz obra algum benevolência encontrar ',
#  ' público ',
#  '',
#  ' capistrano abrer noticiar ',
#  ' publicação livro perguntar memória póstum brás cuba ',
#  ' romance Macedo Soares carta escrever recordar ',
#  ' amigamente viagem terra responder defunto ',
#  ' brás cuba leitor ver ver prólogo de ele adiante ',
#  ' romancer ',
#  ' explicar finado tratase obra difuso brás ',
#  ' cuba adotar livre sterne xavier maistre ',
#  ' metir rabugem pessimismo gente viajar xavier ',
#  ' maistre roda garretr terra de ele sterne terra ',
#  ' brá cuba viajar roda vida ',
#  '',
#  ' brás cuba ',
#  ' autor particular chamar rabugem pessimismo haver alma ',
#  ' livro risonho parecer sentimento amargo áspero ',
#  ' vir modelo taça lavor igual escola ',
#  ' levar outro vinho dizer entrar crítica defunto ',
#  ' pintar se conforme parecer bom certo ',
#  '',
#  ' machado assi ',
#  '',
#  ' leitor ',
#  '',
#  ' stendhal confessar haver ',
#  ' escrito livro cem leitor admira consterno ',
#  ' admirar provavelmente consternar outro livro ter ',
#  ' cem leitor stendhal cinqüentar ',
#  ' tratase verdade obra difuso brás cuba ',
#  ' adotar livre sterne xavier maistre ',
#  ' meti rabugem pessimismo obra finar escrever ',
#  ' pena galhofa tinta melancolia difícil antever ',
#  ' sair conúbio acrescer gente grave achar livro aparência ',
#  ' puro romance passo gente frívolo achar em ele romance usual ',
#  ' eilo ficar privado estima grave amor frívolo ',
#  ' coluna máximo opinião ',
#  '',
#  ' esperar angariar ',
#  ' simpatia opinião remédio fugir prólogo explícito ',
#  ' longo bom prólogo contémr coisa jeito ',
#  ' obscuro truncar conseguintemente evito contar processo extraordinário ',
#  ' empreguei composição de este memória trabalhar outro mundo ',
#  ' curioso nimiamente extenso aliás desnecessário entendimento ',
#  ' obra obra si mesmo agradar fino leitor pagome tarefa ',
#  ' agradar pagote piparote ',
#  '',
#  ' brá cuba ',
#  '',
#  ' capítulo   óbito ',
#  ' autor ',
#  '',
#  ' algum hesitar dever abrir ',
#  ' memória princípio por ',
#  ' nascimento morte suposto uso vulgar ser começar ',
#  ' nascimento consideração levar adotar diferente método ',
#  ' propriamente autor defunto defunto autor ',
#  ' campa outro berço escrito ficar galante ',
#  ' moisés contar morte pôr intróito ',
#  ' cabo diferença radical livro pentateuco ',
#  '',
#  ' dizer expirar hora ',
#  ' sextafeira agosto 1869 belo chácar ',
#  ' catumbi ter sessento ano rijo próspero solteiro ',
#  ' possuir cerca trezento conto acompanhar cemitério ',
#  ' amigo amigo verdade haver carta anúncio acrescer ',
#  ' chover   peneirar chuvinha miúdo triste constante constante ',
#  ' triste levar de aquele fiel último hora intercalar engenhoso ',
#  ' idéia discurso proferir beira cova   conheceste ',
#  ' senhor podeis comigo natureza chorar ',
#  ' perda irreparável belo caracter honrar humanidade ',
#  ' ar sombrio gota céu nuvem escura cobr azul ',
#  ' crepe funéreo dor cruo má rói natureza ',
#  ' íntimas entranha sublime louvor ilustre finado ',
#  '',
#  ' fiel amigo ',
#  ' arreper apólice deixeir cheguei cláusula ',
#  ' dia encaminhar undiscovered ',
#  ' country hamlet ânsia dúvida moço príncipe ',
#  ' pausar trôpegar retirar espetáculo aborrecer ',
#  ' viramme pessoa senhora irmã ',
#  ' sabina casado cotrim filha   lírio vale   ter ',
#  ' paciência de aqui eles dir senhora Contentemse ',
#  ' anônimo parentar padecer parenta ',
#  ' verdade padecer dizer carpir dizer deixar ',
#  ' rolar chão convulsa óbito altamente dramático ',
#  ' solteir expirar sessenzer ano reúnar si ',
#  ' elemento tragédia dar convinha ',
#  ' anônimo aparentálo pé cabeceira cama olho estúpir ',
#  ' boca entreaberto triste senhora crer extinção ',
#  '',
#  '  morrer matar dizer consigo ',
#  '',
#  ' imaginação de ela ',
#  ' cegonha ilustre viajante ver desferir vôo ilisso riba ',
#  ' africana embargo ruína tempo   imaginação senhora ',
#  ' voar destroço presente riba áfrica ',
#  ' juvenil deixála ir ir restituir ',
#  ' primeiro ano morrer tranqüilamente metodicamente ouvir ',
#  ' soluço dama fala baixo homem chuva tamborila ',
#  ' folha tinhorão chácara som estrídulo navalha amolador ',
#  ' afiar porta Correeiro jurolhe orquestra ',
#  ' morte triste parecer certo ',
#  ' chegar delicioso vida estrebuchavame peito ímpeto vaga ',
#  ' marinh esvaíaseme consciência descer imobilidade físico moral ',
#  ' corpo faziaseme planta pedra lodo ',
#  '',
#  ' morri pneumonia ',
#  ' disser pneumonia idéia grandioso útil causa ',
#  ' morte leitor crei todavia verdade ir ',
#  ' exporlhe sumariamente caso julgueo si ',
#  '',
#  ' capítulo ii   ',
#  ' emplasto ',
#  '',
#  ' efeito dia manhã ',
#  ' estar passear chácaro pendurouseme idéia trapézio ter ',
#  ' cérebro pendurar entrar bracejar pernear ',
#  ' arrojar cabriola volatim crer deixeime ',
#  ' contemplála súbito dar salto estender braço perna ',
#  ' tomar x deciframe devorotir ',
#  '',
#  ' idéia ',
#  ' invenção medicamento sublime emplastro antihipocondríaco destinar ',
#  ' aliviar melancólico humanidade petição privilégio ',
#  ' redigi chameir atenção governo resultado verdadeiramente ',
#  ' cristão todavia neguei amigo vantagem pecuniário dever ',
#  ' resultar distribuição produto tamanho profundo efeito ',
#  ' outro vida confessar ',
#  ' influir principalmente gosto impressa jornal mostrador ',
#  ' folheto esquino enfim caixinha remédio palavra ',
#  ' emplasto brás cuba negálo ter paixão arruído ',
#  ' cartaz foguete lágrima modesto argúam defeito fio ',
#  ' talento hão reconhecer hábel idéia ',
#  ' trazer face medalha virada público eu ',
#  ' filantropia lucro outro sede nomeada dizer   amor ',
#  ' glória ',
#  '',
#  ' tio cônego prebenda ',
#  ' inteirar costumar amor glória temporal perdição alma ',
#  ' cobiçar glória eterno retorquiar outro tio oficial ',
#  ' antigo terço infantaria amor glória ',
#  ' verdadeiramente humano haver homem conseguintemente genuíno ',
#  ' feição ',
#  '',
#  ' decer leitor militar ',
#  ' cônego voltar emplasto ',
#  '',
#  ' capítulo iii ',
#  ' genealogiar ',
#  '',
#  '  falar ',
#  ' tio deixemme curto esboço genealógico ',
#  '',
#  ' fundador família ',
#  ' certo damião cuba florescer metade século xviii ',
#  ' tanoeiro ofício natural Rio Janeiro ter morrer penúria ',
#  ' obscuridade exercer tanoaria fezser lavrador ',
#  ' plantar colheu permutar produto boa honrada pataco ',
#  ' morrer deixar grosso cabedal filho licenciado Luís cuba rapaz ',
#  ' verdadeiramente começar série avós   avós família ',
#  ' confessar   damião cubas afinal conta tanoeiro ',
#  ' mau tanoeiro passo Luís cubas estudar coimbra primar ',
#  ' amigo particular vicerei conde cunha ',
#  '',
#  ' apelido cuba ',
#  ' cheirar excessivamente tanoaria alegar pai bisneto damião ',
#  ' dizer apelir dar cavaleiro herói jornada África prêmio ',
#  ' façanha praticar arrebatar trezenta cuba mouro pai ',
#  ' homem imaginação escapar tanoaria asa calembour ',
#  ' caráter pai var digno leal pouco ter verdade ',
#  ' fumos pacholice pachola mundo releva notar ',
#  ' recorrer inventiva senão experimentar falsificação ',
#  ' primeiramente entroncouse família famoso homônimo ',
#  ' capitãomor brás cuba fundar vila vicente morrer 1592 ',
#  ' motivo dar nome brás opôsselher família ',
#  ' capitãomor imaginar trezenta cuba mourisco ',
#  '',
#  ' viver membro ',
#  ' família sobrinho venância lírio vale ',
#  ' flor dama viver pai cotrim sujeito ',
#  ' anteciper sucesso acabemos emplasto ',
#  '',
#  ' capítulo iv   idéia ',
#  ' fixo ',
#  '',
#  ' idéia tanto ',
#  ' cabriolo constituírase idéia fixo deus livre leitor idéia fixo ',
#  ' argueiro trave olho ver cavour idéia fixo ',
#  ' unidade italiano matar verdade bismarck morrer cumprir ',
#  ' advertir natureza caprichoso história eterno ',
#  ' loureira suetônio deuno cláudio simplório   ',
#  ' abóbora chamar sêneca tito merecer delícia ',
#  ' roma vir modernamente professor achar demonstrar ',
#  ' césar delicioso verdadeiro delicioso abóbora sêneca ',
#  ' madama lucrécia flor bórgia poeta pintar messalina ',
#  ' católica aparecer gregorovius incrédulo apagar qualidade ',
#  ' viestar lírio ficaste pântano deixomer ',
#  ' poeta sábio ',
#  '',
#  ' viver história volúvel ',
#  ' história tornar idéia fixo direi ',
#  ' varão forte doido idéia móbil vaga furtacor ',
#  ' cláudio   fórmula suetônio ',
#  '',
#  ' fixo idéia fixo ',
#  ' ocorrer ser assaz fixo mundo lua ',
#  ' pirâmide egito finada dieta germânico leitor ',
#  ' comparação melhor quadrar vejaa estar de aí torcerme nariz ',
#  ' chegar narrativo de este memória ir crer ',
#  ' preferir anedota reflexão leitor confrade ',
#  ' achar ir todavia importa livro ',
#  ' escrito pachorra pachorra homem desafrontar brevidade ',
#  ' século obra supinamente filosófico filosofia desigual austera ',
#  ' brincalhonar edifica destrói inflamar regalar ',
#  ' todavia passatempo apostolado ',
#  '',
#  ' ir retifiquer nariz ',
#  ' tornemos emplasto deixar história capricho dama ',
#  ' elegante nenhum pelejar batalha salamina nenhum escrever ',
#  ' confissão augsburgo algum lembro cromwell ',
#  ' idéia alteza mesmo mão trancar parlamento ',
#  ' ter impor inglês emplasto brás cuba r vitória ',
#  ' comum farmácia puritanismo pé bandeira ',
#  ' pública ostensivo haver muitas várias bandeira modestamente ',
#  ' particular hastear flutuar sombra pouco ',
#  ' sobreviver comparar arraiamiúda acolhiar sombra ',
#  ' castelo feudal cair arraia ficar verdade graúda ',
#  ' castelã comparação prestar ',
#  '',
#  ' capítulo v   aparecer ',
#  ' orelha senhora ',
#  '',
#  ' senão estar ocupar ',
#  ' preparar apurar invenção recebi cheio golpe ar adoeci ',
#  ' tratar ter emplasto cérebro trazer comigo idéia fixo ',
#  ' doido forte viame ascender chão turba ',
#  ' remontar céu águia imortal excelso ',
#  ' espetáculo homem sentir dor punge outro dia mau ',
#  ' trateime enfim incompletamente método cuidado persistência ',
#  ' origem trazer eternidade saber morrir ',
#  ' sextafeira dia aziago crer haver provar invenção ',
#  ' matar haver demonstração lúcida triunfante ',
#  '',
#  ' impossível entretanto ',
#  ' chegar galgar cimo século figurar folha público ',
#  ' macróbio ter saúde robustez suponhase ',
#  ' lançar alicerce invenção farmacêutico tratar coligir ',
#  ' elemento instituição político reforma religioso vir ',
#  ' ar vencer eficácia cálculo humano ir ',
#  ' correr sorte homem ',
#  '',
#  ' reflexão despedi ',
#  ' mulher dir discreto formoso ',
#  ' contemporânea anônimo capítulo imaginação ',
#  ' semelhança cegonha ilisso ter 54 ano ruína ',
#  ' imponente ruína imagine leitor ama ano ',
#  ' dia enfermo vejoar assomar porta alcova ',
#  '',
#  ' capítulo ver   chimène qui ',
#  ' leût dit rodrigue qui leût cru ',
#  '',
#  ' vejoar assomar porta alcova ',
#  ' pálida comover trajada preto ficar durante minuto ânimo ',
#  ' entrar deter presença homem comigo cama ',
#  ' jazer contempleia durante esquecer ',
#  ' nenhum gesto haver ano ver viaar ',
#  ' fôramos ezequia misterioso fizera ',
#  ' recuar sol dia juvenis recuar sol sacudi miséria ',
#  ' punhar pó morte ir espalhar eternidade ',
#  ' ministro morte água juventa igualario ',
#  ' simples saudade ',
#  '',
#  ' creiammer mau recordar ',
#  ' ninguém fie felicidade presente haver em ele gota baba caim corrir ',
#  ' cessar espasmo gozar deveras ',
#  ' de esse ilusão melhor gostar doer ',
#  '',
#  ' durar evocação ',
#  ' realidade dominar presente expelir passado exponha ',
#  ' leitor algum canto livro teoria edição humano ',
#  ' importar virgílier   chamavase virgílio   entrar alcova ',
#  ' firme gravidade dar roupa ano vir ',
#  ' leito estranho levantouse sair sujeito visitar ',
#  ' dia falar câmbio colonização necessidade desenvolver ',
#  ' viação férreo interessante moribundo sair virgílio ',
#  ' deixouse pé durante algum ficar olhar outro ',
#  ' articular palavra dir namorado paixão ',
#  ' freio haver ano haver coração ',
#  ' murcho devastar vida saciar de ela igual dose ',
#  ' enfim saciar virgília ter beleza velhice ar austero ',
#  ' maternal magro ver último festa ',
#  ' João tijuca resistar começar ',
#  ' cabelo escuro intercalarse fio prata ',
#  '',
#  '  andar visitar defunto ',
#  ' disselhe   defunto responder Virgília muxoxo ',
#  ' apertar mão   ar ponho vadio rua ',
#  '',
#  ' ter carícia lacrimoso ',
#  ' outro voz amigo doce sentouse casa ',
#  ' simples enfermeiro poder falar outro perigo Virgília deume ',
#  ' longo notícia narrandoa graça certo travo má língua ',
#  ' sal palestra prestes deixar mundo sent prazer ',
#  ' satânico mofar de ele persuadirme deixar ',
#  '',
#  '  idéia interrompeume ',
#  ' virgíliar zangar olhar voltar morrer haver ',
#  ' morrer bastar estar vivo ',
#  '',
#  ' ver relógio ',
#  '',
#  '  jesus hora voume ',
#  ' ',
#  '',
#  '  ',
#  '',
#  '  virar amanhã ',
#  '',
#  '  retorqui ',
#  ' doente solteir casa senhora ',
#  '',
#  '  mano ',
#  '',
#  '  haver vir passar dia ',
#  ' sábado ',
#  '',
#  ' Virgília refletir instante ',
#  ' levantar ombro dizer gravidade ',
#  '',
#  '  velho ninguém reparar ',
#  ' eu cortar dúvida virar nhonhô ',
#  '',
#  ' nhonhô bacharel único ',
#  ' filho casamento idade ano cúmplice inconsciente ',
#  ' amor vir junto dia confessar vêlo ',
#  ' alcova tomar acanhamento permitir ',
#  ' corresponder palavra afável rapaz virgília adivinhoume dizer ',
#  ' filho ',
#  '',
#  '  nhonhô repar ',
#  ' manhoso falar crer morte ',
#  '',
#  ' sorrir filho crer ',
#  ' sorri acabar pura galhofa virgílio serena risonhar ',
#  ' ter aspecto vida imacular nenhum olhar suspeito nenhum gesto ',
#  ' poder denunciar igualdade palavra espírito dominação ',
#  ' si mesmo parecer ser raro tocásser ',
#  ' casualmente amor ilegítimos secreto divulgar via falar ',
#  ' desdém indignação mulher tratar aliás ',
#  ' amiga filho sentiase satisfeito ouvir palavra digno forte ',
#  ' perguntar eu diriar gavião buffon ter nascer ',
#  ' gavião ',
#  '',
#  ' delírio começar ',
#  '',
#  ' capítulo vii   ',
#  ' delírio ',
#  '',
#  ' ce onste ninguém ',
#  ' relatar delírio façoor ciência mo agradecer leitor ',
#  ' dar contemplação de este fenômeno mental saltar capítulo ir ',
#  ' direito narração curioso ser dizer ',
#  ' interessante passar cabeça durante trinto ',
#  ' minuto ',
#  '',
#  ' primeiramente tomeir figura ',
#  ' barbeiro chinês bojudo destro escanhoar mandarim pagar ',
#  ' trabalho beliscão confeito capricho mandarim ',
#  '',
#  ' sentime transformar ',
#  ' suma teológico tomás impresso volume encadernar ',
#  ' marroquim fecho prata estampa idéia dar corpo ',
#  ' completo imobilidade lembrar ser mão ',
#  ' fecho livro cruzandoa ventre alguém descruzar virgílio ',
#  ' decerto atitude dar imagem defunto ',
#  '',
#  ' ultimamente restituir ',
#  ' humana ver chegar hipopótamo arrebatar deixeime calar ',
#  ' medo confiança carreira modo tornar ',
#  ' vertiginoso atrevi interrogálo algum arte dizer ',
#  ' viagem parecer destino ',
#  '',
#  '  enganase replicar animal ',
#  ' ir origem século ',
#  '',
#  ' insinuei dever ',
#  ' muitíssimo hipopótamo entender ouvir ',
#  ' fingir de esse coisa perguntandolhe ver falar ',
#  ' descendente cavalo aquile asna balaão retorquiume gesto ',
#  ' peculiar quadrúpede abanar orelha fechar ',
#  ' olho deixeime ventura confessar senzet ',
#  ' cócega curiosidade ficar origem ',
#  ' século misterioso origem nilo sobretudo valer ',
#  ' algum consumação mesmo século reflexão ',
#  ' cérebro enfermo ir olho fechar ver lembrame ',
#  ' sensação frio aumentar jornada chegar ocasião ',
#  ' parecer entrar região gelo eterno efeito abri olho ver ',
#  ' animal galopar planície branco neve animal ',
#  ' never never chegar gelarno sol neve falar ',
#  ' pude grunhirr pergunta ansioso ',
#  '',
#  '  estar ',
#  '',
#  '  passar éden ',
#  '',
#  '  paremo tenda abraão ',
#  '',
#  '  caminhamos trás ',
#  ' redargüiu motejar cavalgadura ',
#  '',
#  ' fiquei vexar aturder ',
#  ' jornada entrar parecerme enfadonha extravagante frio incômodo ',
#  ' condução violento resultado impalpável   cogitação enfermo ',
#  ' dar chegássemo indicado impossível século ',
#  ' irritar eles devassar origem esmagar unha dever ',
#  ' secular pensar íamos devorar ',
#  ' planície voar pé animal estacar pude olhar ',
#  ' tranqüilamente torno eu olhar ver imenso ',
#  ' brancura neve invadiro céu azul ',
#  ' espaço parecer planta enorme brutesca menear vento ',
#  ' larga folho silêncio região igual sepulcro ',
#  ' disserase vida coisa ficara estúpido homem ',
#  '',
#  ' cair ar destacouse terra ',
#  ' vulto imenso figura mulher aparecer ',
#  ' fitandome olho rutilante sol figura ter vastidão ',
#  ' forma selvático escapar compreensão olhar humano ',
#  ' contorno perdiamse ambiente parecer espesso muito diáfano ',
#  ' estupefato dizer chegueir sequer soltar grito cabo ',
#  ' algum perguntar chamar curiosidade ',
#  ' delírio ',
#  '',
#  '  chamame natureza pandora ',
#  ' mãe inimigo ',
#  '',
#  ' ouvir último palavra ',
#  ' recuei tomar susto figura soltar gargalhada produziu ',
#  ' torno efeito tufão planta torceramse longo gemido ',
#  ' quebrar mudez coisa externo ',
#  '',
#  '  assuste dizer ',
#  ' inimizade matar sobretudo vida afirmar vive ',
#  ' outro flagelo ',
#  '',
#  '  vivo perguntar enterrar ',
#  ' unha mão certificarme existência ',
#  '',
#  '  verme viver ',
#  ' receie perder andrajo orgulho provarás ',
#  ' hora pão dor vinho miséria vives ensandeceste ',
#  ' vive consciência reouver instante sagacidade dirás ',
#  ' quer viver ',
#  '',
#  ' dizer visão estender ',
#  ' braço seguroume cabelo levantoumir ar pluma ',
#  ' pude verlhe rosto enorme ',
#  ' contorção violento expressão ódio ferocidade feição único ',
#  ' completo impassibilidade egoísta eterna surdez ',
#  ' vontade imóvel raivo ter ficar encerrado coração ',
#  ' rosto expressão glacial haver ar Juventude mescla ',
#  ' força viço sent débil decrépito ser ',
#  '',
#  '  entendesteme dizer ',
#  ' algum mútuo contemplação ',
#  '',
#  '  responder ',
#  ' entenderte absurda fábula sonhar decerto ',
#  ' verdade enlouqueci passa concepção alienar ',
#  ' vã razão ausente reger palpar natureza ',
#  ' natureza conhecer mãe inimiga vida flagelo ',
#  ' trazer rosto indiferente sepulcro pandorar ',
#  '',
#  '  levar bolsa ',
#  ' bem mal esperança consolação homem treme ',
#  '',
#  '  olhar fasciname ',
#  '',
#  '  crer ',
#  ' vida morte prestes devolverme emprestei ',
#  ' lascivo esperater voluptuosidade ',
#  '',
#  ' palavra ecoar ',
#  ' trovão imenso vale afigurouseme som chegar ',
#  ' ouvir pareceume sentir decomposição súbito eu ',
#  ' encareia olho súplice pedir ano ',
#  '',
#  '  pobre minuto exclamar ',
#  ' quer instante vida devorar sere devorar ',
#  ' fartar espetáculo luta conhece sobejo ',
#  ' depar torpe aflitivo alvor dia melancolia ',
#  ' quietação noite aspecto terra sono enfim benefício ',
#  ' mão quer sublime idiota ',
#  '',
#  '  viver peçar ',
#  ' pôr coração amor vida senão amar vida ',
#  ' hás golpear ti mesmo matandome ',
#  '',
#  '  preciso ti ',
#  ' importar minuto passar minuto minuto ',
#  ' forte jucundo supor trazer se eternidade trazer morte perecer ',
#  ' outro subsiste egoísmo diz egoísmo ',
#  ' lei egoísmo conservação onça matar novilho raciocínio onça ',
#  ' viver novilho tenro bom eis estatuto ',
#  ' universal subir olhar ',
#  '',
#  ' dizer arrebatoume alto ',
#  ' montanha inclinei olho vertente contemplei durante ',
#  ' largo nevoeiro único imaginar ',
#  ' leitor redução século desfilar raça ',
#  ' paixão tumulto império guerra apetite ódio ',
#  ' destruição recíproco ser coisa espetáculo acerbo ',
#  ' curioso espetáculo história homem terra ter intensidade ',
#  ' poder imaginação ciência ciência ',
#  ' lento imaginação vago ver condensação ',
#  ' viver tempo descrevêla preciso fixar relâmpago ',
#  ' século desfilar turbilhão obstante olho delírio ',
#  ' ver passar eu flagelo delício ',
#  ' chamar glór chamar misério ver ',
#  ' amor multiplicar miséria ver miséria agravar debilidade ',
#  ' vinhar cobiça devorar cólera inflamar inveja baba enxada ',
#  ' pena úmir suor ambição fome vaidade melancolia ',
#  ' riqueza amor agitar homem chocalho destruílo ',
#  ' farrapo ser forma várias morder víscera ',
#  ' mordia pensamento passear eternamente veste arlequim ',
#  ' derredor espécie humano dor cedia algum ceder indiferença ',
#  ' sono sonho prazer dor bastarda homem ',
#  ' flagelar rebelde correr fatalidade coisa figura ',
#  ' nebulosa esquivo fazer retalho retalho impalpável outro ',
#  ' improvável outro invisível cosido precário agulha ',
#  ' imaginação figura   quimera felicidade   ',
#  ' fugir perpetuamente deixavase apanhar fralda homem cingia ',
#  ' peito r escárnio sumiase ilusão ',
#  '',
#  ' contemplar calamidade ',
#  ' pude reter grito angústia natureza pandora escutar ',
#  ' protestar rir lei transtorno cerebral ',
#  ' pus rir   riso descompassar idiota ',
#  '',
#  '  razão dizer ',
#  ' divertido valer pena   monótonar   valer pena jó ',
#  ' amaldiçoar dia concebido dar gana ',
#  ' espetáculo ir pandora abrir ventre digereme ',
#  ' divertido digereme ',
#  '',
#  ' resposta compelirme ',
#  ' fortemente olhar século continuar passar ',
#  ' veloz turbulento geração superpunhar geração triste ',
#  ' hebreu cativeiro alegre devasso cômodo ',
#  ' pontual sepultura querer fugir força misterioso ',
#  ' retinhar pé dizer comigo   século passar chegar ',
#  ' passar dar decifração eternidade ',
#  ' fixei olho continuei idade vir chegar passar ',
#  ' tranqüilo resoluto alegre alegre século ',
#  ' trazer porção sombra luz apatia combate verdade ',
#  ' erro cortejo sistema idéia ilusão ',
#  ' de ele rebentar verdura primavera amarelecar ',
#  ' remoçar passo vida ter regularidade ',
#  ' calendário faziase história civilização homem nu desarmar ',
#  ' armavase vestiase construir tugúrio paláciar rude aldeia teba ',
#  ' cem porta criar ciência perscruta arte enlever faziase ',
#  ' orador mecânico filósofo correr face globo descia ventre terra ',
#  ' suber esfera nuvem colaborar obra misterioso ',
#  ' entreter necessidade vida melancolia desamparo olhar ',
#  ' enfarar distrair ver enfim chegar século presente de ele ',
#  ' futuro vir ágil destro vibrante cheio se difuso ',
#  ' audaz sabedor cabo miserável primeiro passar ',
#  ' passar mesmo rapidez igual monotonia redobrar ',
#  ' atenção fitar vista ir enfim   ',
#  ' rapidez marcha escapar compreensão pé de ela ',
#  ' relâmpago século entrar objeto trocaremse ',
#  ' crescer minguar perderamse ambiente nevoeiro ',
#  ' cobrir   hipopótamo trouxerar aliás começar ',
#  ' diminuir diminuir diminuir ficar tamanho gato ',
#  ' efetivamente gato encareio gato sultão brincar ',
#  ' porta alcova bola papel ',
#  '',
#  ' capítulo viii   razão ',
#  ' sandice ',
#  '',
#  ' leitor compreender ',
#  ' razão voltar casa convidar sandice sair clamar bom ',
#  ' jus palavra tartufo ',
#  '',
#  ' la Maison est moi cest vous ',
#  ' den sortir ',
#  '',
#  ' sestro antigo sandice ',
#  ' criar amor casa alheia modo senhora dificilmente ',
#  ' lha fazer despejar sestro tirar de aí haver calejar ',
#  ' vergonha advertirr imenso casa ocupar ',
#  ' durante estação calmoso concluiremo amável ',
#  ' peregrina terror proprietário caso haver quase distúrbio ',
#  ' porta cérebro adventícia querer entregar casa dona ',
#  ' cedir intenção tomar afinal sandice contentar ',
#  ' cantinho sótão ',
#  '',
#  '  senhor replicar razão ',
#  ' cansada ceder sótão cansar experimentar ',
#  ' passar mansamente sótão sala jantar de aí visita resto ',
#  '',
#  '  deixeme ficar algum ',
#  ' pista mistério ',
#  '',
#  '  mistério ',
#  '',
#  '  emendar sandice ',
#  ' vida morte peçolhe minuto ',
#  '',
#  ' razão pôr rir ',
#  '',
#  '  hás mesmo ',
#  ' mesmo mesmo ',
#  '',
#  ' dizer travoulhe ',
#  ' pulso arrastoua entrar fechousar sandice gemeu ',
#  ' súplica grunhiu zanga desenganouse depressa deitar ',
#  ' língua ar surriada andar ',
#  '',
#  ' capítulo ix ',
#  ' transição ',
#  '',
#  ' vejam destreza ',
#  ' arte transição livro vejar delírio começar ',
#  ' presença Virgília virgília grão pecar juventude haver ',
#  ' juventude meninice meninice supor nascimento eis chegar ',
#  ' esforço dia 20 outubro 1805 nascer ver juntura ',
#  ' aparente divirtar atenção pausar leitor modo ',
#  ' livro ficar vantagem método rigidez método ',
#  ' verdade método ser indispensável ',
#  ' todavia bom têlo gravata suspensório fresca ',
#  ' soltar vizinho fronteira inspetor ',
#  ' quarteirão eloqüência haver genuína vibrante arte ',
#  ' natural feiticeira tesa engomar chochar ir dia 20 ',
#  ' outubro ',
#  '',
#  ' capítulo x   ',
#  ' dia ',
#  '',
#  ' dia árvore cuba ',
#  ' brotar gracioso flor nascer recebeume braço pascoela insigne ',
#  ' parteira minhota gabar abrir porta mundo geração ',
#  ' inteirar fidalgo impossível pai ouvir declaração ',
#  ' crer todavia sentimento paterno induziu gratificála ',
#  ' meias dobr lavar enfaixar herói casa ',
#  ' prognosticar respeito quadrar sabor tio ',
#  ' João antigo oficial infantaria achavame certo olhar bonaparte ',
#  ' pai ouvir náuseo tio ildefonso simples ',
#  ' padre farejavame cônegar ',
#  '',
#  '  cônegar haver ',
#  ' dizer parecer orgulho admirar deus ',
#  ' destinar bispado verdade bispado impossível ',
#  ' manor bento ',
#  '',
#  ' pai responder ',
#  ' deus quiser alçavame ar intentasse mostrarme ',
#  ' cidade mundo perguntar parecer ',
#  ' inteligente bonito ',
#  '',
#  ' dizer coisa alto ',
#  ' ouvir narrar ano ignoro mor pormenor ',
#  ' famoso dia vizinhança vir mandar cumprimentar recémnascido ',
#  ' durante primeiro semana muito visita casa ',
#  ' haver cadeirinha trabalhar aventouse muito casaca calção ',
#  ' conto mimos beijo admiração bênção ',
#  ' contar acabar capítulo preciso acabálo ',
#  '',
#  ' item ',
#  ' batizar referir respeito ',
#  ' galharda festa ano seguinte 1806 batizeime igreja ',
#  ' domingo terçafeira março dia claro luminoso puro ser padrinho ',
#  ' coronel Rodrigues Matos senhora outro descendir velha ',
#  ' família norte honrar deveras sangue eles correr veia outrora ',
#  ' derramar guerra holanda cuir nome ',
#  ' primeiro coisa aprender dizer muito graça revelar ',
#  ' algum talento precoce haver pessoa estranho ',
#  ' obrigar recitálo ',
#  '',
#  '  nhonhô diga senhor ',
#  ' chamar padrinho ',
#  '',
#  '  padrinho excelentíssimo ',
#  ' senhor coronel Paulo vaz lobo césar Andrade Sousa Rodrigues Matos ',
#  ' madrinha excelentíssima senhor d Maria Luísa Macedo Resende Sousa ',
#  ' Rodrigues Matos ',
#  '',
#  '  esperto menino ',
#  ' exclamar ouvinte ',
#  '',
#  '  esperto concordar ',
#  ' pai olho babavamselhe orgulho espalmar mão ',
#  ' cabeça fitavamer longo namorar cheio si ',
#  '',
#  ' item começar andar ',
#  ' apressar natureza obrigavamme ',
#  ' agarrar cadeira pegavamme fralda davamme carrinho pau   ',
#  ' nhonhô diziame mucama atrair chocalho lata ',
#  ' mãe agitar eu ir frente cair cair acolá andar ',
#  ' provavelmente andar fiquei andar ',
#  '',
#  ' capítulo xi   menino pai ',
#  ' homem ',
#  '',
#  ' crescir em isso família ',
#  ' intervir cresci naturalmente crescer magnólia gato ',
#  ' gato matreiro magnólia inquieta ',
#  ' infância poeta dizer menino pai homem ',
#  ' verdade veja lineamento menino ',
#  '',
#  ' ano merecerar ',
#  ' alcunha menino diabo verdadeiramente ',
#  ' maligno arguto indiscreto traquina voluntarioso ',
#  ' dia quebrar cabeça escrar negar colher ',
#  ' doce coco fazer contente malefício deitar ',
#  ' punhado cinza tacho satisfeito travessura ',
#  ' mãe escrar estragarar doce pirraça ter ',
#  ' ano prudênciar moleque casa cavalo dias punha ',
#  ' mão chão receber cordel queixo guisa freio trepavalhar ',
#  ' dorso varinha mão fustigavao dar volta outro ',
#  ' obedecer   gemer   obedecia palavra ',
#  '   ai nhonhô   retorquiar   calar boca besta ',
#  '  esconder chapéu visita deitar rabo papel pessoa grave puxar ',
#  ' rabicho cabeleira beliscão braço matrona ',
#  ' muito façanha jaez ser mostra gênio indócil dever crer ',
#  ' ser expressão espírito robusto pai tinhame ',
#  ' admiração repreendiar vista gente faziao simples ',
#  ' formalidade particular davame beijo ',
#  '',
#  ' concluar de aqui ',
#  ' levar resto vida quebrar cabeça ',
#  ' esconderlhe chapéu opiniático egoísta contemptor homem ',
#  ' passar esconderlhe chapéu algum eles ',
#  ' puxei rabicho cabeleiro ',
#  '',
#  ' outrossim afeiçoeime ',
#  ' contemplação injustiça humano inclineime atenuála explicála ',
#  ' classifiqueia parte entendêla padrão rígir ',
#  ' sabor circunstância lugar mãe doutrinavamer modo faziame ',
#  ' decorar preceito oração sentir oração ',
#  ' governar nervo sangue regra perder espírito ',
#  ' viver tornar vã fórmula manhã mingau noite ',
#  ' cama pedir deu perdoar perdoar ',
#  ' devedor manhã noite maldade pai ',
#  ' passado alvoroço davame pancadinha cara exclamar rir ah ',
#  ' brejeiro ah brejeirer ',
#  '',
#  ' pai adoravame mãe ',
#  ' senhora fraco cérebro coração assaz crédula ',
#  ' sinceramente piedoso   caseira apesar bonito modesto apesar ',
#  ' abastar temente trovoada marido marido terra deu ',
#  ' colaboração de esse criatura nascer educação ter algum ',
#  ' vicioso incompleta parte negativo tio ',
#  ' cônegar reparo irmão dizialhe dar ',
#  ' liberdade ensino afeição emendar pai responder ',
#  ' aplicar educação inteiramente alto usar ',
#  ' modo confundir irmão iludiase se ',
#  '',
#  ' envolta transmissão ',
#  ' educação haver estranho doméstico vir pai ',
#  ' vejamos tio de ele João homem língua soltar vida galante ',
#  ' conversa picaresco ano entrar admitirme anedota real ',
#  ' eivar obscenidade imundície respeitar ',
#  ' adolescência respeitar batina irmão diferença ',
#  ' fugir enveredar assunto escabroso deixavame ',
#  ' entender princípio entender enfim achandolhe graça ',
#  ' certo procurar gostar eu davame ',
#  ' doce levavame passeio casa ir passar dia pouco ',
#  ' acontecer achálo fundo chácara lavadouro palestrar ',
#  ' escrava bater roupa desfiar anedota dito ',
#  ' pergunta estalar risada ninguém ouvir lavadouro ',
#  ' ficar casa preta tanga ventre arregaçarlhe ',
#  ' palmo vestido tanque inclinar ',
#  ' peça roupa batêla ensaboála torcêla ir ouvir ',
#  ' redargüir pilhéria tio João comentála ',
#  ' palavra ',
#  '',
#  '  Cruz diabo sinhô João ',
#  ' diabo ',
#  '',
#  ' diferente tio cônegar ',
#  ' ter muito austeridade pe ureze dote realçar ',
#  ' espírito alto compensar espírito medíocre homem ',
#  ' vir substancial igreja ver externo hierarquia ',
#  ' preeminência sobrepeliz circunflexão vir sacristia ',
#  ' altar lacuna ritual excitavao infração ',
#  ' mandamento tanto ano distância certo poder ',
#  ' atinar facilmente trecho tertuliano expor titubear ',
#  ' história símbolo nicéia ninguém festa cantadas saber melhor ',
#  ' caso cortesia dever oficiante cônegar único ',
#  ' ambição vida dizer coração dignidade ',
#  ' aspirar piedoso severo costume minucioso observância regra ',
#  ' frouxo acanhar subalterno possuir virtude exemplar ',
#  ' carecia absolutamente força incutir impor ',
#  '',
#  ' dizer tia ',
#  ' materna d emerenciana aliás pessoa autoridade ter ',
#  ' eu diferençavase grandemente viver ',
#  ' companhia ano parente íntimo merecer pena ',
#  ' citar vida comum intermitente claro ',
#  ' separação importar expressão doméstico ficar ',
#  ' indicar   vulgaridade caracter amor aparência rutilante ',
#  ' arruído frouxidão vontade domínio capricho terra ',
#  ' estrume nascer flor ',
#  '',
#  ' capítulo xii   episódio ',
#  ' 1814 ',
#  '',
#  ' passar adiante ',
#  ' contar sumariamente galante episódio 1814 ter ano ',
#  '',
#  ' napoleão nascer ',
#  ' esplendor glória imperador granjear ',
#  ' inteiramente admiração homem pai força persuadir ',
#  ' nobreza acabar persuadindose se nutria ódio ',
#  ' puramente mental motivo renhida contenr casa ',
#  ' tio João espírito classe simpatia ofício perdoar ',
#  ' déspota admirar general tio padre inflexível ',
#  ' corsar parente dividiamse de aí controvérsia rusga ',
#  '',
#  ' chegar rio janeiro ',
#  ' notícia queda napoleão haver naturalmente abalar ',
#  ' casa nenhum chasco remoquar vencido testemunha regozijo ',
#  ' público julgar decoroso silêncio bater palma ',
#  ' população cordialmente alegre regatear demonstração afeto real ',
#  ' família haver iluminação salvo tedeum cortejo aclamação ',
#  ' figurei em esse dia espadim padrinho dera dia ',
#  ' santo antônio francamente interessavamer espadim queda ',
#  ' bonaparte esquecer fenômeno deixei pensar comigo ',
#  ' espadim espar napoleão noter ',
#  ' ouvir discurso vivo li muito página rumoroso idéia ',
#  ' grande palavra fundo aplauso arrancar ',
#  ' boca ecoar alguma conceito experimentar ',
#  '',
#  '  vaiter cuir ',
#  ' espadim ',
#  '',
#  ' contentar família ',
#  ' quinhão anônimo regozijo público entender oportuno indispensável ',
#  ' celebrar destituição imperador jantar jantar ruído ',
#  ' aclamação chegar ouvido alteza ',
#  ' ministros dizer fazer vir abaixo velho prataria herdar avô ',
#  ' Luís cuba vir toalha flandr jarra índia matouse ',
#  ' capado encomendaramse madr ajudar compota marmelada ',
#  ' lavaramse arearamse poliramse sala escadas castiçal arandela ',
#  ' vasta manga vidro aparelho luxo clássico ',
#  '',
#  ' dar hora achousar reunir ',
#  ' sociedade seleto juizdefora oficial militar ',
#  ' comerciante letrado funcionário administração ',
#  ' mulher filha comungar desejo atolar ',
#  ' memória bonaparte papo peru jantar ',
#  ' tedeum dizer letrado presente ',
#  ' dr vilaça glosador insigne acrescentar prato casa acepipe ',
#  ' muso lembramer ser lembramer erguerse ',
#  ' longo cabeleira rabicho casaca seda esmeralda dedo pedir ',
#  ' tio padre repetir mote repetir mote cravar olho testa ',
#  ' senhora tossir alçar mão fechada dedo ',
#  ' índice apontar teto pôr compor devolver mote ',
#  ' glosar gloso jurar deuse acabar ',
#  ' pedir mote davamlho glosavao prontamente pedir outro ',
#  ' outro senhora presente calar ',
#  ' admiração ',
#  '',
#  '  senhora retorquiar ',
#  ' modestamente vilaça ouvir bocage ouvir ',
#  ' século Lisboa facilidade verso luta ',
#  ' hora botequim nicola glosarmos palma ',
#  ' bravo imenso talento bocage dizer haver dia senhora ',
#  ' duquês cadaval ',
#  '',
#  ' palavra último ',
#  ' expressas muito ênfase produzir assembléia frêmito ',
#  ' admiração pasmo homem dado simples pleitear ',
#  ' poeta discretear duquesa bocage cadaval contato ',
#  ' homem damas sentiamse superfina varão olhavamno respeito ',
#  ' inveja raro incredulidade entretanto ir acumular ',
#  ' adjetivo adjetivo advérbio advérbio desfiar rima ',
#  ' tirano usurpador sobremesa ninguém pensar ',
#  ' comer intervalo glosa correr burburinho alegre palavrear ',
#  ' estômago satisfeito olho mole úmir vivo cálir ',
#  ' espreguiçavamse saltitar ponta mesa atulhar doce ',
#  ' fruta ananás fatia melão talhadas compoteira ',
#  ' cristal deixar doce coco finamente ralar amarelo gema ',
#  ' melado escuro grosso queijo cará ',
#  ' riso jovial amplo desabotoar riso família vir quebrar ',
#  ' gravidade político banquete interesse comum agitavamse ',
#  ' pequeno particular moça falar modinha haver ',
#  ' cantar cravo minuete solo inglês faltar matronar ',
#  ' prometesse bailar oitavado compasso mostrar folgara ',
#  ' bom tempo criança sujeito pé eu dar outro notícia recente ',
#  ' negro estar vir carta receber loanda ',
#  ' carta sobrinho dizer negociar cerca quarenta cabeça ',
#  ' carta traziaasr justamente algibeira ler ',
#  ' ocasião afiançar poder contar viagem ',
#  ' negro ',
#  '',
#  '  trás trás trás ',
#  ' vilaça bater mão rumor cessar súbito ',
#  ' estacar orquestra olho voltar glosador ficar ',
#  ' aconchear mão orelha perder palavra mor ',
#  ' glosa ter riso aplauso trivial cândido ',
#  '',
#  ' eu solitário ',
#  ' deslembrado namorar certo compota paixão gloso ',
#  ' ficar contente esperar ser último sobremesa ',
#  ' continuar intatar ninguém lembrar voz pai ',
#  ' cabeceira saborear gole extenso alegria conviva miravase ',
#  ' carão alegre prato flor deliciavase familiaridade travar ',
#  ' distante espírito influxo jantar ver ',
#  ' arrastar olho compota de ele compota pedirlhe ',
#  ' ma servir faziao ver viase se ',
#  ' glosa Sucediamse bátega dáguo obrigandome recolher desejo ',
#  ' pedir pacientei pude pude pedir voz baixo doce ',
#  ' enfim bradei berrei bati pé pai capaz ',
#  ' sol lho exigisse chamar escravo servir doce ',
#  ' tia emerenciano arrancarame cadeira entregarame escrar ',
#  ' obstante grito repelão ',
#  '',
#  ' outro delito ',
#  ' glosador retardar compota dera causa exclusão bastar ',
#  ' cogitar vingança ser exemplar ',
#  ' algum maneira tornar ridículo homem gravar dr ',
#  ' vilaça medir lento quarenta ano casado pai contentar ',
#  ' rabo papel rabicho cabeleira haver pior entrar ',
#  ' espreitálo durante resto seguilo chácara aonde ',
#  ' descer passear vio conversar d eusébio irmã sargentomor ',
#  ' domingue robusta donzelono bonito feio ',
#  '',
#  '  zangar ',
#  ' senhor dizer ',
#  '',
#  '  ',
#  '',
#  '  ',
#  ' sina crer bom morrer ',
#  '',
#  ' ter penetrar pequeno ',
#  ' moita luscofusco seguio vilaça levar olho chispa ',
#  ' vinho volúpia ',
#  '',
#  '  deixeme dizer ',
#  '',
#  '  ninguém ver morrer ',
#  ' anjo idéia morrerei dizer ',
#  ' morro dia paixão saudade ',
#  '',
#  ' d euséber levar lenço ',
#  ' olho glosador vasculhar memória algum pedaço literário achar ',
#  ' verifiquei ópera judeu ',
#  '',
#  '  chor queira ',
#  ' dia amanheça aurora ',
#  '',
#  ' dizer puxoua si ',
#  ' resistir deixouse unir rosto ouvir estalar ',
#  ' leve beijo medroso beijo ',
#  '',
#  '  dr vilaça dar beijo d ',
#  ' euséber bradei correr chácara ',
#  '',
#  ' estouro palavra ',
#  ' estupefação imobilizar olho espraiavamse banda ',
#  ' trocavamse sorriso segrer socapa mães arrastar filha ',
#  ...]

# %% [markdown]
# Vamos criar um dataframe com o texto processado

# %%
data_dict = {'clean': txt}
df_clean = pd.DataFrame(data_dict)
df_clean = df_clean.dropna().drop_duplicates()
df_clean.shape
# Out:
# (5717, 1)

# %%
# !pip install gensim
from gensim.models.phrases import Phrases, Phraser
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gensim in /usr/local/lib/python3.8/dist-packages (3.6.0)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.8/dist-packages (from gensim) (5.2.1)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.8/dist-packages (from gensim) (1.21.6)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.8/dist-packages (from gensim) (1.7.3)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.8/dist-packages (from gensim) (1.15.0)

# %%
sent = [row.split() for row in df_clean['clean']]
sent
# Out:
# [['romancer', 'memória', 'póstum', 'brás', 'cuba', '1880'],
#  [],
#  ['memória', 'póstum'],
#  ['brá', 'cuba'],
#  ['textofonte'],
#  ['obra', 'completo', 'machado'],
#  ['assi'],
#  ['rio'],
#  ['janeiro', 'editora', 'aguilar', '1994'],
#  ['publicar', 'originalmente'],
#  ['folhetim', 'março', '1880', 'revista', 'brasileiro'],
#  ['verme'],
#  [],
#  ['roeu', 'fria'],
#  ['carne'],
#  ['cadáver'],
#  ['dedico'],
#  ['saudoso', 'lembrança'],
#  ['memória'],
#  ['póstuma'],
#  ['prólogo'],
#  ['edição'],
#  ['edição', 'de', 'este'],
#  ['memória', 'póstum', 'brá', 'cuba', 'fazer', 'pedaço', 'revista'],
#  ['brasileira', 'ano', '1880', 'posta', 'livro', 'corrigi', 'texto'],
#  ['lugar', 'rever', 'edição', 'emendei'],
#  ['algum', 'suprimi', 'dúzia', 'linha', 'composta', 'sair'],
#  ['novamente', 'luz', 'obra', 'algum', 'benevolência', 'encontrar'],
#  ['público'],
#  ['capistrano', 'abrer', 'noticiar'],
#  ['publicação', 'livro', 'perguntar', 'memória', 'póstum', 'brás', 'cuba'],
#  ['romance', 'Macedo', 'Soares', 'carta', 'escrever', 'recordar'],
#  ['amigamente', 'viagem', 'terra', 'responder', 'defunto'],
#  ['brás', 'cuba', 'leitor', 'ver', 'ver', 'prólogo', 'de', 'ele', 'adiante'],
#  ['romancer'],
#  ['explicar', 'finado', 'tratase', 'obra', 'difuso', 'brás'],
#  ['cuba', 'adotar', 'livre', 'sterne', 'xavier', 'maistre'],
#  ['metir', 'rabugem', 'pessimismo', 'gente', 'viajar', 'xavier'],
#  ['maistre', 'roda', 'garretr', 'terra', 'de', 'ele', 'sterne', 'terra'],
#  ['brá', 'cuba', 'viajar', 'roda', 'vida'],
#  ['brás', 'cuba'],
#  ['autor', 'particular', 'chamar', 'rabugem', 'pessimismo', 'haver', 'alma'],
#  ['livro', 'risonho', 'parecer', 'sentimento', 'amargo', 'áspero'],
#  ['vir', 'modelo', 'taça', 'lavor', 'igual', 'escola'],
#  ['levar', 'outro', 'vinho', 'dizer', 'entrar', 'crítica', 'defunto'],
#  ['pintar', 'se', 'conforme', 'parecer', 'bom', 'certo'],
#  ['machado', 'assi'],
#  ['leitor'],
#  ['stendhal', 'confessar', 'haver'],
#  ['escrito', 'livro', 'cem', 'leitor', 'admira', 'consterno'],
#  ['admirar', 'provavelmente', 'consternar', 'outro', 'livro', 'ter'],
#  ['cem', 'leitor', 'stendhal', 'cinqüentar'],
#  ['tratase', 'verdade', 'obra', 'difuso', 'brás', 'cuba'],
#  ['adotar', 'livre', 'sterne', 'xavier', 'maistre'],
#  ['meti', 'rabugem', 'pessimismo', 'obra', 'finar', 'escrever'],
#  ['pena', 'galhofa', 'tinta', 'melancolia', 'difícil', 'antever'],
#  ['sair',
#   'conúbio',
#   'acrescer',
#   'gente',
#   'grave',
#   'achar',
#   'livro',
#   'aparência'],
#  ['puro',
#   'romance',
#   'passo',
#   'gente',
#   'frívolo',
#   'achar',
#   'em',
#   'ele',
#   'romance',
#   'usual'],
#  ['eilo', 'ficar', 'privado', 'estima', 'grave', 'amor', 'frívolo'],
#  ['coluna', 'máximo', 'opinião'],
#  ['esperar', 'angariar'],
#  ['simpatia', 'opinião', 'remédio', 'fugir', 'prólogo', 'explícito'],
#  ['longo', 'bom', 'prólogo', 'contémr', 'coisa', 'jeito'],
#  ['obscuro',
#   'truncar',
#   'conseguintemente',
#   'evito',
#   'contar',
#   'processo',
#   'extraordinário'],
#  ['empreguei',
#   'composição',
#   'de',
#   'este',
#   'memória',
#   'trabalhar',
#   'outro',
#   'mundo'],
#  ['curioso',
#   'nimiamente',
#   'extenso',
#   'aliás',
#   'desnecessário',
#   'entendimento'],
#  ['obra',
#   'obra',
#   'si',
#   'mesmo',
#   'agradar',
#   'fino',
#   'leitor',
#   'pagome',
#   'tarefa'],
#  ['agradar', 'pagote', 'piparote'],
#  ['capítulo', 'óbito'],
#  ['autor'],
#  ['algum', 'hesitar', 'dever', 'abrir'],
#  ['memória', 'princípio', 'por'],
#  ['nascimento', 'morte', 'suposto', 'uso', 'vulgar', 'ser', 'começar'],
#  ['nascimento', 'consideração', 'levar', 'adotar', 'diferente', 'método'],
#  ['propriamente', 'autor', 'defunto', 'defunto', 'autor'],
#  ['campa', 'outro', 'berço', 'escrito', 'ficar', 'galante'],
#  ['moisés', 'contar', 'morte', 'pôr', 'intróito'],
#  ['cabo', 'diferença', 'radical', 'livro', 'pentateuco'],
#  ['dizer', 'expirar', 'hora'],
#  ['sextafeira', 'agosto', '1869', 'belo', 'chácar'],
#  ['catumbi', 'ter', 'sessento', 'ano', 'rijo', 'próspero', 'solteiro'],
#  ['possuir', 'cerca', 'trezento', 'conto', 'acompanhar', 'cemitério'],
#  ['amigo', 'amigo', 'verdade', 'haver', 'carta', 'anúncio', 'acrescer'],
#  ['chover',
#   'peneirar',
#   'chuvinha',
#   'miúdo',
#   'triste',
#   'constante',
#   'constante'],
#  ['triste',
#   'levar',
#   'de',
#   'aquele',
#   'fiel',
#   'último',
#   'hora',
#   'intercalar',
#   'engenhoso'],
#  ['idéia', 'discurso', 'proferir', 'beira', 'cova', 'conheceste'],
#  ['senhor', 'podeis', 'comigo', 'natureza', 'chorar'],
#  ['perda', 'irreparável', 'belo', 'caracter', 'honrar', 'humanidade'],
#  ['ar', 'sombrio', 'gota', 'céu', 'nuvem', 'escura', 'cobr', 'azul'],
#  ['crepe', 'funéreo', 'dor', 'cruo', 'má', 'rói', 'natureza'],
#  ['íntimas', 'entranha', 'sublime', 'louvor', 'ilustre', 'finado'],
#  ['fiel', 'amigo'],
#  ['arreper', 'apólice', 'deixeir', 'cheguei', 'cláusula'],
#  ['dia', 'encaminhar', 'undiscovered'],
#  ['country', 'hamlet', 'ânsia', 'dúvida', 'moço', 'príncipe'],
#  ['pausar', 'trôpegar', 'retirar', 'espetáculo', 'aborrecer'],
#  ['viramme', 'pessoa', 'senhora', 'irmã'],
#  ['sabina', 'casado', 'cotrim', 'filha', 'lírio', 'vale', 'ter'],
#  ['paciência', 'de', 'aqui', 'eles', 'dir', 'senhora', 'Contentemse'],
#  ['anônimo', 'parentar', 'padecer', 'parenta'],
#  ['verdade', 'padecer', 'dizer', 'carpir', 'dizer', 'deixar'],
#  ['rolar', 'chão', 'convulsa', 'óbito', 'altamente', 'dramático'],
#  ['solteir', 'expirar', 'sessenzer', 'ano', 'reúnar', 'si'],
#  ['elemento', 'tragédia', 'dar', 'convinha'],
#  ['anônimo', 'aparentálo', 'pé', 'cabeceira', 'cama', 'olho', 'estúpir'],
#  ['boca', 'entreaberto', 'triste', 'senhora', 'crer', 'extinção'],
#  ['morrer', 'matar', 'dizer', 'consigo'],
#  ['imaginação', 'de', 'ela'],
#  ['cegonha',
#   'ilustre',
#   'viajante',
#   'ver',
#   'desferir',
#   'vôo',
#   'ilisso',
#   'riba'],
#  ['africana', 'embargo', 'ruína', 'tempo', 'imaginação', 'senhora'],
#  ['voar', 'destroço', 'presente', 'riba', 'áfrica'],
#  ['juvenil', 'deixála', 'ir', 'ir', 'restituir'],
#  ['primeiro', 'ano', 'morrer', 'tranqüilamente', 'metodicamente', 'ouvir'],
#  ['soluço', 'dama', 'fala', 'baixo', 'homem', 'chuva', 'tamborila'],
#  ['folha', 'tinhorão', 'chácara', 'som', 'estrídulo', 'navalha', 'amolador'],
#  ['afiar', 'porta', 'Correeiro', 'jurolhe', 'orquestra'],
#  ['morte', 'triste', 'parecer', 'certo'],
#  ['chegar', 'delicioso', 'vida', 'estrebuchavame', 'peito', 'ímpeto', 'vaga'],
#  ['marinh',
#   'esvaíaseme',
#   'consciência',
#   'descer',
#   'imobilidade',
#   'físico',
#   'moral'],
#  ['corpo', 'faziaseme', 'planta', 'pedra', 'lodo'],
#  ['morri', 'pneumonia'],
#  ['disser', 'pneumonia', 'idéia', 'grandioso', 'útil', 'causa'],
#  ['morte', 'leitor', 'crei', 'todavia', 'verdade', 'ir'],
#  ['exporlhe', 'sumariamente', 'caso', 'julgueo', 'si'],
#  ['capítulo', 'ii'],
#  ['emplasto'],
#  ['efeito', 'dia', 'manhã'],
#  ['estar', 'passear', 'chácaro', 'pendurouseme', 'idéia', 'trapézio', 'ter'],
#  ['cérebro', 'pendurar', 'entrar', 'bracejar', 'pernear'],
#  ['arrojar', 'cabriola', 'volatim', 'crer', 'deixeime'],
#  ['contemplála', 'súbito', 'dar', 'salto', 'estender', 'braço', 'perna'],
#  ['tomar', 'x', 'deciframe', 'devorotir'],
#  ['idéia'],
#  ['invenção',
#   'medicamento',
#   'sublime',
#   'emplastro',
#   'antihipocondríaco',
#   'destinar'],
#  ['aliviar', 'melancólico', 'humanidade', 'petição', 'privilégio'],
#  ['redigi', 'chameir', 'atenção', 'governo', 'resultado', 'verdadeiramente'],
#  ['cristão', 'todavia', 'neguei', 'amigo', 'vantagem', 'pecuniário', 'dever'],
#  ['resultar', 'distribuição', 'produto', 'tamanho', 'profundo', 'efeito'],
#  ['outro', 'vida', 'confessar'],
#  ['influir', 'principalmente', 'gosto', 'impressa', 'jornal', 'mostrador'],
#  ['folheto', 'esquino', 'enfim', 'caixinha', 'remédio', 'palavra'],
#  ['emplasto', 'brás', 'cuba', 'negálo', 'ter', 'paixão', 'arruído'],
#  ['cartaz', 'foguete', 'lágrima', 'modesto', 'argúam', 'defeito', 'fio'],
#  ['talento', 'hão', 'reconhecer', 'hábel', 'idéia'],
#  ['trazer', 'face', 'medalha', 'virada', 'público', 'eu'],
#  ['filantropia', 'lucro', 'outro', 'sede', 'nomeada', 'dizer', 'amor'],
#  ['glória'],
#  ['tio', 'cônego', 'prebenda'],
#  ['inteirar', 'costumar', 'amor', 'glória', 'temporal', 'perdição', 'alma'],
#  ['cobiçar', 'glória', 'eterno', 'retorquiar', 'outro', 'tio', 'oficial'],
#  ['antigo', 'terço', 'infantaria', 'amor', 'glória'],
#  ['verdadeiramente',
#   'humano',
#   'haver',
#   'homem',
#   'conseguintemente',
#   'genuíno'],
#  ['feição'],
#  ['decer', 'leitor', 'militar'],
#  ['cônego', 'voltar', 'emplasto'],
#  ['capítulo', 'iii'],
#  ['genealogiar'],
#  ['falar'],
#  ['tio', 'deixemme', 'curto', 'esboço', 'genealógico'],
#  ['fundador', 'família'],
#  ['certo', 'damião', 'cuba', 'florescer', 'metade', 'século', 'xviii'],
#  ['tanoeiro',
#   'ofício',
#   'natural',
#   'Rio',
#   'Janeiro',
#   'ter',
#   'morrer',
#   'penúria'],
#  ['obscuridade', 'exercer', 'tanoaria', 'fezser', 'lavrador'],
#  ['plantar', 'colheu', 'permutar', 'produto', 'boa', 'honrada', 'pataco'],
#  ['morrer',
#   'deixar',
#   'grosso',
#   'cabedal',
#   'filho',
#   'licenciado',
#   'Luís',
#   'cuba',
#   'rapaz'],
#  ['verdadeiramente', 'começar', 'série', 'avós', 'avós', 'família'],
#  ['confessar', 'damião', 'cubas', 'afinal', 'conta', 'tanoeiro'],
#  ['mau', 'tanoeiro', 'passo', 'Luís', 'cubas', 'estudar', 'coimbra', 'primar'],
#  ['amigo', 'particular', 'vicerei', 'conde', 'cunha'],
#  ['apelido', 'cuba'],
#  ['cheirar',
#   'excessivamente',
#   'tanoaria',
#   'alegar',
#   'pai',
#   'bisneto',
#   'damião'],
#  ['dizer',
#   'apelir',
#   'dar',
#   'cavaleiro',
#   'herói',
#   'jornada',
#   'África',
#   'prêmio'],
#  ['façanha', 'praticar', 'arrebatar', 'trezenta', 'cuba', 'mouro', 'pai'],
#  ['homem', 'imaginação', 'escapar', 'tanoaria', 'asa', 'calembour'],
#  ['caráter', 'pai', 'var', 'digno', 'leal', 'pouco', 'ter', 'verdade'],
#  ['fumos', 'pacholice', 'pachola', 'mundo', 'releva', 'notar'],
#  ['recorrer', 'inventiva', 'senão', 'experimentar', 'falsificação'],
#  ['primeiramente', 'entroncouse', 'família', 'famoso', 'homônimo'],
#  ['capitãomor', 'brás', 'cuba', 'fundar', 'vila', 'vicente', 'morrer', '1592'],
#  ['motivo', 'dar', 'nome', 'brás', 'opôsselher', 'família'],
#  ['capitãomor', 'imaginar', 'trezenta', 'cuba', 'mourisco'],
#  ['viver', 'membro'],
#  ['família', 'sobrinho', 'venância', 'lírio', 'vale'],
#  ['flor', 'dama', 'viver', 'pai', 'cotrim', 'sujeito'],
#  ['anteciper', 'sucesso', 'acabemos', 'emplasto'],
#  ['capítulo', 'iv', 'idéia'],
#  ['fixo'],
#  ['idéia', 'tanto'],
#  ['cabriolo',
#   'constituírase',
#   'idéia',
#   'fixo',
#   'deus',
#   'livre',
#   'leitor',
#   'idéia',
#   'fixo'],
#  ['argueiro', 'trave', 'olho', 'ver', 'cavour', 'idéia', 'fixo'],
#  ['unidade', 'italiano', 'matar', 'verdade', 'bismarck', 'morrer', 'cumprir'],
#  ['advertir', 'natureza', 'caprichoso', 'história', 'eterno'],
#  ['loureira', 'suetônio', 'deuno', 'cláudio', 'simplório'],
#  ['abóbora', 'chamar', 'sêneca', 'tito', 'merecer', 'delícia'],
#  ['roma', 'vir', 'modernamente', 'professor', 'achar', 'demonstrar'],
#  ['césar', 'delicioso', 'verdadeiro', 'delicioso', 'abóbora', 'sêneca'],
#  ['madama', 'lucrécia', 'flor', 'bórgia', 'poeta', 'pintar', 'messalina'],
#  ['católica', 'aparecer', 'gregorovius', 'incrédulo', 'apagar', 'qualidade'],
#  ['viestar', 'lírio', 'ficaste', 'pântano', 'deixomer'],
#  ['poeta', 'sábio'],
#  ['viver', 'história', 'volúvel'],
#  ['história', 'tornar', 'idéia', 'fixo', 'direi'],
#  ['varão', 'forte', 'doido', 'idéia', 'móbil', 'vaga', 'furtacor'],
#  ['cláudio', 'fórmula', 'suetônio'],
#  ['fixo', 'idéia', 'fixo'],
#  ['ocorrer', 'ser', 'assaz', 'fixo', 'mundo', 'lua'],
#  ['pirâmide', 'egito', 'finada', 'dieta', 'germânico', 'leitor'],
#  ['comparação',
#   'melhor',
#   'quadrar',
#   'vejaa',
#   'estar',
#   'de',
#   'aí',
#   'torcerme',
#   'nariz'],
#  ['chegar', 'narrativo', 'de', 'este', 'memória', 'ir', 'crer'],
#  ['preferir', 'anedota', 'reflexão', 'leitor', 'confrade'],
#  ['achar', 'ir', 'todavia', 'importa', 'livro'],
#  ['escrito', 'pachorra', 'pachorra', 'homem', 'desafrontar', 'brevidade'],
#  ['século',
#   'obra',
#   'supinamente',
#   'filosófico',
#   'filosofia',
#   'desigual',
#   'austera'],
#  ['brincalhonar', 'edifica', 'destrói', 'inflamar', 'regalar'],
#  ['todavia', 'passatempo', 'apostolado'],
#  ['ir', 'retifiquer', 'nariz'],
#  ['tornemos', 'emplasto', 'deixar', 'história', 'capricho', 'dama'],
#  ['elegante',
#   'nenhum',
#   'pelejar',
#   'batalha',
#   'salamina',
#   'nenhum',
#   'escrever'],
#  ['confissão', 'augsburgo', 'algum', 'lembro', 'cromwell'],
#  ['idéia', 'alteza', 'mesmo', 'mão', 'trancar', 'parlamento'],
#  ['ter', 'impor', 'inglês', 'emplasto', 'brás', 'cuba', 'r', 'vitória'],
#  ['comum', 'farmácia', 'puritanismo', 'pé', 'bandeira'],
#  ['pública',
#   'ostensivo',
#   'haver',
#   'muitas',
#   'várias',
#   'bandeira',
#   'modestamente'],
#  ['particular', 'hastear', 'flutuar', 'sombra', 'pouco'],
#  ['sobreviver', 'comparar', 'arraiamiúda', 'acolhiar', 'sombra'],
#  ['castelo', 'feudal', 'cair', 'arraia', 'ficar', 'verdade', 'graúda'],
#  ['castelã', 'comparação', 'prestar'],
#  ['capítulo', 'v', 'aparecer'],
#  ['orelha', 'senhora'],
#  ['senão', 'estar', 'ocupar'],
#  ['preparar',
#   'apurar',
#   'invenção',
#   'recebi',
#   'cheio',
#   'golpe',
#   'ar',
#   'adoeci'],
#  ['tratar', 'ter', 'emplasto', 'cérebro', 'trazer', 'comigo', 'idéia', 'fixo'],
#  ['doido', 'forte', 'viame', 'ascender', 'chão', 'turba'],
#  ['remontar', 'céu', 'águia', 'imortal', 'excelso'],
#  ['espetáculo', 'homem', 'sentir', 'dor', 'punge', 'outro', 'dia', 'mau'],
#  ['trateime', 'enfim', 'incompletamente', 'método', 'cuidado', 'persistência'],
#  ['origem', 'trazer', 'eternidade', 'saber', 'morrir'],
#  ['sextafeira', 'dia', 'aziago', 'crer', 'haver', 'provar', 'invenção'],
#  ['matar', 'haver', 'demonstração', 'lúcida', 'triunfante'],
#  ['impossível', 'entretanto'],
#  ['chegar', 'galgar', 'cimo', 'século', 'figurar', 'folha', 'público'],
#  ['macróbio', 'ter', 'saúde', 'robustez', 'suponhase'],
#  ['lançar', 'alicerce', 'invenção', 'farmacêutico', 'tratar', 'coligir'],
#  ['elemento', 'instituição', 'político', 'reforma', 'religioso', 'vir'],
#  ['ar', 'vencer', 'eficácia', 'cálculo', 'humano', 'ir'],
#  ['correr', 'sorte', 'homem'],
#  ['reflexão', 'despedi'],
#  ['mulher', 'dir', 'discreto', 'formoso'],
#  ['contemporânea', 'anônimo', 'capítulo', 'imaginação'],
#  ['semelhança', 'cegonha', 'ilisso', 'ter', '54', 'ano', 'ruína'],
#  ['imponente', 'ruína', 'imagine', 'leitor', 'ama', 'ano'],
#  ['dia', 'enfermo', 'vejoar', 'assomar', 'porta', 'alcova'],
#  ['capítulo', 'ver', 'chimène', 'qui'],
#  ['leût', 'dit', 'rodrigue', 'qui', 'leût', 'cru'],
#  ['vejoar', 'assomar', 'porta', 'alcova'],
#  ['pálida',
#   'comover',
#   'trajada',
#   'preto',
#   'ficar',
#   'durante',
#   'minuto',
#   'ânimo'],
#  ['entrar', 'deter', 'presença', 'homem', 'comigo', 'cama'],
#  ['jazer', 'contempleia', 'durante', 'esquecer'],
#  ['nenhum', 'gesto', 'haver', 'ano', 'ver', 'viaar'],
#  ['fôramos', 'ezequia', 'misterioso', 'fizera'],
#  ['recuar', 'sol', 'dia', 'juvenis', 'recuar', 'sol', 'sacudi', 'miséria'],
#  ['punhar', 'pó', 'morte', 'ir', 'espalhar', 'eternidade'],
#  ['ministro', 'morte', 'água', 'juventa', 'igualario'],
#  ['simples', 'saudade'],
#  ['creiammer', 'mau', 'recordar'],
#  ['ninguém',
#   'fie',
#   'felicidade',
#   'presente',
#   'haver',
#   'em',
#   'ele',
#   'gota',
#   'baba',
#   'caim',
#   'corrir'],
#  ['cessar', 'espasmo', 'gozar', 'deveras'],
#  ['de', 'esse', 'ilusão', 'melhor', 'gostar', 'doer'],
#  ['durar', 'evocação'],
#  ['realidade', 'dominar', 'presente', 'expelir', 'passado', 'exponha'],
#  ['leitor', 'algum', 'canto', 'livro', 'teoria', 'edição', 'humano'],
#  ['importar', 'virgílier', 'chamavase', 'virgílio', 'entrar', 'alcova'],
#  ['firme', 'gravidade', 'dar', 'roupa', 'ano', 'vir'],
#  ['leito', 'estranho', 'levantouse', 'sair', 'sujeito', 'visitar'],
#  ['dia', 'falar', 'câmbio', 'colonização', 'necessidade', 'desenvolver'],
#  ['viação', 'férreo', 'interessante', 'moribundo', 'sair', 'virgílio'],
#  ['deixouse', 'pé', 'durante', 'algum', 'ficar', 'olhar', 'outro'],
#  ['articular', 'palavra', 'dir', 'namorado', 'paixão'],
#  ['freio', 'haver', 'ano', 'haver', 'coração'],
#  ['murcho', 'devastar', 'vida', 'saciar', 'de', 'ela', 'igual', 'dose'],
#  ['enfim', 'saciar', 'virgília', 'ter', 'beleza', 'velhice', 'ar', 'austero'],
#  ['maternal', 'magro', 'ver', 'último', 'festa'],
#  ['João', 'tijuca', 'resistar', 'começar'],
#  ['cabelo', 'escuro', 'intercalarse', 'fio', 'prata'],
#  ['andar', 'visitar', 'defunto'],
#  ['disselhe', 'defunto', 'responder', 'Virgília', 'muxoxo'],
#  ['apertar', 'mão', 'ar', 'ponho', 'vadio', 'rua'],
#  ['ter', 'carícia', 'lacrimoso'],
#  ['outro', 'voz', 'amigo', 'doce', 'sentouse', 'casa'],
#  ['simples',
#   'enfermeiro',
#   'poder',
#   'falar',
#   'outro',
#   'perigo',
#   'Virgília',
#   'deume'],
#  ['longo', 'notícia', 'narrandoa', 'graça', 'certo', 'travo', 'má', 'língua'],
#  ['sal', 'palestra', 'prestes', 'deixar', 'mundo', 'sent', 'prazer'],
#  ['satânico', 'mofar', 'de', 'ele', 'persuadirme', 'deixar'],
#  ['idéia', 'interrompeume'],
#  ['virgíliar', 'zangar', 'olhar', 'voltar', 'morrer', 'haver'],
#  ['morrer', 'bastar', 'estar', 'vivo'],
#  ['ver', 'relógio'],
#  ['jesus', 'hora', 'voume'],
#  [],
#  ['virar', 'amanhã'],
#  ['retorqui'],
#  ['doente', 'solteir', 'casa', 'senhora'],
#  ['mano'],
#  ['haver', 'vir', 'passar', 'dia'],
#  ['sábado'],
#  ['Virgília', 'refletir', 'instante'],
#  ['levantar', 'ombro', 'dizer', 'gravidade'],
#  ['velho', 'ninguém', 'reparar'],
#  ['eu', 'cortar', 'dúvida', 'virar', 'nhonhô'],
#  ['nhonhô', 'bacharel', 'único'],
#  ['filho', 'casamento', 'idade', 'ano', 'cúmplice', 'inconsciente'],
#  ['amor', 'vir', 'junto', 'dia', 'confessar', 'vêlo'],
#  ['alcova', 'tomar', 'acanhamento', 'permitir'],
#  ['corresponder',
#   'palavra',
#   'afável',
#   'rapaz',
#   'virgília',
#   'adivinhoume',
#   'dizer'],
#  ['filho'],
#  ['nhonhô', 'repar'],
#  ['manhoso', 'falar', 'crer', 'morte'],
#  ['sorrir', 'filho', 'crer'],
#  ['sorri', 'acabar', 'pura', 'galhofa', 'virgílio', 'serena', 'risonhar'],
#  ['ter',
#   'aspecto',
#   'vida',
#   'imacular',
#   'nenhum',
#   'olhar',
#   'suspeito',
#   'nenhum',
#   'gesto'],
#  ['poder', 'denunciar', 'igualdade', 'palavra', 'espírito', 'dominação'],
#  ['si', 'mesmo', 'parecer', 'ser', 'raro', 'tocásser'],
#  ['casualmente', 'amor', 'ilegítimos', 'secreto', 'divulgar', 'via', 'falar'],
#  ['desdém', 'indignação', 'mulher', 'tratar', 'aliás'],
#  ['amiga',
#   'filho',
#   'sentiase',
#   'satisfeito',
#   'ouvir',
#   'palavra',
#   'digno',
#   'forte'],
#  ['perguntar', 'eu', 'diriar', 'gavião', 'buffon', 'ter', 'nascer'],
#  ['gavião'],
#  ['delírio', 'começar'],
#  ['capítulo', 'vii'],
#  ['delírio'],
#  ['ce', 'onste', 'ninguém'],
#  ['relatar', 'delírio', 'façoor', 'ciência', 'mo', 'agradecer', 'leitor'],
#  ['dar',
#   'contemplação',
#   'de',
#   'este',
#   'fenômeno',
#   'mental',
#   'saltar',
#   'capítulo',
#   'ir'],
#  ['direito', 'narração', 'curioso', 'ser', 'dizer'],
#  ['interessante', 'passar', 'cabeça', 'durante', 'trinto'],
#  ['minuto'],
#  ['primeiramente', 'tomeir', 'figura'],
#  ['barbeiro', 'chinês', 'bojudo', 'destro', 'escanhoar', 'mandarim', 'pagar'],
#  ['trabalho', 'beliscão', 'confeito', 'capricho', 'mandarim'],
#  ['sentime', 'transformar'],
#  ['suma', 'teológico', 'tomás', 'impresso', 'volume', 'encadernar'],
#  ['marroquim', 'fecho', 'prata', 'estampa', 'idéia', 'dar', 'corpo'],
#  ['completo', 'imobilidade', 'lembrar', 'ser', 'mão'],
#  ['fecho', 'livro', 'cruzandoa', 'ventre', 'alguém', 'descruzar', 'virgílio'],
#  ['decerto', 'atitude', 'dar', 'imagem', 'defunto'],
#  ['ultimamente', 'restituir'],
#  ['humana', 'ver', 'chegar', 'hipopótamo', 'arrebatar', 'deixeime', 'calar'],
#  ['medo', 'confiança', 'carreira', 'modo', 'tornar'],
#  ['vertiginoso', 'atrevi', 'interrogálo', 'algum', 'arte', 'dizer'],
#  ['viagem', 'parecer', 'destino'],
#  ['enganase', 'replicar', 'animal'],
#  ['ir', 'origem', 'século'],
#  ['insinuei', 'dever'],
#  ['muitíssimo', 'hipopótamo', 'entender', 'ouvir'],
#  ['fingir', 'de', 'esse', 'coisa', 'perguntandolhe', 'ver', 'falar'],
#  ['descendente', 'cavalo', 'aquile', 'asna', 'balaão', 'retorquiume', 'gesto'],
#  ['peculiar', 'quadrúpede', 'abanar', 'orelha', 'fechar'],
#  ['olho', 'deixeime', 'ventura', 'confessar', 'senzet'],
#  ['cócega', 'curiosidade', 'ficar', 'origem'],
#  ['século', 'misterioso', 'origem', 'nilo', 'sobretudo', 'valer'],
#  ['algum', 'consumação', 'mesmo', 'século', 'reflexão'],
#  ['cérebro', 'enfermo', 'ir', 'olho', 'fechar', 'ver', 'lembrame'],
#  ['sensação', 'frio', 'aumentar', 'jornada', 'chegar', 'ocasião'],
#  ['parecer',
#   'entrar',
#   'região',
#   'gelo',
#   'eterno',
#   'efeito',
#   'abri',
#   'olho',
#   'ver'],
#  ['animal', 'galopar', 'planície', 'branco', 'neve', 'animal'],
#  ['never', 'never', 'chegar', 'gelarno', 'sol', 'neve', 'falar'],
#  ['pude', 'grunhirr', 'pergunta', 'ansioso'],
#  ['estar'],
#  ['passar', 'éden'],
#  ['paremo', 'tenda', 'abraão'],
#  ['caminhamos', 'trás'],
#  ['redargüiu', 'motejar', 'cavalgadura'],
#  ['fiquei', 'vexar', 'aturder'],
#  ['jornada',
#   'entrar',
#   'parecerme',
#   'enfadonha',
#   'extravagante',
#   'frio',
#   'incômodo'],
#  ['condução', 'violento', 'resultado', 'impalpável', 'cogitação', 'enfermo'],
#  ['dar', 'chegássemo', 'indicado', 'impossível', 'século'],
#  ['irritar', 'eles', 'devassar', 'origem', 'esmagar', 'unha', 'dever'],
#  ['secular', 'pensar', 'íamos', 'devorar'],
#  ['planície', 'voar', 'pé', 'animal', 'estacar', 'pude', 'olhar'],
#  ['tranqüilamente', 'torno', 'eu', 'olhar', 'ver', 'imenso'],
#  ['brancura', 'neve', 'invadiro', 'céu', 'azul'],
#  ['espaço', 'parecer', 'planta', 'enorme', 'brutesca', 'menear', 'vento'],
#  ['larga', 'folho', 'silêncio', 'região', 'igual', 'sepulcro'],
#  ['disserase', 'vida', 'coisa', 'ficara', 'estúpido', 'homem'],
#  ['cair', 'ar', 'destacouse', 'terra'],
#  ['vulto', 'imenso', 'figura', 'mulher', 'aparecer'],
#  ['fitandome', 'olho', 'rutilante', 'sol', 'figura', 'ter', 'vastidão'],
#  ['forma', 'selvático', 'escapar', 'compreensão', 'olhar', 'humano'],
#  ['contorno',
#   'perdiamse',
#   'ambiente',
#   'parecer',
#   'espesso',
#   'muito',
#   'diáfano'],
#  ['estupefato', 'dizer', 'chegueir', 'sequer', 'soltar', 'grito', 'cabo'],
#  ['algum', 'perguntar', 'chamar', 'curiosidade'],
#  ['chamame', 'natureza', 'pandora'],
#  ['mãe', 'inimigo'],
#  ['ouvir', 'último', 'palavra'],
#  ['recuei', 'tomar', 'susto', 'figura', 'soltar', 'gargalhada', 'produziu'],
#  ['torno', 'efeito', 'tufão', 'planta', 'torceramse', 'longo', 'gemido'],
#  ['quebrar', 'mudez', 'coisa', 'externo'],
#  ['assuste', 'dizer'],
#  ['inimizade', 'matar', 'sobretudo', 'vida', 'afirmar', 'vive'],
#  ['outro', 'flagelo'],
#  ['vivo', 'perguntar', 'enterrar'],
#  ['unha', 'mão', 'certificarme', 'existência'],
#  ['verme', 'viver'],
#  ['receie', 'perder', 'andrajo', 'orgulho', 'provarás'],
#  ['hora', 'pão', 'dor', 'vinho', 'miséria', 'vives', 'ensandeceste'],
#  ['vive', 'consciência', 'reouver', 'instante', 'sagacidade', 'dirás'],
#  ['quer', 'viver'],
#  ['dizer', 'visão', 'estender'],
#  ['braço', 'seguroume', 'cabelo', 'levantoumir', 'ar', 'pluma'],
#  ['pude', 'verlhe', 'rosto', 'enorme'],
#  ['contorção',
#   'violento',
#   'expressão',
#   'ódio',
#   'ferocidade',
#   'feição',
#   'único'],
#  ['completo', 'impassibilidade', 'egoísta', 'eterna', 'surdez'],
#  ['vontade', 'imóvel', 'raivo', 'ter', 'ficar', 'encerrado', 'coração'],
#  ['rosto', 'expressão', 'glacial', 'haver', 'ar', 'Juventude', 'mescla'],
#  ['força', 'viço', 'sent', 'débil', 'decrépito', 'ser'],
#  ['entendesteme', 'dizer'],
#  ['algum', 'mútuo', 'contemplação'],
#  ['responder'],
#  ['entenderte', 'absurda', 'fábula', 'sonhar', 'decerto'],
#  ['verdade', 'enlouqueci', 'passa', 'concepção', 'alienar'],
#  ['vã', 'razão', 'ausente', 'reger', 'palpar', 'natureza'],
#  ['natureza', 'conhecer', 'mãe', 'inimiga', 'vida', 'flagelo'],
#  ['trazer', 'rosto', 'indiferente', 'sepulcro', 'pandorar'],
#  ['levar', 'bolsa'],
#  ['bem', 'mal', 'esperança', 'consolação', 'homem', 'treme'],
#  ['olhar', 'fasciname'],
#  ['crer'],
#  ['vida', 'morte', 'prestes', 'devolverme', 'emprestei'],
#  ['lascivo', 'esperater', 'voluptuosidade'],
#  ['palavra', 'ecoar'],
#  ['trovão', 'imenso', 'vale', 'afigurouseme', 'som', 'chegar'],
#  ['ouvir', 'pareceume', 'sentir', 'decomposição', 'súbito', 'eu'],
#  ['encareia', 'olho', 'súplice', 'pedir', 'ano'],
#  ['pobre', 'minuto', 'exclamar'],
#  ['quer', 'instante', 'vida', 'devorar', 'sere', 'devorar'],
#  ['fartar', 'espetáculo', 'luta', 'conhece', 'sobejo'],
#  ['depar', 'torpe', 'aflitivo', 'alvor', 'dia', 'melancolia'],
#  ['quietação', 'noite', 'aspecto', 'terra', 'sono', 'enfim', 'benefício'],
#  ['mão', 'quer', 'sublime', 'idiota'],
#  ['viver', 'peçar'],
#  ['pôr', 'coração', 'amor', 'vida', 'senão', 'amar', 'vida'],
#  ['hás', 'golpear', 'ti', 'mesmo', 'matandome'],
#  ['preciso', 'ti'],
#  ['importar', 'minuto', 'passar', 'minuto', 'minuto'],
#  ['forte',
#   'jucundo',
#   'supor',
#   'trazer',
#   'se',
#   'eternidade',
#   'trazer',
#   'morte',
#   'perecer'],
#  ['outro', 'subsiste', 'egoísmo', 'diz', 'egoísmo'],
#  ['lei',
#   'egoísmo',
#   'conservação',
#   'onça',
#   'matar',
#   'novilho',
#   'raciocínio',
#   'onça'],
#  ['viver', 'novilho', 'tenro', 'bom', 'eis', 'estatuto'],
#  ['universal', 'subir', 'olhar'],
#  ['dizer', 'arrebatoume', 'alto'],
#  ['montanha', 'inclinei', 'olho', 'vertente', 'contemplei', 'durante'],
#  ['largo', 'nevoeiro', 'único', 'imaginar'],
#  ['leitor', 'redução', 'século', 'desfilar', 'raça'],
#  ['paixão', 'tumulto', 'império', 'guerra', 'apetite', 'ódio'],
#  ['destruição', 'recíproco', 'ser', 'coisa', 'espetáculo', 'acerbo'],
#  ['curioso', 'espetáculo', 'história', 'homem', 'terra', 'ter', 'intensidade'],
#  ['poder', 'imaginação', 'ciência', 'ciência'],
#  ['lento', 'imaginação', 'vago', 'ver', 'condensação'],
#  ['viver', 'tempo', 'descrevêla', 'preciso', 'fixar', 'relâmpago'],
#  ['século', 'desfilar', 'turbilhão', 'obstante', 'olho', 'delírio'],
#  ['ver', 'passar', 'eu', 'flagelo', 'delício'],
#  ['chamar', 'glór', 'chamar', 'misério', 'ver'],
#  ['amor', 'multiplicar', 'miséria', 'ver', 'miséria', 'agravar', 'debilidade'],
#  ['vinhar',
#   'cobiça',
#   'devorar',
#   'cólera',
#   'inflamar',
#   'inveja',
#   'baba',
#   'enxada'],
#  ['pena', 'úmir', 'suor', 'ambição', 'fome', 'vaidade', 'melancolia'],
#  ['riqueza', 'amor', 'agitar', 'homem', 'chocalho', 'destruílo'],
#  ['farrapo', 'ser', 'forma', 'várias', 'morder', 'víscera'],
#  ['mordia', 'pensamento', 'passear', 'eternamente', 'veste', 'arlequim'],
#  ['derredor',
#   'espécie',
#   'humano',
#   'dor',
#   'cedia',
#   'algum',
#   'ceder',
#   'indiferença'],
#  ['sono', 'sonho', 'prazer', 'dor', 'bastarda', 'homem'],
#  ['flagelar', 'rebelde', 'correr', 'fatalidade', 'coisa', 'figura'],
#  ['nebulosa', 'esquivo', 'fazer', 'retalho', 'retalho', 'impalpável', 'outro'],
#  ['improvável', 'outro', 'invisível', 'cosido', 'precário', 'agulha'],
#  ['imaginação', 'figura', 'quimera', 'felicidade'],
#  ['fugir',
#   'perpetuamente',
#   'deixavase',
#   'apanhar',
#   'fralda',
#   'homem',
#   'cingia'],
#  ['peito', 'r', 'escárnio', 'sumiase', 'ilusão'],
#  ['contemplar', 'calamidade'],
#  ['pude', 'reter', 'grito', 'angústia', 'natureza', 'pandora', 'escutar'],
#  ['protestar', 'rir', 'lei', 'transtorno', 'cerebral'],
#  ['pus', 'rir', 'riso', 'descompassar', 'idiota'],
#  ['razão', 'dizer'],
#  ['divertido', 'valer', 'pena', 'monótonar', 'valer', 'pena', 'jó'],
#  ['amaldiçoar', 'dia', 'concebido', 'dar', 'gana'],
#  ['espetáculo', 'ir', 'pandora', 'abrir', 'ventre', 'digereme'],
#  ['divertido', 'digereme'],
#  ['resposta', 'compelirme'],
#  ['fortemente', 'olhar', 'século', 'continuar', 'passar'],
#  ['veloz', 'turbulento', 'geração', 'superpunhar', 'geração', 'triste'],
#  ['hebreu', 'cativeiro', 'alegre', 'devasso', 'cômodo'],
#  ['pontual', 'sepultura', 'querer', 'fugir', 'força', 'misterioso'],
#  ['retinhar', 'pé', 'dizer', 'comigo', 'século', 'passar', 'chegar'],
#  ['passar', 'dar', 'decifração', 'eternidade'],
#  ['fixei', 'olho', 'continuei', 'idade', 'vir', 'chegar', 'passar'],
#  ['tranqüilo', 'resoluto', 'alegre', 'alegre', 'século'],
#  ['trazer', 'porção', 'sombra', 'luz', 'apatia', 'combate', 'verdade'],
#  ['erro', 'cortejo', 'sistema', 'idéia', 'ilusão'],
#  ['de', 'ele', 'rebentar', 'verdura', 'primavera', 'amarelecar'],
#  ['remoçar', 'passo', 'vida', 'ter', 'regularidade'],
#  ['calendário',
#   'faziase',
#   'história',
#   'civilização',
#   'homem',
#   'nu',
#   'desarmar'],
#  ['armavase',
#   'vestiase',
#   'construir',
#   'tugúrio',
#   'paláciar',
#   'rude',
#   'aldeia',
#   'teba'],
#  ['cem',
#   'porta',
#   'criar',
#   'ciência',
#   'perscruta',
#   'arte',
#   'enlever',
#   'faziase'],
#  ['orador',
#   'mecânico',
#   'filósofo',
#   'correr',
#   'face',
#   'globo',
#   'descia',
#   'ventre',
#   'terra'],
#  ['suber', 'esfera', 'nuvem', 'colaborar', 'obra', 'misterioso'],
#  ['entreter', 'necessidade', 'vida', 'melancolia', 'desamparo', 'olhar'],
#  ['enfarar',
#   'distrair',
#   'ver',
#   'enfim',
#   'chegar',
#   'século',
#   'presente',
#   'de',
#   'ele'],
#  ['futuro', 'vir', 'ágil', 'destro', 'vibrante', 'cheio', 'se', 'difuso'],
#  ['audaz', 'sabedor', 'cabo', 'miserável', 'primeiro', 'passar'],
#  ['passar', 'mesmo', 'rapidez', 'igual', 'monotonia', 'redobrar'],
#  ['atenção', 'fitar', 'vista', 'ir', 'enfim'],
#  ['rapidez', 'marcha', 'escapar', 'compreensão', 'pé', 'de', 'ela'],
#  ['relâmpago', 'século', 'entrar', 'objeto', 'trocaremse'],
#  ['crescer', 'minguar', 'perderamse', 'ambiente', 'nevoeiro'],
#  ['cobrir', 'hipopótamo', 'trouxerar', 'aliás', 'começar'],
#  ['diminuir', 'diminuir', 'diminuir', 'ficar', 'tamanho', 'gato'],
#  ['efetivamente', 'gato', 'encareio', 'gato', 'sultão', 'brincar'],
#  ['porta', 'alcova', 'bola', 'papel'],
#  ['capítulo', 'viii', 'razão'],
#  ['sandice'],
#  ['leitor', 'compreender'],
#  ['razão', 'voltar', 'casa', 'convidar', 'sandice', 'sair', 'clamar', 'bom'],
#  ['jus', 'palavra', 'tartufo'],
#  ['la', 'Maison', 'est', 'moi', 'cest', 'vous'],
#  ['den', 'sortir'],
#  ['sestro', 'antigo', 'sandice'],
#  ['criar', 'amor', 'casa', 'alheia', 'modo', 'senhora', 'dificilmente'],
#  ['lha',
#   'fazer',
#   'despejar',
#   'sestro',
#   'tirar',
#   'de',
#   'aí',
#   'haver',
#   'calejar'],
#  ['vergonha', 'advertirr', 'imenso', 'casa', 'ocupar'],
#  ['durante', 'estação', 'calmoso', 'concluiremo', 'amável'],
#  ['peregrina',
#   'terror',
#   'proprietário',
#   'caso',
#   'haver',
#   'quase',
#   'distúrbio'],
#  ['porta', 'cérebro', 'adventícia', 'querer', 'entregar', 'casa', 'dona'],
#  ['cedir', 'intenção', 'tomar', 'afinal', 'sandice', 'contentar'],
#  ['cantinho', 'sótão'],
#  ['senhor', 'replicar', 'razão'],
#  ['cansada', 'ceder', 'sótão', 'cansar', 'experimentar'],
#  ['passar',
#   'mansamente',
#   'sótão',
#   'sala',
#   'jantar',
#   'de',
#   'aí',
#   'visita',
#   'resto'],
#  ['deixeme', 'ficar', 'algum'],
#  ['pista', 'mistério'],
#  ['mistério'],
#  ['emendar', 'sandice'],
#  ['vida', 'morte', 'peçolhe', 'minuto'],
#  ['razão', 'pôr', 'rir'],
#  ['hás', 'mesmo'],
#  ['mesmo', 'mesmo'],
#  ['dizer', 'travoulhe'],
#  ['pulso', 'arrastoua', 'entrar', 'fechousar', 'sandice', 'gemeu'],
#  ['súplica', 'grunhiu', 'zanga', 'desenganouse', 'depressa', 'deitar'],
#  ['língua', 'ar', 'surriada', 'andar'],
#  ['capítulo', 'ix'],
#  ['transição'],
#  ['vejam', 'destreza'],
#  ['arte', 'transição', 'livro', 'vejar', 'delírio', 'começar'],
#  ['presença', 'Virgília', 'virgília', 'grão', 'pecar', 'juventude', 'haver'],
#  ['juventude', 'meninice', 'meninice', 'supor', 'nascimento', 'eis', 'chegar'],
#  ['esforço', 'dia', '20', 'outubro', '1805', 'nascer', 'ver', 'juntura'],
#  ['aparente', 'divirtar', 'atenção', 'pausar', 'leitor', 'modo'],
#  ['livro', 'ficar', 'vantagem', 'método', 'rigidez', 'método'],
#  ['verdade', 'método', 'ser', 'indispensável'],
#  ['todavia', 'bom', 'têlo', 'gravata', 'suspensório', 'fresca'],
#  ['soltar', 'vizinho', 'fronteira', 'inspetor'],
#  ['quarteirão', 'eloqüência', 'haver', 'genuína', 'vibrante', 'arte'],
#  ['natural', 'feiticeira', 'tesa', 'engomar', 'chochar', 'ir', 'dia', '20'],
#  ['outubro'],
#  ['capítulo', 'x'],
#  ['dia'],
#  ['dia', 'árvore', 'cuba'],
#  ['brotar',
#   'gracioso',
#   'flor',
#   'nascer',
#   'recebeume',
#   'braço',
#   'pascoela',
#   'insigne'],
#  ['parteira', 'minhota', 'gabar', 'abrir', 'porta', 'mundo', 'geração'],
#  ['inteirar', 'fidalgo', 'impossível', 'pai', 'ouvir', 'declaração'],
#  ['crer', 'todavia', 'sentimento', 'paterno', 'induziu', 'gratificála'],
#  ['meias', 'dobr', 'lavar', 'enfaixar', 'herói', 'casa'],
#  ['prognosticar', 'respeito', 'quadrar', 'sabor', 'tio'],
#  ['João',
#   'antigo',
#   'oficial',
#   'infantaria',
#   'achavame',
#   'certo',
#   'olhar',
#   'bonaparte'],
#  ['pai', 'ouvir', 'náuseo', 'tio', 'ildefonso', 'simples'],
#  ['padre', 'farejavame', 'cônegar'],
#  ['cônegar', 'haver'],
#  ['dizer', 'parecer', 'orgulho', 'admirar', 'deus'],
#  ['destinar', 'bispado', 'verdade', 'bispado', 'impossível'],
#  ['manor', 'bento'],
#  ['pai', 'responder'],
#  ['deus', 'quiser', 'alçavame', 'ar', 'intentasse', 'mostrarme'],
#  ['cidade', 'mundo', 'perguntar', 'parecer'],
#  ['inteligente', 'bonito'],
#  ['dizer', 'coisa', 'alto'],
#  ['ouvir', 'narrar', 'ano', 'ignoro', 'mor', 'pormenor'],
#  ['famoso',
#   'dia',
#   'vizinhança',
#   'vir',
#   'mandar',
#   'cumprimentar',
#   'recémnascido'],
#  ['durante', 'primeiro', 'semana', 'muito', 'visita', 'casa'],
#  ['haver',
#   'cadeirinha',
#   'trabalhar',
#   'aventouse',
#   'muito',
#   'casaca',
#   'calção'],
#  ['conto', 'mimos', 'beijo', 'admiração', 'bênção'],
#  ['contar', 'acabar', 'capítulo', 'preciso', 'acabálo'],
#  ['item'],
#  ['batizar', 'referir', 'respeito'],
#  ['galharda', 'festa', 'ano', 'seguinte', '1806', 'batizeime', 'igreja'],
#  ['domingo',
#   'terçafeira',
#   'março',
#   'dia',
#   'claro',
#   'luminoso',
#   'puro',
#   'ser',
#   'padrinho'],
#  ['coronel', 'Rodrigues', 'Matos', 'senhora', 'outro', 'descendir', 'velha'],
#  ['família',
#   'norte',
#   'honrar',
#   'deveras',
#   'sangue',
#   'eles',
#   'correr',
#   'veia',
#   'outrora'],
#  ['derramar', 'guerra', 'holanda', 'cuir', 'nome'],
#  ['primeiro', 'coisa', 'aprender', 'dizer', 'muito', 'graça', 'revelar'],
#  ['algum', 'talento', 'precoce', 'haver', 'pessoa', 'estranho'],
#  ['obrigar', 'recitálo'],
#  ['nhonhô', 'diga', 'senhor'],
#  ['chamar', 'padrinho'],
#  ['padrinho', 'excelentíssimo'],
#  ['senhor',
#   'coronel',
#   'Paulo',
#   'vaz',
#   'lobo',
#   'césar',
#   'Andrade',
#   'Sousa',
#   'Rodrigues',
#   'Matos'],
#  ['madrinha',
#   'excelentíssima',
#   'senhor',
#   'd',
#   'Maria',
#   'Luísa',
#   'Macedo',
#   'Resende',
#   'Sousa'],
#  ['Rodrigues', 'Matos'],
#  ['esperto', 'menino'],
#  ['exclamar', 'ouvinte'],
#  ['esperto', 'concordar'],
#  ['pai', 'olho', 'babavamselhe', 'orgulho', 'espalmar', 'mão'],
#  ['cabeça', 'fitavamer', 'longo', 'namorar', 'cheio', 'si'],
#  ['item', 'começar', 'andar'],
#  ['apressar', 'natureza', 'obrigavamme'],
#  ['agarrar', 'cadeira', 'pegavamme', 'fralda', 'davamme', 'carrinho', 'pau'],
#  ['nhonhô', 'diziame', 'mucama', 'atrair', 'chocalho', 'lata'],
#  ['mãe', 'agitar', 'eu', 'ir', 'frente', 'cair', 'cair', 'acolá', 'andar'],
#  ['provavelmente', 'andar', 'fiquei', 'andar'],
#  ['capítulo', 'xi', 'menino', 'pai'],
#  ['homem'],
#  ['crescir', 'em', 'isso', 'família'],
#  ['intervir', 'cresci', 'naturalmente', 'crescer', 'magnólia', 'gato'],
#  ['gato', 'matreiro', 'magnólia', 'inquieta'],
#  ['infância', 'poeta', 'dizer', 'menino', 'pai', 'homem'],
#  ['verdade', 'veja', 'lineamento', 'menino'],
#  ['ano', 'merecerar'],
#  ['alcunha', 'menino', 'diabo', 'verdadeiramente'],
#  ['maligno', 'arguto', 'indiscreto', 'traquina', 'voluntarioso'],
#  ['dia', 'quebrar', 'cabeça', 'escrar', 'negar', 'colher'],
#  ['doce', 'coco', 'fazer', 'contente', 'malefício', 'deitar'],
#  ['punhado', 'cinza', 'tacho', 'satisfeito', 'travessura'],
#  ['mãe', 'escrar', 'estragarar', 'doce', 'pirraça', 'ter'],
#  ['ano', 'prudênciar', 'moleque', 'casa', 'cavalo', 'dias', 'punha'],
#  ['mão',
#   'chão',
#   'receber',
#   'cordel',
#   'queixo',
#   'guisa',
#   'freio',
#   'trepavalhar'],
#  ['dorso', 'varinha', 'mão', 'fustigavao', 'dar', 'volta', 'outro'],
#  ['obedecer', 'gemer', 'obedecia', 'palavra'],
#  ['ai', 'nhonhô', 'retorquiar', 'calar', 'boca', 'besta'],
#  ['esconder',
#   'chapéu',
#   'visita',
#   'deitar',
#   'rabo',
#   'papel',
#   'pessoa',
#   'grave',
#   'puxar'],
#  ['rabicho', 'cabeleira', 'beliscão', 'braço', 'matrona'],
#  ['muito',
#   'façanha',
#   'jaez',
#   'ser',
#   'mostra',
#   'gênio',
#   'indócil',
#   'dever',
#   'crer'],
#  ['ser', 'expressão', 'espírito', 'robusto', 'pai', 'tinhame'],
#  ['admiração', 'repreendiar', 'vista', 'gente', 'faziao', 'simples'],
#  ['formalidade', 'particular', 'davame', 'beijo'],
#  ['concluar', 'de', 'aqui'],
#  ['levar', 'resto', 'vida', 'quebrar', 'cabeça'],
#  ['esconderlhe', 'chapéu', 'opiniático', 'egoísta', 'contemptor', 'homem'],
#  ['passar', 'esconderlhe', 'chapéu', 'algum', 'eles'],
#  ['puxei', 'rabicho', 'cabeleiro'],
#  ['outrossim', 'afeiçoeime'],
#  ['contemplação',
#   'injustiça',
#   'humano',
#   'inclineime',
#   'atenuála',
#   'explicála'],
#  ['classifiqueia', 'parte', 'entendêla', 'padrão', 'rígir'],
#  ['sabor',
#   'circunstância',
#   'lugar',
#   'mãe',
#   'doutrinavamer',
#   'modo',
#   'faziame'],
#  ['decorar', 'preceito', 'oração', 'sentir', 'oração'],
#  ['governar', 'nervo', 'sangue', 'regra', 'perder', 'espírito'],
#  ['viver', 'tornar', 'vã', 'fórmula', 'manhã', 'mingau', 'noite'],
#  ['cama', 'pedir', 'deu', 'perdoar', 'perdoar'],
#  ['devedor', 'manhã', 'noite', 'maldade', 'pai'],
#  ['passado',
#   'alvoroço',
#   'davame',
#   'pancadinha',
#   'cara',
#   'exclamar',
#   'rir',
#   'ah'],
#  ['brejeiro', 'ah', 'brejeirer'],
#  ['pai', 'adoravame', 'mãe'],
#  ['senhora', 'fraco', 'cérebro', 'coração', 'assaz', 'crédula'],
#  ['sinceramente',
#   'piedoso',
#   'caseira',
#   'apesar',
#   'bonito',
#   'modesto',
#   'apesar'],
#  ['abastar', 'temente', 'trovoada', 'marido', 'marido', 'terra', 'deu'],
#  ['colaboração',
#   'de',
#   'esse',
#   'criatura',
#   'nascer',
#   'educação',
#   'ter',
#   'algum'],
#  ['vicioso', 'incompleta', 'parte', 'negativo', 'tio'],
#  ['cônegar', 'reparo', 'irmão', 'dizialhe', 'dar'],
#  ['liberdade', 'ensino', 'afeição', 'emendar', 'pai', 'responder'],
#  ['aplicar', 'educação', 'inteiramente', 'alto', 'usar'],
#  ['modo', 'confundir', 'irmão', 'iludiase', 'se'],
#  ['envolta', 'transmissão'],
#  ['educação', 'haver', 'estranho', 'doméstico', 'vir', 'pai'],
#  ['vejamos',
#   'tio',
#   'de',
#   'ele',
#   'João',
#   'homem',
#   'língua',
#   'soltar',
#   'vida',
#   'galante'],
#  ['conversa', 'picaresco', 'ano', 'entrar', 'admitirme', 'anedota', 'real'],
#  ['eivar', 'obscenidade', 'imundície', 'respeitar'],
#  ['adolescência', 'respeitar', 'batina', 'irmão', 'diferença'],
#  ['fugir', 'enveredar', 'assunto', 'escabroso', 'deixavame'],
#  ['entender', 'princípio', 'entender', 'enfim', 'achandolhe', 'graça'],
#  ['certo', 'procurar', 'gostar', 'eu', 'davame'],
#  ['doce', 'levavame', 'passeio', 'casa', 'ir', 'passar', 'dia', 'pouco'],
#  ['acontecer', 'achálo', 'fundo', 'chácara', 'lavadouro', 'palestrar'],
#  ['escrava', 'bater', 'roupa', 'desfiar', 'anedota', 'dito'],
#  ['pergunta', 'estalar', 'risada', 'ninguém', 'ouvir', 'lavadouro'],
#  ['ficar', 'casa', 'preta', 'tanga', 'ventre', 'arregaçarlhe'],
#  ['palmo', 'vestido', 'tanque', 'inclinar'],
#  ['peça', 'roupa', 'batêla', 'ensaboála', 'torcêla', 'ir', 'ouvir'],
#  ['redargüir', 'pilhéria', 'tio', 'João', 'comentála'],
#  ['palavra'],
#  ['Cruz', 'diabo', 'sinhô', 'João'],
#  ['diabo'],
#  ['diferente', 'tio', 'cônegar'],
#  ['ter', 'muito', 'austeridade', 'pe', 'ureze', 'dote', 'realçar'],
#  ['espírito', 'alto', 'compensar', 'espírito', 'medíocre', 'homem'],
#  ['vir', 'substancial', 'igreja', 'ver', 'externo', 'hierarquia'],
#  ['preeminência', 'sobrepeliz', 'circunflexão', 'vir', 'sacristia'],
#  ['altar', 'lacuna', 'ritual', 'excitavao', 'infração'],
#  ['mandamento', 'tanto', 'ano', 'distância', 'certo', 'poder'],
#  ['atinar', 'facilmente', 'trecho', 'tertuliano', 'expor', 'titubear'],
#  ['história',
#   'símbolo',
#   'nicéia',
#   'ninguém',
#   'festa',
#   'cantadas',
#   'saber',
#   'melhor'],
#  ['caso', 'cortesia', 'dever', 'oficiante', 'cônegar', 'único'],
#  ['ambição', 'vida', 'dizer', 'coração', 'dignidade'],
#  ['aspirar',
#   'piedoso',
#   'severo',
#   'costume',
#   'minucioso',
#   'observância',
#   'regra'],
#  ['frouxo', 'acanhar', 'subalterno', 'possuir', 'virtude', 'exemplar'],
#  ['carecia', 'absolutamente', 'força', 'incutir', 'impor'],
#  ['dizer', 'tia'],
#  ['materna', 'd', 'emerenciana', 'aliás', 'pessoa', 'autoridade', 'ter'],
#  ['eu', 'diferençavase', 'grandemente', 'viver'],
#  ['companhia', 'ano', 'parente', 'íntimo', 'merecer', 'pena'],
#  ['citar', 'vida', 'comum', 'intermitente', 'claro'],
#  ['separação', 'importar', 'expressão', 'doméstico', 'ficar'],
#  ['indicar', 'vulgaridade', 'caracter', 'amor', 'aparência', 'rutilante'],
#  ['arruído', 'frouxidão', 'vontade', 'domínio', 'capricho', 'terra'],
#  ['estrume', 'nascer', 'flor'],
#  ['capítulo', 'xii', 'episódio'],
#  ['1814'],
#  ['passar', 'adiante'],
#  ['contar', 'sumariamente', 'galante', 'episódio', '1814', 'ter', 'ano'],
#  ['napoleão', 'nascer'],
#  ['esplendor', 'glória', 'imperador', 'granjear'],
#  ['inteiramente', 'admiração', 'homem', 'pai', 'força', 'persuadir'],
#  ['nobreza', 'acabar', 'persuadindose', 'se', 'nutria', 'ódio'],
#  ['puramente', 'mental', 'motivo', 'renhida', 'contenr', 'casa'],
#  ['tio', 'João', 'espírito', 'classe', 'simpatia', 'ofício', 'perdoar'],
#  ['déspota', 'admirar', 'general', 'tio', 'padre', 'inflexível'],
#  ['corsar', 'parente', 'dividiamse', 'de', 'aí', 'controvérsia', 'rusga'],
#  ['chegar', 'rio', 'janeiro'],
#  ['notícia', 'queda', 'napoleão', 'haver', 'naturalmente', 'abalar'],
#  ['casa', 'nenhum', 'chasco', 'remoquar', 'vencido', 'testemunha', 'regozijo'],
#  ['público', 'julgar', 'decoroso', 'silêncio', 'bater', 'palma'],
#  ['população',
#   'cordialmente',
#   'alegre',
#   'regatear',
#   'demonstração',
#   'afeto',
#   'real'],
#  ['família', 'haver', 'iluminação', 'salvo', 'tedeum', 'cortejo', 'aclamação'],
#  ['figurei', 'em', 'esse', 'dia', 'espadim', 'padrinho', 'dera', 'dia'],
#  ['santo', 'antônio', 'francamente', 'interessavamer', 'espadim', 'queda'],
#  ['bonaparte', 'esquecer', 'fenômeno', 'deixei', 'pensar', 'comigo'],
#  ['espadim', 'espar', 'napoleão', 'noter'],
#  ['ouvir', 'discurso', 'vivo', 'li', 'muito', 'página', 'rumoroso', 'idéia'],
#  ['grande', 'palavra', 'fundo', 'aplauso', 'arrancar'],
#  ['boca', 'ecoar', 'alguma', 'conceito', 'experimentar'],
#  ['vaiter', 'cuir'],
#  ['espadim'],
#  ['contentar', 'família'],
#  ['quinhão',
#   'anônimo',
#   'regozijo',
#   'público',
#   'entender',
#   'oportuno',
#   'indispensável'],
#  ['celebrar', 'destituição', 'imperador', 'jantar', 'jantar', 'ruído'],
#  ['aclamação', 'chegar', 'ouvido', 'alteza'],
#  ['ministros',
#   'dizer',
#   'fazer',
#   'vir',
#   'abaixo',
#   'velho',
#   'prataria',
#   'herdar',
#   'avô'],
#  ['Luís', 'cuba', 'vir', 'toalha', 'flandr', 'jarra', 'índia', 'matouse'],
#  ['capado', 'encomendaramse', 'madr', 'ajudar', 'compota', 'marmelada'],
#  ['lavaramse',
#   'arearamse',
#   'poliramse',
#   'sala',
#   'escadas',
#   'castiçal',
#   'arandela'],
#  ['vasta', 'manga', 'vidro', 'aparelho', 'luxo', 'clássico'],
#  ['dar', 'hora', 'achousar', 'reunir'],
#  ['sociedade', 'seleto', 'juizdefora', 'oficial', 'militar'],
#  ['comerciante', 'letrado', 'funcionário', 'administração'],
#  ['mulher', 'filha', 'comungar', 'desejo', 'atolar'],
#  ['memória', 'bonaparte', 'papo', 'peru', 'jantar'],
#  ['tedeum', 'dizer', 'letrado', 'presente'],
#  ['dr',
#   'vilaça',
#   'glosador',
#   'insigne',
#   'acrescentar',
#   'prato',
#   'casa',
#   'acepipe'],
#  ['muso', 'lembramer', 'ser', 'lembramer', 'erguerse'],
#  ['longo',
#   'cabeleira',
#   'rabicho',
#   'casaca',
#   'seda',
#   'esmeralda',
#   'dedo',
#   'pedir'],
#  ['tio',
#   'padre',
#   'repetir',
#   'mote',
#   'repetir',
#   'mote',
#   'cravar',
#   'olho',
#   'testa'],
#  ['senhora', 'tossir', 'alçar', 'mão', 'fechada', 'dedo'],
#  ['índice', 'apontar', 'teto', 'pôr', 'compor', 'devolver', 'mote'],
#  ['glosar', 'gloso', 'jurar', 'deuse', 'acabar'],
#  ['pedir', 'mote', 'davamlho', 'glosavao', 'prontamente', 'pedir', 'outro'],
#  ['outro', 'senhora', 'presente', 'calar'],
#  ['admiração'],
#  ['senhora', 'retorquiar'],
#  ['modestamente', 'vilaça', 'ouvir', 'bocage', 'ouvir'],
#  ['século', 'Lisboa', 'facilidade', 'verso', 'luta'],
#  ['hora', 'botequim', 'nicola', 'glosarmos', 'palma'],
#  ['bravo', 'imenso', 'talento', 'bocage', 'dizer', 'haver', 'dia', 'senhora'],
#  ['duquês', 'cadaval'],
#  ['palavra', 'último'],
#  ['expressas', 'muito', 'ênfase', 'produzir', 'assembléia', 'frêmito'],
#  ['admiração', 'pasmo', 'homem', 'dado', 'simples', 'pleitear'],
#  ['poeta', 'discretear', 'duquesa', 'bocage', 'cadaval', 'contato'],
#  ['homem',
#   'damas',
#   'sentiamse',
#   'superfina',
#   'varão',
#   'olhavamno',
#   'respeito'],
#  ['inveja', 'raro', 'incredulidade', 'entretanto', 'ir', 'acumular'],
#  ['adjetivo', 'adjetivo', 'advérbio', 'advérbio', 'desfiar', 'rima'],
#  ['tirano', 'usurpador', 'sobremesa', 'ninguém', 'pensar'],
#  ['comer',
#   'intervalo',
#   'glosa',
#   'correr',
#   'burburinho',
#   'alegre',
#   'palavrear'],
#  ['estômago', 'satisfeito', 'olho', 'mole', 'úmir', 'vivo', 'cálir'],
#  ['espreguiçavamse', 'saltitar', 'ponta', 'mesa', 'atulhar', 'doce'],
#  ['fruta', 'ananás', 'fatia', 'melão', 'talhadas', 'compoteira'],
#  ['cristal',
#   'deixar',
#   'doce',
#   'coco',
#   'finamente',
#   'ralar',
#   'amarelo',
#   'gema'],
#  ['melado', 'escuro', 'grosso', 'queijo', 'cará'],
#  ['riso',
#   'jovial',
#   'amplo',
#   'desabotoar',
#   'riso',
#   'família',
#   'vir',
#   'quebrar'],
#  ['gravidade', 'político', 'banquete', 'interesse', 'comum', 'agitavamse'],
#  ['pequeno', 'particular', 'moça', 'falar', 'modinha', 'haver'],
#  ['cantar', 'cravo', 'minuete', 'solo', 'inglês', 'faltar', 'matronar'],
#  ['prometesse', 'bailar', 'oitavado', 'compasso', 'mostrar', 'folgara'],
#  ['bom',
#   'tempo',
#   'criança',
#   'sujeito',
#   'pé',
#   'eu',
#   'dar',
#   'outro',
#   'notícia',
#   'recente'],
#  ['negro', 'estar', 'vir', 'carta', 'receber', 'loanda'],
#  ['carta', 'sobrinho', 'dizer', 'negociar', 'cerca', 'quarenta', 'cabeça'],
#  ['carta', 'traziaasr', 'justamente', 'algibeira', 'ler'],
#  ['ocasião', 'afiançar', 'poder', 'contar', 'viagem'],
#  ['negro'],
#  ['trás', 'trás', 'trás'],
#  ['vilaça', 'bater', 'mão', 'rumor', 'cessar', 'súbito'],
#  ['estacar', 'orquestra', 'olho', 'voltar', 'glosador', 'ficar'],
#  ['aconchear', 'mão', 'orelha', 'perder', 'palavra', 'mor'],
#  ['glosa', 'ter', 'riso', 'aplauso', 'trivial', 'cândido'],
#  ['eu', 'solitário'],
#  ['deslembrado', 'namorar', 'certo', 'compota', 'paixão', 'gloso'],
#  ['ficar', 'contente', 'esperar', 'ser', 'último', 'sobremesa'],
#  ['continuar', 'intatar', 'ninguém', 'lembrar', 'voz', 'pai'],
#  ['cabeceira',
#   'saborear',
#   'gole',
#   'extenso',
#   'alegria',
#   'conviva',
#   'miravase'],
#  ['carão',
#   'alegre',
#   'prato',
#   'flor',
#   'deliciavase',
#   'familiaridade',
#   'travar'],
#  ['distante', 'espírito', 'influxo', 'jantar', 'ver'],
#  ['arrastar', 'olho', 'compota', 'de', 'ele', 'compota', 'pedirlhe'],
#  ['ma', 'servir', 'faziao', 'ver', 'viase', 'se'],
#  ['glosa',
#   'Sucediamse',
#   'bátega',
#   'dáguo',
#   'obrigandome',
#   'recolher',
#   'desejo'],
#  ['pedir', 'pacientei', 'pude', 'pude', 'pedir', 'voz', 'baixo', 'doce'],
#  ['enfim', 'bradei', 'berrei', 'bati', 'pé', 'pai', 'capaz'],
#  ['sol', 'lho', 'exigisse', 'chamar', 'escravo', 'servir', 'doce'],
#  ['tia', 'emerenciano', 'arrancarame', 'cadeira', 'entregarame', 'escrar'],
#  ['obstante', 'grito', 'repelão'],
#  ['outro', 'delito'],
#  ['glosador', 'retardar', 'compota', 'dera', 'causa', 'exclusão', 'bastar'],
#  ['cogitar', 'vingança', 'ser', 'exemplar'],
#  ['algum', 'maneira', 'tornar', 'ridículo', 'homem', 'gravar', 'dr'],
#  ['vilaça', 'medir', 'lento', 'quarenta', 'ano', 'casado', 'pai', 'contentar'],
#  ['rabo', 'papel', 'rabicho', 'cabeleira', 'haver', 'pior', 'entrar'],
#  ['espreitálo', 'durante', 'resto', 'seguilo', 'chácara', 'aonde'],
#  ['descer',
#   'passear',
#   'vio',
#   'conversar',
#   'd',
#   'eusébio',
#   'irmã',
#   'sargentomor'],
#  ['domingue', 'robusta', 'donzelono', 'bonito', 'feio'],
#  ['zangar'],
#  ['senhor', 'dizer'],
#  ['sina', 'crer', 'bom', 'morrer'],
#  ['ter', 'penetrar', 'pequeno'],
#  ['moita', 'luscofusco', 'seguio', 'vilaça', 'levar', 'olho', 'chispa'],
#  ['vinho', 'volúpia'],
#  ['deixeme', 'dizer'],
#  ['ninguém', 'ver', 'morrer'],
#  ['anjo', 'idéia', 'morrerei', 'dizer'],
#  ['morro', 'dia', 'paixão', 'saudade'],
#  ['d', 'euséber', 'levar', 'lenço'],
#  ['olho',
#   'glosador',
#   'vasculhar',
#   'memória',
#   'algum',
#   'pedaço',
#   'literário',
#   'achar'],
#  ['verifiquei', 'ópera', 'judeu'],
#  ['chor', 'queira'],
#  ['dia', 'amanheça', 'aurora'],
#  ['dizer', 'puxoua', 'si'],
#  ['resistir', 'deixouse', 'unir', 'rosto', 'ouvir', 'estalar'],
#  ['leve', 'beijo', 'medroso', 'beijo'],
#  ['dr', 'vilaça', 'dar', 'beijo', 'd'],
#  ['euséber', 'bradei', 'correr', 'chácara'],
#  ['estouro', 'palavra'],
#  ['estupefação', 'imobilizar', 'olho', 'espraiavamse', 'banda'],
#  ['trocavamse', 'sorriso', 'segrer', 'socapa', 'mães', 'arrastar', 'filha'],
#  ['pretextar',
#   'sereno',
#   'pai',
#   'puxoumar',
#   'orelha',
#   'disfarçadamente',
#   'irritado'],
#  ['deveras', 'indiscrição', 'dia', 'seguinte', 'almoço', 'lembrar', 'caso'],
#  ['sacudiumar', 'nariz', 'rir', 'ah', 'brejeiro', 'ah', 'brejeirer'],
#  ['capítulo', 'xiii'],
#  ['salto'],
#  ['unamos', 'pé', 'dar'],
#  ['salto', 'escola', 'enfadonha', 'escola', 'aprender', 'ler', 'escrever'],
#  ['contar', 'cacholeta', 'apanhála', 'diabrura', 'morro'],
#  ['praia', 'ser', 'propício', 'ocioso'],
#  ['ter', 'amargura', 'ter'],
#  ['ralho', 'castigo', 'lição', 'árduo', 'longo'],
#  ['levar', 'pesar', 'palmatória', 'ó', 'palmatória', 'terror'],
#  ['dia', 'pueri', 'compelle', 'intrare', 'velho'],
#  ['mestre',
#   'ossudo',
#   'calvo',
#   'incutir',
#   'cérebro',
#   'alfabeto',
#   'prosóder',
#   'sintaxe'],
#  ['saber', 'bento', 'palmatório', 'praguejado', 'moderno'],
#  ['dera', 'ficar', 'jugo', 'alma', 'imberber', 'ignorância'],
#  ['espadim', 'espadim', '1814', 'alto', 'espada', 'napoleão'],
#  ['queria', 'afinal', 'velho', 'mestre', 'primeiro', 'letra', 'lição', 'cor'],
#  ['compostura', 'aula', 'vida', 'último'],
#  ['letra', 'diferença', 'metia', 'medo', 'meteste', 'zanga'],
#  ['vejote', 'entrar', 'sala', 'chinela', 'couro', 'branco'],
#  ['capote',
#   'lenço',
#   'mão',
#   'calvo',
#   'mostrar',
#   'barba',
#   'rapar',
#   'vejote',
#   'sentar',
#   'bufar'],
#  ['grunhirr',
#   'absorver',
#   'pitado',
#   'inicial',
#   'chamarno',
#   'lição',
#   'fizestar'],
#  ['durante', 'ano', 'calar', 'obscuro', 'pontual', 'meter', 'casinha'],
#  ['rua', 'piolho', 'enfadar', 'mundo', 'mediocridade', 'dia'],
#  ['mergulho', 'treva', 'ninguém', 'chorar', 'salvo', 'preto', 'velho'],
#  ['ninguém', 'dever', 'rudimento', 'escrita'],
#  ['chamavase', 'ludgero', 'mestre'],
#  ['escreverlhar', 'nome', 'página', 'ludgero', 'barato', 'nome', 'funesto'],
#  ['servio', 'menino', 'eterno', 'mote', 'chufa', 'quincas', 'borba'],
#  ['cruel', 'pobre', 'homem', 'semana', 'haver'],
#  ['deixar', 'algibeira', 'calça', 'larga', 'calça', 'enfiar', 'gaveta'],
#  ['mesa', 'pé', 'tinteiro', 'barato', 'morta', 'encontrar'],
#  ['hora', 'aula', 'dar', 'pulo', 'circular', 'olho', 'chamejante', 'diziano'],
#  ['último', 'nome', 'éramos', 'sevandija', 'capadócio', 'malcriar', 'moleque'],
#  ['trem', 'rosnar', 'quincas', 'borba', 'deixavase'],
#  ['olho', 'espetar', 'ar'],
#  ['flor', 'quincas', 'borba'],
#  ['infância', 'vida', 'achar', 'menino', 'gracioso'],
#  ['inventivo', 'travesso', 'flor', 'escola', 'senão', 'cidade'],
#  ['mãe', 'viúvo', 'algum', 'adorar', 'filho', 'traziao', 'amimar'],
#  ['assear', 'enfeitar', 'vistoso', 'pajem', 'pajem', 'deixar', 'gazear'],
#  ['escola', 'caçar', 'ninho', 'pássaros', 'perseguir', 'lagartixa', 'morro'],
#  ['livramento', 'conceição', 'simplesmente', 'arruar', 'toa', 'peralta'],
#  ['emprego', 'imperador', 'gosto', 'quincas', 'borba', 'imperador'],
#  ['festa', 'espírito', 'santo', 'resto', 'jogo', 'Pueris', 'escolhia'],
#  ['papel', 'rei', 'ministro', 'general', 'supremacia', 'ser', 'ter'],
#  ['garbo',
#   'traquina',
#   'gravidade',
#   'certo',
#   'magnificência',
#   'atitude',
#   'meneio'],
#  ['dizer', 'suspendamos', 'pena', 'adianter', 'sucesso', 'ir'],
#  ['salto', '1822', 'data', 'independência', 'político', 'cativeiro'],
#  ['pessoal'],
#  ['capítulo', 'xiv'],
#  ['beijo'],
#  ['ter', 'dezessete', 'ano', 'pungiame'],
#  ['buçozinho', 'forcejar', 'trazer', 'bigode', 'olho', 'vivo', 'resoluto'],
#  ['ser',
#   'feição',
#   'verdadeiramente',
#   'máscular',
#   'ostentassar',
#   'certo',
#   'arrogância'],
#  ['distinguir', 'criança', 'fumos', 'homem', 'homem'],
#  ['ar', 'menino', 'cabo', 'lir', 'garção', 'lir', 'audaz', 'entrar', 'vida'],
#  ['bota', 'espora', 'chicote', 'mão', 'sangue', 'veia', 'cavalgar', 'corcel'],
#  ['nervoso', 'rijo', 'veloz', 'corcel', 'antigo', 'balada', 'romantismo'],
#  ['buscar', 'castelo', 'medieval', 'rua', 'século', 'mau'],
#  ['estafar', 'preciso', 'deitálo', 'margem', 'realismo'],
#  ['vir', 'achar', 'comer', 'lazeira', 'verme', 'compaixão', 'transportar'],
#  ['livro'],
#  ['garção', 'bonito'],
#  ['airoso', 'abastar', 'facilmente', 'imaginar', 'dama', 'inclinar'],
#  ['eu', 'fronte', 'pensativo', 'levantar', 'eu', 'olho', 'cobiçoso'],
#  ['cativar', 'digar', 'livro'],
#  ['car', 'intenção', 'intenção', 'castíssimo', 'ir', 'haver'],
#  ['cativar', 'dama', 'espanhol', 'marcela', 'linda'],
#  ['marcela', 'chamar', 'rapaz', 'ter', 'razão', 'rapaz'],
#  ['filha', 'hortelão', 'astúria', 'dissemo', 'mesmo', 'dia', 'sinceridade'],
#  ['opinião', 'aceitar', 'nascer', 'letrado', 'madri', 'vítima', 'invasão'],
#  ['francês', 'ferir', 'encarcerar', 'espingardear', 'ter', 'ano'],
#  ['coso', 'españa', 'ser'],
#  ['pai', 'letrar', 'hortelão', 'verdade', 'marcela', 'possuir'],
#  ['inocência', 'rústico', 'chegar', 'entender', 'moral', 'código', 'moça'],
#  ['léper', 'escrúpulo', 'tolher', 'austeridade'],
#  ['permitir', 'arrastar', 'rua', 'estouvamento', 'berlinda', 'luxuoso'],
#  ['impaciente', 'amiga', 'dinheiro', 'rapaz', 'ano', 'morrer', 'amor'],
#  ['certo', 'xavier', 'sujeitar', 'abastar', 'tísico', 'pérola'],
#  ['ver', 'rocio'],
#  ['noite', 'luminária', 'constar', 'declaração', 'independência'],
#  ['festa', 'primavera', 'amanhecer', 'alma', 'público', 'éramos', 'rapaz'],
#  ['vínhar', 'infância', 'arrebatamento', 'juventude', 'ver'],
#  ['sair', 'cadeirinha', 'airoso', 'vistoso', 'corpo', 'esbeltor', 'ondulante'],
#  ['desgarrer', 'algum', 'acharar', 'mulher', 'pura', 'segueme', 'dizer'],
#  ['pajem', 'seguir', 'pajem', 'outro', 'ordem', 'ser'],
#  ['dar', 'deixeime', 'namorar', 'vibrante', 'cheio', 'primeiro', 'aurora'],
#  ['chamaramlhe', 'linda', 'marcela', 'lembroume', 'ouvirir', 'nome', 'tio'],
#  ['João', 'fiquei', 'confessar', 'fiquei', 'tonto'],
#  ['dia', 'perguntoumir'],
#  ['tio', 'segredo', 'querer', 'ceia', 'moça', 'cajueiro'],
#  ['casa', 'marcela', 'xavier', 'tubérculo', 'presider', 'banquete'],
#  ['noturno', 'comir', 'ter', 'olho', 'dona'],
#  ['casa', 'gentil', 'espanhola', 'haver', 'meia', 'dúzia', 'mulher'],
#  ['partido', 'bonita', 'cheia', 'graça', 'espanhol'],
#  ['entusiasmo', 'gole', 'vinho', 'gênio', 'imperioso', 'estouvar'],
#  ['levar', 'único', 'saída', 'porta', 'rua', 'dizer', 'tio'],
#  ['esperar', 'instante', 'tornei', 'subir', 'escada'],
#  ['esquecer', 'algum', 'perguntar'],
#  ['marcela', 'pé', 'patamar'],
#  ['lenço'],
#  ['ir', 'abrirme'],
#  ['tornar', 'sala', 'segureilher', 'mão', 'puxeia', 'eu', 'deilhe', 'beijo'],
#  ['dizer', 'algum', 'gritar', 'chamar', 'alguém'],
#  ['descir', 'escada', 'veloz', 'tufão', 'incerto'],
#  ['ébrio'],
#  ['capítulo', 'xv'],
#  ['marcela'],
#  ['gastar', 'trinta', 'dia'],
#  ['rocio', 'coração', 'marcela', 'cavalgar', 'corcel', 'cego', 'desejo'],
#  ['asno', 'paciência', 'manhoso', 'teimoso', 'verdade', 'haver'],
#  ['meio', 'granjear', 'vontade', 'mulher', 'violento', 'touro', 'Europa'],
#  ['insinuativo', 'cisne', 'leda', 'chuva', 'ouro', 'danae', 'invento'],
#  ['padre', 'zeu', 'estar', 'moda', 'ficar', 'trocado', 'cavalo'],
#  ['asno', 'dir', 'traça', 'urdi', 'peita', 'alternativa'],
#  ['confiança', 'temor', 'espera', 'baldar', 'de', 'esse', 'coisa'],
#  ['preliminar', 'afirmolhe', 'asno', 'digno', 'corcel', 'asno', 'sancho'],
#  ['deveras',
#   'filósofo',
#   'levar',
#   'casa',
#   'de',
#   'ela',
#   'citar',
#   'período',
#   'apeeime'],
#  ['batilhe', 'anca', 'mandeio', 'pastar'],
#  ['comoção'],
#  ['juventude', 'doce', 'dever', 'criação', 'bíblico', 'efeito', 'sol'],
#  ['imaginar', 'efeito', 'sol', 'bater', 'chapa', 'face', 'mundo'],
#  ['flor', 'mesmo', 'leitor', 'amigo', 'algum', 'contaste'],
#  ['ano', 'deve', 'lembrarte'],
#  ['fase', 'paixão'],
#  ['ligação', 'outro', 'nome', 'nome', 'curo', 'fase', 'consular'],
#  ['fase', 'imperial', 'curto', 'regemo', 'xavier'],
#  ['jamais', 'acreditasse', 'dividir', 'comigo', 'governo', 'roma'],
#  ['credulidade', 'resistir', 'evidência', 'xavier', 'depor', 'insígnia'],
#  ['concentrar', 'poder', 'mão', 'fase', 'cesariana'],
#  ['universo',
#   'ai',
#   'triste',
#   'graça',
#   'foime',
#   'preciso',
#   'coligir',
#   'dinheiro'],
#  ['multiplicálo', 'inventálo', 'explorei', 'largueza', 'pai'],
#  ['davamer', 'pedir', 'repreensão', 'demor', 'frieza', 'dizer'],
#  ['rapaz', 'extremo', 'chegar'],
#  ['abuso', 'restringir', 'franqueza'],
#  ['recorri', 'mãe', 'induzer', 'desviar', 'algum', 'dar'],
#  ['escondidas', 'lanceer', 'mão', 'recurso', 'entrar', 'sacar'],
#  ['herança',
#   'pai',
#   'assinar',
#   'obrigação',
#   'dever',
#   'resgatar',
#   'dia',
#   'usura'],
#  ['verdade', 'diziame', 'marcela'],
#  ['levar', 'algum', 'seda', 'algum', 'jóia', 'verdade', 'brigar'],
#  ['comigo', 'fazer', 'presente', 'caro'],
#  ['jóia', 'dizer'],
#  ['contemplála', 'dedo', 'procurar', 'bom', 'luz', 'ensaiála', 'si', 'rir'],
#  ['beijarme', 'reincidência', 'impetuoso', 'sincer', 'protestar'],
#  ['derramavaselhe', 'felicidade', 'olho', 'sentiame', 'feliz', 'vêla'],
#  ['gostar', 'antigo', 'dobra', 'ouro', 'levavalher', 'quantas'],
#  ['obter', 'marcela', 'Juntavaas', 'caixinha', 'ferro', 'chave'],
#  ['ninguém',
#   'jamais',
#   'saber',
#   'ficar',
#   'escondiaa',
#   'medo',
#   'escravo',
#   'casa'],
#  ['morar', 'cajueiro', 'próprio', 'ser', 'sólir', 'bom', 'móvel'],
#  ['jacarandá', 'lavrar', 'alfaia', 'espelhos', 'jarra', 'baixelo'],
#  ['linda', 'baixela', 'índia', 'doar', 'desembargador', 'baixela', 'diabo'],
#  ['destemer', 'repelão', 'nervo', 'disseor', 'muito', 'próprio', 'dona'],
#  ['dissimular', 'tédio', 'fazer', 'despojo', 'amor'],
#  ...]

# %% [markdown]
# Vamos processar o texto para considerar bigramas. Esta etapa é importante para identificar palavras compostas como "Brás Cubas"

# %%
phrases = Phrases(sent,min_count=1, progress_per=10)

# %%
bigram = Phraser(phrases)
sentences = bigram[sent]
sentences

# %% [markdown]
# Vamos também ver quais as palavras mais frequentes no texto após remover stop-words

# %%
word_freq = defaultdict(int)
for sent in sentences:
    for i in sent:
        word_freq[i] += 1
len(word_freq)
# Out:
# 8741

# %%
sorted(word_freq, key=word_freq.get, reverse=True)[:10]
# Out:
# ['dizer',
#  'capítulo',
#  'ter',
#  'haver',
#  'ser',
#  'homem',
#  'ir',
#  'algum',
#  'olho',
#  'outro']

# %% [markdown]
# #Treinando um modelo Word2Vec
#
# Vamos agora treinar um modelo para retornar as palavras mais próximas dado o contexto da escrita deste conto de machado de assis.
#
# Word2Vec():
# Nesta primeira etapa, configuramos os parâmetros do modelo.
#
# .build_vocab():
# Aqui construímos o vocabulário a partir de uma sequência de frases e assim inicializamos o modelo.
#
# .Train():
# Finalmente, treinamos o modelo.

# %%
import multiprocessing

from gensim.models import Word2Vec
cores = multiprocessing.cpu_count()

# %% [markdown]
# #Estes são os parâmetros do modelo segundo a referência da bilbioteca Gensim:
#
# *   min_count = int - Ignores all words with total absolute frequency lower than this - (2, 100)
# *   window = int - The maximum distance between the current and predicted word within a sentence. E.g. window words on the left and window words on the left of our target - (2, 10)
# *   size = int - Dimensionality of the feature vectors. - (50, 300)
# *   sample = float - The threshold for configuring which higher-frequency words are randomly downsampled. Highly influencial. - (0, 1e-5)
# *   alpha = float - The initial learning rate - (0.01, 0.05)
# *   min_alpha = float - Learning rate will linearly drop to min_alpha as training progresses. To set it: alpha - (min_alpha * epochs) ~ 0.00
# *   negative = int - If > 0, negative sampling will be used, the int for negative specifies how many "noise words" should be drown. If set to 0, no negative sampling is used. - (5, 20)
# *  workers = int - Use these many worker threads to train the model (=faster training with multicore machines)

# %%
w2v_model = Word2Vec(min_count=3,
                     window=5,
                     size=300,
                     sample=1e-3, 
                     alpha=0.03, 
                     min_alpha=0.0007, 
                     negative=20,
                     workers=cores-1)
t = time()

#Vamos contruir o vocabulário
w2v_model.build_vocab(sentences)

print('Time to build vocab: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# Time to build vocab: 0.01 mins

# %%
t = time()

w2v_model.train(sentences, total_examples=w2v_model.corpus_count, epochs=20, report_delay=1)

print('Time to train the model: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# Time to train the model: 0.06 mins

# %%
w2v_model.init_sims(replace=True)

# %% [markdown]
# #Vamos agora verificar a similaridade entre algumas palavras

# %%
w2v_model.wv.most_similar(positive=["brás"])
# Out:
# [('cocheiro', 0.9999237060546875),
#  ('egoísta', 0.9999216198921204),
#  ('descansar', 0.9999199509620667),
#  ('inicial', 0.9999192953109741),
#  ('contemplação', 0.9999191761016846),
#  ('interior', 0.9999179840087891),
#  ('mole', 0.9999179840087891),
#  ('substância', 0.9999163746833801),
#  ('finado', 0.9999162554740906),
#  ('tanoaria', 0.9999161958694458)]

# %%
w2v_model.wv.most_similar(negative=["homem"])
# Out:
# [('___', -0.6152580380439758),
#  ('ver', -0.9986587762832642),
#  ('cuba', -0.9987366795539856),
#  ('mão', -0.998762845993042),
#  ('crer', -0.9988263845443726),
#  ('velho', -0.9988966584205627),
#  ('beijo', -0.9988994598388672),
#  ('passar', -0.9989227056503296),
#  ('mesmo', -0.9989330768585205),
#  ('marcela', -0.998935341835022)]

# %% [markdown]
# #Exercício 1
#
# Agora que você já apredeu a como processar textos e verificar a similaridade entre palavras, verifique quais parâmetros podem de fato alterar os resultdos do modelo. Como podemos melhorar os resultados? E se combinarmos mais de um texto? Qual o resultado?
#
# #Desafio:
# Como podemos fazer analogias com as palavras pesquisadas? Ex: mulher + brás - homem = ?
