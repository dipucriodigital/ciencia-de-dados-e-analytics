# %% [markdown]
# # Configuração inicial

# %%
# Instala versão mais recente da biblioteca matplotlib disponível no Colab no momento de criação deste arquivo.
# Na primeira vez em que for instalado na sessão, precisará reiniciar o runtime
# !pip install matplotlib==3.5.3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: matplotlib==3.5.3 in /usr/local/lib/python3.7/dist-packages (3.5.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from matplotlib==3.5.3) (1.21.6)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib==3.5.3) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib==3.5.3) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib==3.5.3) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib==3.5.3) (7.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/dist-packages (from matplotlib==3.5.3) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib==3.5.3) (4.38.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib==3.5.3) (21.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from kiwisolver>=1.0.1->matplotlib==3.5.3) (4.1.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7->matplotlib==3.5.3) (1.15.0)

# %%
## Carrega bibliotecas utilizadas

import pandas as pd
import numpy as np
import math

import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.patches import Patch, Polygon
from matplotlib.lines import Line2D

from IPython.display import display, Markdown

# %%
## Verifica a versão da matplotlib instalada
mpl.__version__
# Out:
# '3.5.3'

# %%
# Define paleta de cores

# # alternativa A: definição manual das cores a partir de lista de cores em hex
# coresViridis = ["#440154","#3b528b","#21918c","#5ec962","#fde725"]

# alternativa B: definição de cores utilizando palette do próprio matplotlib
# a paleta viridis é robusta para pessoas com daltonismo
vcmap = plt.get_cmap("viridis", 6) # um a mais do que o necessário para evitar utilizar o amarelo

# exibe o mapa de cores
display(vcmap)

# converte o mapa de cores em um vetor, para uso de cores individuais
coresViridis = [mpl.colors.rgb2hex(vcmap(i)) for i in range(6)] # extrai lista de cores em hex
display(coresViridis)

# define uma cor default
corDefault = coresViridis[1]

# Carrega uma folha de estilos (opcional - questões estéticas)
plt.style.use("ggplot")

# Modifica mais alguns parâmetros gráficos (opcional - questões estéticas)
plt.rc("axes", facecolor="#fcfcfc", grid = True)
plt.rc("grid", color = "#f0f0f0")
plt.rc("axes", edgecolor="#cccccc", lw=0.1)

# plt.rcdefaults() # Restaura a configuração default
# Out:
# ['#440154', '#414487', '#2a788e', '#22a884', '#7ad151', '#fde725']

# %% [markdown]
# # Carrega e prepara dados

# %%
# Dados dos países do G20 (includindo Espanha, excluindo União Europaia) obtidos do Banco Mundial:
# https://databank.worldbank.org/G20-pop-gdp-imp-exp-gini/id/d0bc168d
    
# Carrrega dados brutos do G20
G20 = pd.read_csv("https://raw.githubusercontent.com/simonedjb/ccec-vis-info-pub/main/dados/G20-WorldDev-02.csv", 
                  na_values="..",
                  skipfooter=5,
                  engine="python").drop(columns="Series Code")

# Examina o dataframe carregado
G20
# Out:
#       Country Name Country Code                                  Series Name  \
# 0        Argentina          ARG                            GDP (current US$)
# 1        Argentina          ARG                        GDP growth (annual %)
# 2        Argentina          ARG             GDP per capita growth (annual %)
# 3        Argentina          ARG                 GDP per capita (current US$)
# 4        Argentina          ARG     Imports of goods and services (% of GDP)
# ..             ...          ...                                          ...
# 195  United States          USA  Imports of goods and services (current US$)
# 196  United States          USA     Exports of goods and services (% of GDP)
# 197  United States          USA  Exports of goods and services (current US$)
# 198  United States          USA                            Population, total
# 199  United States          USA                                   Gini index
#
#      2012 [YR2012]  2013 [YR2013]  2014 [YR2014]  2015 [YR2015]  \
# 0     5.459824e+11   5.520251e+11   5.263197e+11   5.947493e+11
# 1    -1.026420e+00   2.405324e+00  -2.512615e+00   2.731160e+00
# 2    -2.145284e+00   1.265685e+00  -3.578581e+00   1.629664e+00
# 3     1.308266e+04   1.308025e+04   1.233480e+04   1.378906e+04
# 4     1.428868e+01   1.471676e+01   1.400132e+01   1.178057e+01
# ..             ...            ...            ...            ...
# 195   2.769317e+12   2.766375e+12   2.887445e+12   2.794850e+12
# 196   1.364405e+01   1.357807e+01   1.354596e+01   1.246099e+01
# 197   2.217700e+12   2.286981e+12   2.377408e+12   2.268651e+12
# 198   3.138777e+08   3.160599e+08   3.183863e+08   3.207390e+08
# 199   4.090000e+01   4.070000e+01   4.150000e+01   4.120000e+01
#
#      2016 [YR2016]  2017 [YR2017]  2018 [YR2018]  2019 [YR2019]  \
# 0     5.575314e+11   6.436287e+11   5.248197e+11   4.528184e+11
# 1    -2.080328e+00   2.818503e+00  -2.617396e+00  -2.025934e+00
# 2    -3.110064e+00   1.757648e+00  -3.601610e+00  -2.994388e+00
# 3     1.279024e+04   1.461304e+04   1.179516e+04   1.007636e+04
# 4     1.356679e+01   1.396932e+01   1.632585e+01   1.451850e+01
# ..             ...            ...            ...            ...
# 195   2.738359e+12   2.923691e+12   3.129697e+12   3.115990e+12
# 196   1.193954e+01   1.223719e+01   1.234224e+01   1.178954e+01
# 197   2.232110e+12   2.383758e+12   2.533511e+12   2.519727e+12
# 198   3.230718e+08   3.251221e+08   3.268382e+08   3.283300e+08
# 199   4.110000e+01   4.120000e+01   4.140000e+01   4.150000e+01
#
#      2020 [YR2020]  2021 [YR2021]
# 0     3.895910e+11   4.914927e+11
# 1    -9.895269e+00   1.026376e+01
# 2    -1.076511e+01   9.223956e+00
# 3     8.585695e+03   1.072923e+04
# 4     1.355632e+01   1.512831e+01
# ..             ...            ...
# 195   2.774597e+12            NaN
# 196   1.016290e+01            NaN
# 197   2.123410e+12            NaN
# 198   3.315011e+08   3.318937e+08
# 199            NaN            NaN
#
# [200 rows x 13 columns]

# %%
# Dicionário para atribuir continentes aos países listados
relPaisContinente = {
    "Argentina": "Américas",
    "Australia": "Oceania",
    "Brazil": "Américas",
    "Canada": "Américas",
    "China": "Ásia",
    "France": "Europa",
    "Germany": "Europa", 
    "India": "Ásia", 
    "Indonesia": "Oceania", 
    "Italy": "Europa", 
    "Japan": "Ásia", 
    "Korea, Rep.": "Ásia",
    "Mexico": "Américas", 
    "Russian Federation": "Europa", 
    "Saudi Arabia": "Ásia", 
    "South Africa": "África",
    "Turkiye": "Ásia",
    "United Kingdom": "Europa",
    "United States": "Américas",
    "Spain": "Europa"
}

# %%
# Cria uma coluna associando os continentes aos países
G20["Continent"] = G20.apply(lambda row: relPaisContinente[row["Country Name"]], axis = 1)

# Examina o dataframe resultante
G20
# Out:
#       Country Name Country Code                                  Series Name  \
# 0        Argentina          ARG                            GDP (current US$)
# 1        Argentina          ARG                        GDP growth (annual %)
# 2        Argentina          ARG             GDP per capita growth (annual %)
# 3        Argentina          ARG                 GDP per capita (current US$)
# 4        Argentina          ARG     Imports of goods and services (% of GDP)
# ..             ...          ...                                          ...
# 195  United States          USA  Imports of goods and services (current US$)
# 196  United States          USA     Exports of goods and services (% of GDP)
# 197  United States          USA  Exports of goods and services (current US$)
# 198  United States          USA                            Population, total
# 199  United States          USA                                   Gini index
#
#      2012 [YR2012]  2013 [YR2013]  2014 [YR2014]  2015 [YR2015]  \
# 0     5.459824e+11   5.520251e+11   5.263197e+11   5.947493e+11
# 1    -1.026420e+00   2.405324e+00  -2.512615e+00   2.731160e+00
# 2    -2.145284e+00   1.265685e+00  -3.578581e+00   1.629664e+00
# 3     1.308266e+04   1.308025e+04   1.233480e+04   1.378906e+04
# 4     1.428868e+01   1.471676e+01   1.400132e+01   1.178057e+01
# ..             ...            ...            ...            ...
# 195   2.769317e+12   2.766375e+12   2.887445e+12   2.794850e+12
# 196   1.364405e+01   1.357807e+01   1.354596e+01   1.246099e+01
# 197   2.217700e+12   2.286981e+12   2.377408e+12   2.268651e+12
# 198   3.138777e+08   3.160599e+08   3.183863e+08   3.207390e+08
# 199   4.090000e+01   4.070000e+01   4.150000e+01   4.120000e+01
#
#      2016 [YR2016]  2017 [YR2017]  2018 [YR2018]  2019 [YR2019]  \
# 0     5.575314e+11   6.436287e+11   5.248197e+11   4.528184e+11
# 1    -2.080328e+00   2.818503e+00  -2.617396e+00  -2.025934e+00
# 2    -3.110064e+00   1.757648e+00  -3.601610e+00  -2.994388e+00
# 3     1.279024e+04   1.461304e+04   1.179516e+04   1.007636e+04
# 4     1.356679e+01   1.396932e+01   1.632585e+01   1.451850e+01
# ..             ...            ...            ...            ...
# 195   2.738359e+12   2.923691e+12   3.129697e+12   3.115990e+12
# 196   1.193954e+01   1.223719e+01   1.234224e+01   1.178954e+01
# 197   2.232110e+12   2.383758e+12   2.533511e+12   2.519727e+12
# 198   3.230718e+08   3.251221e+08   3.268382e+08   3.283300e+08
# 199   4.110000e+01   4.120000e+01   4.140000e+01   4.150000e+01
#
#      2020 [YR2020]  2021 [YR2021] Continent
# 0     3.895910e+11   4.914927e+11  Américas
# 1    -9.895269e+00   1.026376e+01  Américas
# 2    -1.076511e+01   9.223956e+00  Américas
# 3     8.585695e+03   1.072923e+04  Américas
# 4     1.355632e+01   1.512831e+01  Américas
# ..             ...            ...       ...
# 195   2.774597e+12            NaN  Américas
# 196   1.016290e+01            NaN  Américas
# 197   2.123410e+12            NaN  Américas
# 198   3.315011e+08   3.318937e+08  Américas
# 199            NaN            NaN  Américas
#
# [200 rows x 14 columns]

# %%
# Reformata o dataframe para o formato longo, criando uma coluna Year (ano)
G20_long = pd.melt(G20, id_vars = ["Country Name", "Country Code", "Continent", "Series Name"], 
                   var_name = "Year",
                   value_name = "Value")

# Transforma a coluna Year para conter somente o valor numérico do ano
G20_long['Year'] = G20_long['Year'].apply(lambda x: int(x[:4]))

# Examina o dataframe resultante
G20_long
# Out:
#        Country Name Country Code Continent  \
# 0         Argentina          ARG  Américas
# 1         Argentina          ARG  Américas
# 2         Argentina          ARG  Américas
# 3         Argentina          ARG  Américas
# 4         Argentina          ARG  Américas
# ...             ...          ...       ...
# 1995  United States          USA  Américas
# 1996  United States          USA  Américas
# 1997  United States          USA  Américas
# 1998  United States          USA  Américas
# 1999  United States          USA  Américas
#
#                                       Series Name  Year         Value
# 0                               GDP (current US$)  2012  5.459824e+11
# 1                           GDP growth (annual %)  2012 -1.026420e+00
# 2                GDP per capita growth (annual %)  2012 -2.145284e+00
# 3                    GDP per capita (current US$)  2012  1.308266e+04
# 4        Imports of goods and services (% of GDP)  2012  1.428868e+01
# ...                                           ...   ...           ...
# 1995  Imports of goods and services (current US$)  2021           NaN
# 1996     Exports of goods and services (% of GDP)  2021           NaN
# 1997  Exports of goods and services (current US$)  2021           NaN
# 1998                            Population, total  2021  3.318937e+08
# 1999                                   Gini index  2021           NaN
#
# [2000 rows x 6 columns]

# %%
# Examina o nome de todas as séries de dados
sorted(set(G20_long['Series Name']))
# Out:
# ['Exports of goods and services (% of GDP)',
#  'Exports of goods and services (current US$)',
#  'GDP (current US$)',
#  'GDP growth (annual %)',
#  'GDP per capita (current US$)',
#  'GDP per capita growth (annual %)',
#  'Gini index',
#  'Imports of goods and services (% of GDP)',
#  'Imports of goods and services (current US$)',
#  'Population, total']

# %% [markdown]
# # Cria dataframe com os volumes de importação e exportação relativos ao PIB

# %%
# Cria dataframe com apenas os dados a serem visualizados
ie_long = G20_long[(G20_long['Series Name'] == 'Imports of goods and services (% of GDP)') | (G20_long['Series Name'] == 'Exports of goods and services (% of GDP)')].copy()

# Examine dataframe criado
ie_long
# Out:
#         Country Name Country Code Continent  \
# 4          Argentina          ARG  Américas
# 6          Argentina          ARG  Américas
# 14         Australia          AUS   Oceania
# 16         Australia          AUS   Oceania
# 24            Brazil          BRA  Américas
# ...              ...          ...       ...
# 1976         Turkiye          TUR      Ásia
# 1984  United Kingdom          GBR    Europa
# 1986  United Kingdom          GBR    Europa
# 1994   United States          USA  Américas
# 1996   United States          USA  Américas
#
#                                    Series Name  Year      Value
# 4     Imports of goods and services (% of GDP)  2012  14.288683
# 6     Exports of goods and services (% of GDP)  2012  16.237859
# 14    Imports of goods and services (% of GDP)  2012  21.672765
# 16    Exports of goods and services (% of GDP)  2012  21.504677
# 24    Imports of goods and services (% of GDP)  2012  13.236735
# ...                                        ...   ...        ...
# 1976  Exports of goods and services (% of GDP)  2021  35.395628
# 1984  Imports of goods and services (% of GDP)  2021  28.246256
# 1986  Exports of goods and services (% of GDP)  2021  26.990049
# 1994  Imports of goods and services (% of GDP)  2021        NaN
# 1996  Exports of goods and services (% of GDP)  2021        NaN
#
# [400 rows x 6 columns]

# %% [markdown]
# # Cria dataframe no formato "wide" com valores de exportação e importação

# %%
ie_wide = pd.pivot(ie_long, index = ['Country Name', 'Country Code', 'Continent', 'Year'], columns= 'Series Name', values='Value').reset_index()
ie_wide
# Out:
# Series Name   Country Name Country Code Continent  Year  \
# 0                Argentina          ARG  Américas  2012
# 1                Argentina          ARG  Américas  2013
# 2                Argentina          ARG  Américas  2014
# 3                Argentina          ARG  Américas  2015
# 4                Argentina          ARG  Américas  2016
# ..                     ...          ...       ...   ...
# 195          United States          USA  Américas  2017
# 196          United States          USA  Américas  2018
# 197          United States          USA  Américas  2019
# 198          United States          USA  Américas  2020
# 199          United States          USA  Américas  2021
#
# Series Name  Exports of goods and services (% of GDP)  \
# 0                                           16.237859
# 1                                           14.617173
# 2                                           14.405479
# 3                                           10.705652
# 4                                           12.527095
# ..                                                ...
# 195                                         12.237189
# 196                                         12.342241
# 197                                         11.789535
# 198                                         10.162899
# 199                                               NaN
#
# Series Name  Imports of goods and services (% of GDP)
# 0                                           14.288683
# 1                                           14.716756
# 2                                           14.001315
# 3                                           11.780574
# 4                                           13.566793
# ..                                                ...
# 195                                         15.008973
# 196                                         15.246618
# 197                                         14.579387
# 198                                         13.279559
# 199                                               NaN
#
# [200 rows x 6 columns]

# %%
# Cria dataframe com dados de 2021
ie_wide_2020 = ie_wide[ie_wide["Year"] == 2020]
ie_wide_2020
# Out:
# Series Name        Country Name Country Code Continent  Year  \
# 8                     Argentina          ARG  Américas  2020
# 18                    Australia          AUS   Oceania  2020
# 28                       Brazil          BRA  Américas  2020
# 38                       Canada          CAN  Américas  2020
# 48                        China          CHN      Ásia  2020
# 58                       France          FRA    Europa  2020
# 68                      Germany          DEU    Europa  2020
# 78                        India          IND      Ásia  2020
# 88                    Indonesia          IDN   Oceania  2020
# 98                        Italy          ITA    Europa  2020
# 108                       Japan          JPN      Ásia  2020
# 118                 Korea, Rep.          KOR      Ásia  2020
# 128                      Mexico          MEX  Américas  2020
# 138          Russian Federation          RUS    Europa  2020
# 148                Saudi Arabia          SAU      Ásia  2020
# 158                South Africa          ZAF    África  2020
# 168                       Spain          ESP    Europa  2020
# 178                     Turkiye          TUR      Ásia  2020
# 188              United Kingdom          GBR    Europa  2020
# 198               United States          USA  Américas  2020
#
# Series Name  Exports of goods and services (% of GDP)  \
# 8                                           16.591817
# 18                                          23.983854
# 28                                          16.795068
# 38                                          29.363448
# 48                                          18.541060
# 58                                          27.873644
# 68                                          43.416895
# 78                                          18.708899
# 88                                          17.271421
# 98                                          29.532511
# 108                                         15.558554
# 118                                         36.445859
# 128                                         39.603047
# 138                                         25.531215
# 148                                         26.182905
# 158                                         27.778011
# 168                                         30.620938
# 178                                         28.664856
# 188                                         28.362276
# 198                                         10.162899
#
# Series Name  Imports of goods and services (% of GDP)
# 8                                           13.556325
# 18                                          20.055673
# 28                                          16.095384
# 38                                          31.419082
# 48                                          16.048190
# 58                                          29.893784
# 68                                          37.691652
# 78                                          19.096455
# 88                                          15.704174
# 98                                          25.870131
# 108                                         15.800157
# 118                                         32.769662
# 128                                         37.555725
# 138                                         20.430731
# 148                                         25.893684
# 158                                         23.348835
# 168                                         29.147786
# 178                                         32.475748
# 188                                         28.066701
# 198                                         13.279559

# %% [markdown]
# # Gráfico de dispersão (*scatterplot*) com dados de importação e exportação relativos ao PIB em 2020

# %% [markdown]
# 1: Plota o gráfico de dispersão e inclui título e rótulos dos eixos
# * Função `pyplot.scatter()` para o gráfico de dispersão
# * Função `Axes.set_title()` para o título
# * Funções `Axes.set_xlabel()` e `Axes.set_ylabel()` para os rótulos dos eixos

# %%
# Prepara a figura (fig) e a área do gráfico (ax) com largura 8 e altura 8
fig, ax = plt.subplots(figsize = (8, 8))

# Plota o gráfico de dispersão
ax.scatter(x = ie_wide_2020['Imports of goods and services (% of GDP)'], y = ie_wide_2020['Exports of goods and services (% of GDP)'], 
        color = corDefault)

# Acrescenta um título ao gráfico
ax.set_title('Importações e exportações de bens e serviços nos países do G20 em 2020')

# Define os rótulos dos eixos
ax.set_xlabel('importação de bens e serviços (% do PIB)') # é importante esclarecer a unidade e a ordem de grandeza
ax.set_ylabel('exportação de bens e serviços (% do PIB)') # é importante esclarecer a unidade e a ordem de grandeza

# Armazena o gráfico (em diferentes formatos):
# - formatos vetoriais (NÃO perdem resolução quando redimensionados)
plt.savefig("scatterplot.pdf")
plt.savefig("scatterplot.svg")
# - formato rasterizado (perde resolução quando redimensionado)
plt.savefig("scatterplot.png", dpi = 150, format = "png")

# Exibe o gráfico
plt.show()

# %% [markdown]
# ## Variação: Colorir pontos conforme o continente

# %%
# Define as cores por continente
continentes = sorted(set(ie_wide["Continent"]))
dictCoresContinentes = dict(zip(continentes, coresViridis))

# Prepara a figura (fig) e a área do gráfico (ax) com largura 8 e altura 8
fig, ax = plt.subplots(figsize = (8, 8))

# Plota um gráfico de dispersão por continente
plots = []
for i, continente in enumerate(continentes):
  dados = ie_wide_2020[(ie_wide_2020["Continent"] == continente)]
  plots.append(ax.scatter(x = dados['Imports of goods and services (% of GDP)'], y = dados['Exports of goods and services (% of GDP)'], 
            color = dictCoresContinentes[continente], 
            label = continente))

# Acrescenta um título ao gráfico
ax.set_title('Importações e exportações de bens e serviços nos países do G20 em 2020')

# Define os rótulos dos eixos
ax.set_xlabel('importação de bens e serviços (% do PIB)') # é importante esclarecer a unidade e a ordem de grandeza
ax.set_ylabel('exportação de bens e serviços (% do PIB)') # é importante esclarecer a unidade e a ordem de grandeza

# Acrescenta legenda
plt.legend()

# Armazena o gráfico (em diferentes formatos):
# - formatos vetoriais (NÃO perdem resolução quando redimensionados)
plt.savefig("scatterplot-cores.pdf")
plt.savefig("scatterplot-cores.svg")
# - formato rasterizado (perde resolução quando redimensionado)
plt.savefig("scatterplot-cores.png", dpi = 150, format = "png")

# Exibe o gráfico
plt.show()

# %% [markdown]
# Variação: Gráficos de dispersão em pequenos múltiplos

# %%
# Define as cores por continente
continentes = sorted(set(ie_wide["Continent"]))
dictCoresContinentes = dict(zip(continentes, coresViridis))

# Prepara a figura (fig) e a área do gráfico (ax) com largura 15 e altura 10
# e com eixos x e y compartilhados
fig, axs = plt.subplots(nrows = 2, ncols = 3, figsize = (15, 10), sharex = True, sharey = True)

# Plota um gráfico de dispersão por continente
for i in range(0, 2):
  for j in range(0, 3):
    k = i * 3 + j 
    if k < len(continentes):
      continente = continentes[k]
      dados = ie_wide_2020[(ie_wide_2020["Continent"] == continente)]
      axs[i, j].scatter(x = dados['Imports of goods and services (% of GDP)'], y = dados['Exports of goods and services (% of GDP)'], 
                color = dictCoresContinentes[continente], 
                alpha = 0.75,
                label = continente)
      axs[i, j].set_title(continente)
      # Define os rótulos dos eixos
      axs[i,j].set_xlabel('importação (% do PIB)') # é importante esclarecer a unidade e a ordem de grandeza
      axs[i,j].set_ylabel('exportação (% do PIB)') # é importante esclarecer a unidade e a ordem de grandeza
    else:
      axs[i,j].set_visible(False)

# Acrescenta um título à figura (superior a todos os gráficos)
fig.suptitle('Importações e exportações de bens e serviços nos países do G20 em 2020')

# Armazena o gráfico (em diferentes formatos):
# - formatos vetoriais (NÃO perdem resolução quando redimensionados)
plt.savefig("scatterplot-multiplos.pdf")
plt.savefig("scatterplot-multiplos.svg")
# - formato rasterizado (perde resolução quando redimensionado)
plt.savefig("scatterplot-multiplos.png", dpi = 150, format = "png")

# Exibe o gráfico
plt.show()
